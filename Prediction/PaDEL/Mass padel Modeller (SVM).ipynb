# %%
#26/8/24 Creates a K fold KNN model for each file in a folder provided they are padel

import os
import pandas as pd
import numpy as np
import math
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Padel/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
resultslist = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 4):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = mtry,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)


            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = bestmetrics,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)

        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    resultslist.append(results[12])
# Out:
# ========================================
# For dataset Hepatotoxicity_PaDEL.csv
# for fold 1 test set mcc of 0.044896511966089965 valid set mcc of -0.07920680151201938
# for fold 2 test set mcc of 0.007620661851060195 valid set mcc of 0.003258744989316822
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0.03620697591426426 valid set mcc of 0.01091772022063852
# for fold 5 test set mcc of 0.04032258064516129 valid set mcc of 0.08435845241842684
#
# validation metrics of:
# positives in data 249
# negatives in data 226
# net accuracy = 0.52
# mcc = -0.041664190650208786
# ========================================
# For dataset NR-PPAR-gamma_PaDEL.csv
# for fold 1 test set mcc of 0.14860752335342742 valid set mcc of 0.07858682668274143
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0.2218421599939607 valid set mcc of 0.0222717701593687
# for fold 5 test set mcc of 0.10660035817780521 valid set mcc of -0.03739787960033829
#
# validation metrics of:
# positives in data 29
# negatives in data 36
# net accuracy = 0.5384615384615384
# mcc = -0.012287873191375833
# ========================================
# For dataset NR-AR-LBD_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.10369516947304253 valid set mcc of 0
# for fold 3 test set mcc of 0.22710998958306755 valid set mcc of 0.225101084147303
# for fold 4 test set mcc of 0.04957577328158355 valid set mcc of 0
# for fold 5 test set mcc of 0.397705839334203 valid set mcc of 0.07174300539794393
#
# validation metrics of:
# positives in data 41
# negatives in data 44
# net accuracy = 0.5176470588235295
# mcc = 0.1026262674759889
# ========================================
# For dataset NR-AR_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.192068331336634 valid set mcc of 0
# for fold 3 test set mcc of 0.04724555912615341 valid set mcc of 0.09962343947220229
# for fold 4 test set mcc of 0 valid set mcc of 0.12795265564328
# for fold 5 test set mcc of 0.23134892065350224 valid set mcc of 0
#
# validation metrics of:
# positives in data 55
# negatives in data 59
# net accuracy = 0.5614035087719298
# mcc = 0.22002729183355538
# ========================================
# For dataset Respiratory_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Ames_Mutagenicity_PaDEL.csv
# for fold 1 test set mcc of 0.08349783909986855 valid set mcc of 0.07414088941681836
# for fold 2 test set mcc of 0.10250935877803453 valid set mcc of 0.07775601340684461
# for fold 3 test set mcc of 0.12362377896470883 valid set mcc of 0.0667563446108813
# for fold 4 test set mcc of 0.15305889448909443 valid set mcc of 0.03680597509855791
# for fold 5 test set mcc of 0.09416229539053975 valid set mcc of 0.09524382367634374
#
# validation metrics of:
# positives in data 790
# negatives in data 611
# net accuracy = 0.583868665239115
# mcc = 0.11916222957534281
# ========================================
# For dataset Cardiotoxicity-1_PaDEL.csv
# for fold 1 test set mcc of 0.10342786900932203 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Developmental_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-ER-LBD_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.02873942942636716 valid set mcc of 0.08547960742202877
# for fold 3 test set mcc of 0.02873942942636716 valid set mcc of 0.12948309934455932
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0.03564363423913181
#
# validation metrics of:
# positives in data 61
# negatives in data 67
# net accuracy = 0.515625
# mcc = -0.044426769723184524
# ========================================
# For dataset SR-ARE_PaDEL.csv
# for fold 1 test set mcc of 0.02278214986997527 valid set mcc of 0
# for fold 2 test set mcc of 0.013499946000323998 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0.015024366745489466 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 160
# negatives in data 225
# net accuracy = 0.5792207792207792
# mcc = -0.03442678335356777
# ========================================
# For dataset Cardiotoxicity-10_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0.09787577659555899 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 157
# negatives in data 99
# net accuracy = 0.6015625
# mcc = -0.0347746251948789
# ========================================
# For dataset SR-p53_PaDEL.csv
# for fold 1 test set mcc of 0.1552223774446773 valid set mcc of 0.12943016062061133
# for fold 2 test set mcc of 0.1752983667812797 valid set mcc of -0.08153688226810184
# for fold 3 test set mcc of 0.06142951168339512 valid set mcc of 0
# for fold 4 test set mcc of 0.093706146008198 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 65
# negatives in data 80
# net accuracy = 0.5448275862068965
# mcc = -0.0019818812256437255
# ========================================
# For dataset Reproductive_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-AhR_PaDEL.csv
# for fold 1 test set mcc of 0.008483796839677036 valid set mcc of -0.0018411617182912878
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0.017078584845967148 valid set mcc of 0
# for fold 4 test set mcc of 0.06887700227870033 valid set mcc of 0
# for fold 5 test set mcc of 0.06595715377236427 valid set mcc of 0
#
# validation metrics of:
# positives in data 136
# negatives in data 168
# net accuracy = 0.555921052631579
# mcc = 0.044031352467577924
# ========================================
# For dataset Carcinogenicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.07935196008581541 valid set mcc of -0.0634916007741964
# for fold 3 test set mcc of 0.10308374045052707 valid set mcc of -0.08183170883849714
# for fold 4 test set mcc of 0.06532553344640132 valid set mcc of 0
# for fold 5 test set mcc of 0.22222378083968178 valid set mcc of 0.12248296376214993
#
# validation metrics of:
# positives in data 94
# negatives in data 94
# net accuracy = 0.5425531914893617
# mcc = 0.13801311186847084
# ========================================
# For dataset NR-ER_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.0825064022120018 valid set mcc of 0.04062815260439482
# for fold 3 test set mcc of 0.05679301390639018 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of -0.05471045255007144
# for fold 5 test set mcc of 0.13788893072094477 valid set mcc of -0.03998186489252411
#
# validation metrics of:
# positives in data 142
# negatives in data 193
# net accuracy = 0.564179104477612
# mcc = -0.04397274623673089
# ========================================
# For dataset NR-aromatase_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of -0.0950496913043515
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0.21483446221182986 valid set mcc of 0.0
# for fold 4 test set mcc of 0.02946043407527773 valid set mcc of -0.07380124046167462
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 53
# negatives in data 57
# net accuracy = 0.5181818181818182
# mcc = 0.008740043387431076
# ========================================
# For dataset Cardiotoxicity-5_PaDEL.csv
# for fold 1 test set mcc of 0.01790389053554956 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0.008333333333333333 valid set mcc of -0.046070323934988215
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset SR-HSE_PaDEL.csv
# for fold 1 test set mcc of 0.07577069075791953 valid set mcc of 0
# for fold 2 test set mcc of 0.11478278228033131 valid set mcc of -0.07372097807744857
# for fold 3 test set mcc of 0.18218902918214652 valid set mcc of 0.0
# for fold 4 test set mcc of 0.08295150620062532 valid set mcc of 0.12797267422224787
# for fold 5 test set mcc of 0.10683473081289468 valid set mcc of 0
#
# validation metrics of:
# positives in data 62
# negatives in data 72
# net accuracy = 0.5746268656716418
# mcc = 0.14095153371938593
# ========================================
# For dataset Cardiotoxicity-30_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset SR-ATAD5_PaDEL.csv
# for fold 1 test set mcc of 0.05527899928227821 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0.13093568454461216 valid set mcc of -0.19474579822405907
#
# validation metrics of:
# positives in data 42
# negatives in data 48
# net accuracy = 0.5333333333333333
# mcc = 0.010072787050317254
# ========================================
# For dataset SR-MMP_PaDEL.csv
# for fold 1 test set mcc of 0.2676044987275019 valid set mcc of -0.0031921686187837157
# for fold 2 test set mcc of 0.17864541895637806 valid set mcc of 0.18741100391879767
# for fold 3 test set mcc of 0.14497027039847687 valid set mcc of 0.05184577852795757
# for fold 4 test set mcc of 0.1385540857939326 valid set mcc of 0.1815173985093618
# for fold 5 test set mcc of 0.1899483051289014 valid set mcc of 0.10883849693542025
#
# validation metrics of:
# positives in data 161
# negatives in data 217
# net accuracy = 0.6243386243386243
# mcc = 0.22319647641775542

# %%
namelist
# Out:
# ['NR-ER_Chemopy.csv',
#  'Developmental_Toxicity_Chemopy.csv',
#  'NR-aromatase_Chemopy.csv',
#  'SR-ATAD5_Chemopy.csv',
#  'SR-ARE_Chemopy.csv',
#  'SR-p53_Chemopy.csv',
#  'Cardiotoxicity-1_Chemopy.csv',
#  'SR-HSE_Chemopy.csv',
#  'Respiratory_Toxicity_Chemopy.csv',
#  'Carcinogenicity_Chemopy.csv',
#  'Cardiotoxicity-30_Chemopy.csv',
#  'Cardiotoxicity-10_Chemopy.csv',
#  'Cardiotoxicity-5_Chemopy.csv',
#  'NR-AR-LBD_Chemopy.csv',
#  'Ames_Mutagenicity_Chemopy.csv',
#  'Hepatotoxicity_Chemopy.csv',
#  'NR-AR_Chemopy.csv',
#  'Reproductive_Toxicity_Chemopy.csv',
#  'NR-ER-LBD_Chemopy.csv',
#  'NR-PPAR-gamma_Chemopy.csv',
#  'NR-AhR_Chemopy.csv',
#  'SR-MMP_Chemopy.csv']

# %%
len(resultslist)
# Out:
# 22

# %%
temp = pd.DataFrame(resultslist, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Figure_Development/PaDEL/data/padel_svm.csv')
