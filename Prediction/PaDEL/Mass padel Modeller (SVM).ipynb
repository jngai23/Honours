# %%
#26/8/24 Creates a K fold KNN model for each file in a folder provided they are padel

import os
import pandas as pd
import numpy as np
import math
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math
pd.options.mode.use_inf_as_na = True

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Padel/3D/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
resultslist = []
for df in datasets:
    df = df.dropna()
    df = df.dropna()
    df = df.drop(['Name'], axis=1)
    df = df.to_numpy()
    df = np.nan_to_num(df)
    df = pd.DataFrame(df)
    df = df.rename(columns={0: "Toxicity_Value"})
    dfarray = df.to_numpy()
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 4):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = mtry,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)


            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = bestmetrics,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)

        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    resultslist.append(results[12])
# Out:
# /var/folders/cq/5cl8ry195dj0219k6rt6csbm0000gn/T/ipykernel_27013/1430333831.py:15: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.options.mode.use_inf_as_na = True
# ========================================
# For dataset Hepatotoxicity_PaDEL.csv
# for fold 1 test set mcc of 0.007482336909294478 valid set mcc of 0
# for fold 2 test set mcc of 0.09493697024570262 valid set mcc of 0.0007069300707549023
# for fold 3 test set mcc of 0.06376732639486413 valid set mcc of 0.10173070603104845
# for fold 4 test set mcc of 0.007352352295762271 valid set mcc of 0
# for fold 5 test set mcc of 0.06799012476753126 valid set mcc of -0.053359619019448884
#
# validation metrics of:
# positives in data 293
# negatives in data 283
# net accuracy = 0.5034722222222222
# mcc = -0.0277510912270634
# ========================================
# For dataset NR-PPAR-gamma_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-AR-LBD_PaDEL.csv
# for fold 1 test set mcc of 0.1777575437524446 valid set mcc of 0.018781205660633703
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0.23134069792952236 valid set mcc of -0.11878277418329972
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0.15737789507292674 valid set mcc of 0
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.4895833333333333
# mcc = -0.00931897247219203
# ========================================
# For dataset NR-AR_PaDEL.csv
# for fold 1 test set mcc of 0.0789781195492476 valid set mcc of 0.07690288519554891
# for fold 2 test set mcc of 0.17588161767036212 valid set mcc of 0.24618298195866548
# for fold 3 test set mcc of 0.10977563647894488 valid set mcc of 0.3644054444067475
# for fold 4 test set mcc of 0.0842151921066519 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.552
# mcc = 0.20948951387692868
# ========================================
# For dataset Respiratory_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0.05138989789408431 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Ames_Mutagenicity_PaDEL.csv
# for fold 1 test set mcc of 0.06387801375051609 valid set mcc of 0.07202966852358109
# for fold 2 test set mcc of 0.10876433821225791 valid set mcc of 0.09442084204422906
# for fold 3 test set mcc of 0.1496259304022976 valid set mcc of 0.15499017359095899
# for fold 4 test set mcc of 0.09002471837999015 valid set mcc of 0.113035883628836
# for fold 5 test set mcc of 0.12699778754436186 valid set mcc of 0.049335781105421896
#
# validation metrics of:
# positives in data 839
# negatives in data 657
# net accuracy = 0.5862299465240641
# mcc = 0.13412252726494409
# ========================================
# For dataset Cardiotoxicity-1_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Developmental_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-ER-LBD_PaDEL.csv
# for fold 1 test set mcc of 0.05086846840791568 valid set mcc of -0.1302878414515109
# for fold 2 test set mcc of 0.011720180773462385 valid set mcc of -0.013964247025894199
# for fold 3 test set mcc of 0 valid set mcc of -0.011720180773462385
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 69
# negatives in data 76
# net accuracy = 0.5379310344827586
# mcc = 0.09245411182168033
# ========================================
# For dataset SR-ARE_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Cardiotoxicity-10_PaDEL.csv
# for fold 1 test set mcc of 0.03650599595485923 valid set mcc of 0.11246715932323313
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0.022277183154991064 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 190
# negatives in data 119
# net accuracy = 0.6116504854368932
# mcc = 0.0039233383267631
# ========================================
# For dataset SR-p53_PaDEL.csv
# for fold 1 test set mcc of 0.1983265651147133 valid set mcc of 0.010257624248277726
# for fold 2 test set mcc of 0.19211686860162736 valid set mcc of -0.07796387675305838
# for fold 3 test set mcc of 0 valid set mcc of -0.04482107285003976
# for fold 4 test set mcc of 0 valid set mcc of -0.03677848562449136
# for fold 5 test set mcc of 0 valid set mcc of 0.04982137763721182
#
# validation metrics of:
# positives in data 81
# negatives in data 88
# net accuracy = 0.5207100591715976
# mcc = 0.01146106552968651
# ========================================
# For dataset Reproductive_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-AhR_PaDEL.csv
# for fold 1 test set mcc of 0.00736187729426597 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0.07308816827558576 valid set mcc of 0.022408582636848026
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Carcinogenicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.192068331336634 valid set mcc of 0.04539658520388832
# for fold 3 test set mcc of 0.19485877909876578 valid set mcc of 0.15339356171742885
# for fold 4 test set mcc of 0 valid set mcc of -0.021246134125960322
# for fold 5 test set mcc of 0.024999822780712395 valid set mcc of 0.1444960929545186
#
# validation metrics of:
# positives in data 101
# negatives in data 103
# net accuracy = 0.5147058823529411
# mcc = 0.041441586784417464
# ========================================
# For dataset NR-ER_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0.020268745359939996
# for fold 3 test set mcc of 0.023029057032387137 valid set mcc of 0.06772309752492321
# for fold 4 test set mcc of 0.05699465149248665 valid set mcc of 0
# for fold 5 test set mcc of 0.1264559777648223 valid set mcc of -0.03556194915061158
#
# validation metrics of:
# positives in data 156
# negatives in data 210
# net accuracy = 0.5737704918032787
# mcc = 0.019258222162991084
# ========================================
# For dataset NR-aromatase_PaDEL.csv
# for fold 1 test set mcc of 0.14301644557079338 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0.028048409700253712 valid set mcc of 0
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.512396694214876
# mcc = -0.04660043461071933
# ========================================
# For dataset Cardiotoxicity-5_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.017941315508213013 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset SR-HSE_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0.01866308369852848 valid set mcc of 0.09887865147828519
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Cardiotoxicity-30_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset SR-ATAD5_PaDEL.csv
# for fold 1 test set mcc of 0.1369780776730122 valid set mcc of 0.2721655269759087
# for fold 2 test set mcc of 0.0732958551392412 valid set mcc of 0.0663372722626695
# for fold 3 test set mcc of 0 valid set mcc of 0.032274861218395144
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0.09354143466934853 valid set mcc of 0
#
# validation metrics of:
# positives in data 51
# negatives in data 52
# net accuracy = 0.5436893203883495
# mcc = 0.15382379606111096
# ========================================
# For dataset SR-MMP_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.084602870323426 valid set mcc of 0.14819469257928403
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0

# %%
resultslist
# Out:
# [-0.0277510912270634,
#  0,
#  -0.00931897247219203,
#  0.20948951387692868,
#  0,
#  0.13412252726494409,
#  0,
#  0,
#  0.09245411182168033,
#  0,
#  0.0039233383267631,
#  0.01146106552968651,
#  0,
#  0,
#  0.041441586784417464,
#  0.019258222162991084,
#  -0.04660043461071933,
#  0,
#  0,
#  0,
#  0.15382379606111096,
#  0]

# %%
namelist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 namelist
#
# NameError: name 'namelist' is not defined

# %%
temp = pd.DataFrame(resultslist, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Figure_Development/PaDEL/data/3D/padel_svm.csv')
