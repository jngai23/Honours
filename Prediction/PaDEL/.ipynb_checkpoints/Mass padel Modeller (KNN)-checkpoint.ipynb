# %%
#26/8/24 Creates a K fold KNN model for each file in a folder provided they are padel

import os
import pandas as pd
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math
pd.options.mode.use_inf_as_na = True

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Padel/3D/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
finalresults = []
for df in datasets:
    df = df.dropna()
    df = df.dropna()
    df = df.drop(['Name'], axis=1)
    df = df.to_numpy()
    df = np.nan_to_num(df)
    df = pd.DataFrame(df)
    df = df.rename(columns={0: "Toxicity_Value"})
    dfarray = df.to_numpy()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        
        length = len(xtrain)
        nneigh = 100
        if length < nneigh:
            nneigh = length
        for mtry in range(1, nneigh):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = KNeighborsClassifier(n_neighbors=mtry, weights='distance', 
                            algorithm='auto', leaf_size=100, p=2, metric='minkowski', 
                            metric_params=None, n_jobs=4)

            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = KNeighborsClassifier(n_neighbors=bestmetrics, weights='distance', 
                            algorithm='auto', leaf_size=100, p=2, metric='minkowski', 
                            metric_params=None, n_jobs=4)
        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    finalresults.append(results[12])
# Out:
# /var/folders/cq/5cl8ry195dj0219k6rt6csbm0000gn/T/ipykernel_2622/4070467726.py:15: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.options.mode.use_inf_as_na = True
# ========================================
# For dataset Hepatotoxicity_PaDEL.csv
# for fold 1 test set mcc of 0.36442649807773236 valid set mcc of 0.2649573206650135
# for fold 2 test set mcc of 0.32799696997113265 valid set mcc of 0.3160342302853533
# for fold 3 test set mcc of 0.39352690659242356 valid set mcc of 0.3944343311190788
# for fold 4 test set mcc of 0.3227167898602232 valid set mcc of 0.31577769971390995
# for fold 5 test set mcc of 0.321708962392648 valid set mcc of 0.18402312981791566
#
# validation metrics of:
# positives in data 293
# negatives in data 283
# net accuracy = 0.6440972222222222
# mcc = 0.28773398077591283
# ========================================
# For dataset NR-PPAR-gamma_PaDEL.csv
# for fold 1 test set mcc of 0.30952380952380953 valid set mcc of 0.5345224838248488
# for fold 2 test set mcc of 0.25123411544939434 valid set mcc of 0.5933082268219884
# for fold 3 test set mcc of 0.3779947574107829 valid set mcc of 0.3942307692307692
# for fold 4 test set mcc of 0.5814571893892646 valid set mcc of 0.40121296172898085
# for fold 5 test set mcc of 0.6424188694912957 valid set mcc of 0.042797648953895366
#
# validation metrics of:
# positives in data 35
# negatives in data 37
# net accuracy = 0.6527777777777778
# mcc = 0.30460012749977394
# ========================================
# For dataset NR-AR-LBD_PaDEL.csv
# for fold 1 test set mcc of 0.5803810000880093 valid set mcc of 0.46953014151584255
# for fold 2 test set mcc of 0.8406414965939838 valid set mcc of 0.4353577159671462
# for fold 3 test set mcc of 0.6356048762998656 valid set mcc of 0.5871841250301055
# for fold 4 test set mcc of 0.3779504272457184 valid set mcc of 0.38421052631578945
# for fold 5 test set mcc of 0.6150708011167444 valid set mcc of 0.6708203932499369
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.78125
# mcc = 0.5670807236297686
# ========================================
# For dataset NR-AR_PaDEL.csv
# for fold 1 test set mcc of 0.5664652260218807 valid set mcc of 0.39747795134385916
# for fold 2 test set mcc of 0.6651330399133047 valid set mcc of 0.6531972647421809
# for fold 3 test set mcc of 0.45924984246809447 valid set mcc of 0.7624437362098715
# for fold 4 test set mcc of 0.600245047998781 valid set mcc of 0.47534745630546277
# for fold 5 test set mcc of 0.7495652173913043 valid set mcc of 0.26471377818400643
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.696
# mcc = 0.3986118512736629
# ========================================
# For dataset Respiratory_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0.43307569930317197 valid set mcc of 0.16690042075736325
# for fold 2 test set mcc of 0.3919033577599661 valid set mcc of 0.2327618734517921
# for fold 3 test set mcc of 0.4433330929507443 valid set mcc of 0.330972210813609
# for fold 4 test set mcc of 0.31463112971231105 valid set mcc of 0.40291148201269017
# for fold 5 test set mcc of 0.3258703822882119 valid set mcc of 0.3760115382517821
#
# validation metrics of:
# positives in data 163
# negatives in data 106
# net accuracy = 0.6728624535315985
# mcc = 0.29711970815452493
# ========================================
# For dataset Ames_Mutagenicity_PaDEL.csv
# for fold 1 test set mcc of 0.48206238952155306 valid set mcc of 0.43472931838567236
# for fold 2 test set mcc of 0.47433097733441676 valid set mcc of 0.36962688589390763
# for fold 3 test set mcc of 0.4661547705263608 valid set mcc of 0.4609950341662404
# for fold 4 test set mcc of 0.4360115302419883 valid set mcc of 0.44624533116761783
# for fold 5 test set mcc of 0.45356900644548737 valid set mcc of 0.4320748545692979
#
# validation metrics of:
# positives in data 839
# negatives in data 657
# net accuracy = 0.7266042780748663
# mcc = 0.44005060438170496
# ========================================
# For dataset Cardiotoxicity-1_PaDEL.csv
# for fold 1 test set mcc of 0.3917299065898154 valid set mcc of 0.2401409011362083
# for fold 2 test set mcc of 0.3856041288404944 valid set mcc of 0.506518593906335
# for fold 3 test set mcc of 0.4103681277810839 valid set mcc of 0.25502592544076436
# for fold 4 test set mcc of 0.3582608695652174 valid set mcc of 0.5386904761904762
# for fold 5 test set mcc of 0.37752711907679926 valid set mcc of 0.27333782575667837
#
# validation metrics of:
# positives in data 70
# negatives in data 239
# net accuracy = 0.7961165048543689
# mcc = 0.3352911848523585
# ========================================
# For dataset Developmental_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0.25
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0.0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 8
# negatives in data 6
# net accuracy = 0.6428571428571429
# mcc = 0.251259453814803
# ========================================
# For dataset NR-ER-LBD_PaDEL.csv
# for fold 1 test set mcc of 0.4304925884122814 valid set mcc of 0.2876871870285159
# for fold 2 test set mcc of 0.5520524474738834 valid set mcc of 0.17937400083354382
# for fold 3 test set mcc of 0.3671064458432221 valid set mcc of 0.37857142857142856
# for fold 4 test set mcc of 0.560112033611204 valid set mcc of 0.5411415938540767
# for fold 5 test set mcc of 0.3348006918570717 valid set mcc of 0.3983771666930137
#
# validation metrics of:
# positives in data 69
# negatives in data 76
# net accuracy = 0.7241379310344828
# mcc = 0.4469870327993898
# ========================================
# For dataset SR-ARE_PaDEL.csv
# for fold 1 test set mcc of 0.3813808481049714 valid set mcc of 0.17304727376259443
# for fold 2 test set mcc of 0.3251778531441199 valid set mcc of 0.3100054281901844
# for fold 3 test set mcc of 0.3529658223806545 valid set mcc of 0.27470313991673134
# for fold 4 test set mcc of 0.2703945405276701 valid set mcc of 0.2763010723410064
# for fold 5 test set mcc of 0.32217639478347854 valid set mcc of 0.33912921674035035
#
# validation metrics of:
# positives in data 178
# negatives in data 242
# net accuracy = 0.6547619047619048
# mcc = 0.2811893561157818
# ========================================
# For dataset Cardiotoxicity-10_PaDEL.csv
# for fold 1 test set mcc of 0.2520221940134379 valid set mcc of 0.2672219705520019
# for fold 2 test set mcc of 0.3342490706137219 valid set mcc of 0.33123374297594527
# for fold 3 test set mcc of 0.33775288825035676 valid set mcc of 0.36362153659511737
# for fold 4 test set mcc of 0.33856343261676836 valid set mcc of 0.1489730228233566
# for fold 5 test set mcc of 0.3287202291733454 valid set mcc of 0.17678418095339263
#
# validation metrics of:
# positives in data 190
# negatives in data 119
# net accuracy = 0.6796116504854369
# mcc = 0.28593358301364796
# ========================================
# For dataset SR-p53_PaDEL.csv
# for fold 1 test set mcc of 0.5627039587626639 valid set mcc of 0.22889594398897323
# for fold 2 test set mcc of 0.5549617799408361 valid set mcc of 0.29523809523809524
# for fold 3 test set mcc of 0.48877086807379044 valid set mcc of 0.2145308842782656
# for fold 4 test set mcc of 0.3053047307786778 valid set mcc of 0.1355393195313562
# for fold 5 test set mcc of 0.43115726148674066 valid set mcc of 0.2072072072072072
#
# validation metrics of:
# positives in data 81
# negatives in data 88
# net accuracy = 0.6923076923076923
# mcc = 0.38277695409216156
# ========================================
# For dataset Reproductive_Toxicity_PaDEL.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 5
# negatives in data 4
# net accuracy = 0.5555555555555556
# mcc = 0.05976143046671968
# ========================================
# For dataset NR-AhR_PaDEL.csv
# for fold 1 test set mcc of 0.4635133474834651 valid set mcc of 0.4747340305417816
# for fold 2 test set mcc of 0.4893484917635828 valid set mcc of 0.49508667646895843
# for fold 3 test set mcc of 0.5087719298245614 valid set mcc of 0.33004157719410765
# for fold 4 test set mcc of 0.4395210727252969 valid set mcc of 0.4597362928334753
# for fold 5 test set mcc of 0.5441355180887718 valid set mcc of 0.45671062515379907
#
# validation metrics of:
# positives in data 147
# negatives in data 187
# net accuracy = 0.6916167664670658
# mcc = 0.39141202231490524
# ========================================
# For dataset Carcinogenicity_PaDEL.csv
# for fold 1 test set mcc of 0.21977383072747694 valid set mcc of 0.3315938128703508
# for fold 2 test set mcc of 0.22698984612511292 valid set mcc of 0.060778974111806904
# for fold 3 test set mcc of 0.4428746928746929 valid set mcc of 0.14161697239501866
# for fold 4 test set mcc of 0.3829268292682927 valid set mcc of 0.2360947844740331
# for fold 5 test set mcc of 0.33475926709278553 valid set mcc of 0.13386318071331377
#
# validation metrics of:
# positives in data 101
# negatives in data 103
# net accuracy = 0.6421568627450981
# mcc = 0.2844346146728079
# ========================================
# For dataset NR-ER_PaDEL.csv
# for fold 1 test set mcc of 0.4030923241028823 valid set mcc of 0.3891544543370621
# for fold 2 test set mcc of 0.2592981776093564 valid set mcc of 0.3298170315194588
# for fold 3 test set mcc of 0.2618700570981817 valid set mcc of 0.2767381680299383
# for fold 4 test set mcc of 0.38569163012594365 valid set mcc of 0.4187583593865018
# for fold 5 test set mcc of 0.4055514393921711 valid set mcc of 0.3127622519243806
#
# validation metrics of:
# positives in data 156
# negatives in data 210
# net accuracy = 0.6885245901639344
# mcc = 0.3513428121407796
# ========================================
# For dataset NR-aromatase_PaDEL.csv
# for fold 1 test set mcc of 0.3919647479510927 valid set mcc of 0.3512902125456798
# for fold 2 test set mcc of 0.3731486172347935 valid set mcc of 0.14917397079657826
# for fold 3 test set mcc of 0.43915343915343913 valid set mcc of 0.47491638795986624
# for fold 4 test set mcc of 0.37360090973062793 valid set mcc of 0.0723905723905724
# for fold 5 test set mcc of 0.5649019553110248 valid set mcc of 0.17407765595569782
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.768595041322314
# mcc = 0.5363984674329502
# ========================================
# For dataset Cardiotoxicity-5_PaDEL.csv
# for fold 1 test set mcc of 0.34826909711202975 valid set mcc of 0.37167988215859277
# for fold 2 test set mcc of 0.39908412799653115 valid set mcc of 0.35821528278699555
# for fold 3 test set mcc of 0.40802139037433155 valid set mcc of 0.30697624513552574
# for fold 4 test set mcc of 0.33342147012162876 valid set mcc of 0.2867581741591662
# for fold 5 test set mcc of 0.36408239230497424 valid set mcc of 0.23246007344087596
#
# validation metrics of:
# positives in data 143
# negatives in data 166
# net accuracy = 0.6634304207119741
# mcc = 0.3231106243154436
# ========================================
# For dataset SR-HSE_PaDEL.csv
# for fold 1 test set mcc of 0.2361111111111111 valid set mcc of 0.2560443903710958
# for fold 2 test set mcc of 0.48304589153964794 valid set mcc of 0.0
# for fold 3 test set mcc of 0.2692850423384597 valid set mcc of 0.12919146336922627
# for fold 4 test set mcc of 0.36363636363636365 valid set mcc of 0.1165103456070926
# for fold 5 test set mcc of 0.25 valid set mcc of 0.08058229640253803
#
# validation metrics of:
# positives in data 71
# negatives in data 79
# net accuracy = 0.6133333333333333
# mcc = 0.22435634578416394
# ========================================
# For dataset Cardiotoxicity-30_PaDEL.csv
# for fold 1 test set mcc of 0.57995833716615 valid set mcc of 0.29396490050880597
# for fold 2 test set mcc of 0.339182544372743 valid set mcc of 0.24942628966927255
# for fold 3 test set mcc of 0.23697366329197236 valid set mcc of 0.32272861188858776
# for fold 4 test set mcc of 0.35536966825016814 valid set mcc of 0.14149211999266964
# for fold 5 test set mcc of 0.559737561993242 valid set mcc of 0.4280227367832966
#
# validation metrics of:
# positives in data 85
# negatives in data 52
# net accuracy = 0.7518248175182481
# mcc = 0.4571130462814951
# ========================================
# For dataset SR-ATAD5_PaDEL.csv
# for fold 1 test set mcc of 0.4300756154038903 valid set mcc of 0.5262013605584339
# for fold 2 test set mcc of 0.19813880646508317 valid set mcc of 0.5296964548820617
# for fold 3 test set mcc of 0.644063802598921 valid set mcc of 0.3194444444444444
# for fold 4 test set mcc of 0.39402983543367903 valid set mcc of 0.36051834183722337
# for fold 5 test set mcc of 0.729080682761043 valid set mcc of 0.2854496128592251
#
# validation metrics of:
# positives in data 51
# negatives in data 52
# net accuracy = 0.6990291262135923
# mcc = 0.3979630611312895
# ========================================
# For dataset SR-MMP_PaDEL.csv
# for fold 1 test set mcc of 0.3933402473259827 valid set mcc of 0.20909706007720114
# for fold 2 test set mcc of 0.36514837167011077 valid set mcc of 0.3794957865067853
# for fold 3 test set mcc of 0.3584419049189969 valid set mcc of 0.25410506266458005
# for fold 4 test set mcc of 0.42336537115199285 valid set mcc of 0.29786630291791916
# for fold 5 test set mcc of 0.46529272903245766 valid set mcc of 0.34792803810136885
#
# validation metrics of:
# positives in data 178
# negatives in data 241
# net accuracy = 0.7326968973747017
# mcc = 0.4455215914051166

# %%
datasets[0]
# Out:
#       Toxicity_Value                                               Name  \
# 0                  0                               C#CC1(OC(N)=O)CCCCC1
# 1                  0              OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# 2                  1  FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F...
# 3                  0                                           OCC(O)CO
# 4                  1       O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# ...              ...                                                ...
# 2884               0  COc1cc(OC)c2oc3cc(OC)c(OC)c(OC4OC(OC5OCC(O)C(O...
# 2885               0  CC1(C)CCC2(C(=O)O)CCC3(C)C(=CCC4C5(C)CC(O)C(OC...
# 2886               0                                N=C(N)NCCN1CCCCCCC1
# 2887               0                             OC1C(O)C(O)C(O)C(O)C1O
# 2888               1                       N=C(N)NC(=O)c1nc(Cl)c(N)nc1N
#
#       nAcid   ALogP     ALogp2       AMR        apol  naAromAtom  nAromBond  \
# 0       0.0  0.0432   0.001866   36.4984   27.212309         0.0        0.0
# 1       0.0 -2.9402   8.644776   38.4036   24.707102         0.0        0.0
# 2       0.0  5.5463  30.761444   48.5205   26.599000         0.0        0.0
# 3       0.0 -1.4081   1.982746   20.5161   13.020344         0.0        0.0
# 4       0.0  2.0503   4.203730   28.5429   19.131965         0.0        0.0
# ...     ...     ...        ...       ...         ...         ...        ...
# 2884    0.0 -3.7051  13.727766   95.0445   81.689376         6.0        6.0
# 2885    0.0 -2.3663   5.599376  203.4950  130.228752         0.0        0.0
# 2886    0.0 -1.8499   3.422130   47.5045   36.669446         0.0        0.0
# 2887    0.0 -3.0642   9.389322   35.7750   23.373516         0.0        0.0
# 2888    0.0 -1.5591   2.430793   30.6876   26.576344         6.0        6.0
#
#       nAtom  ...       P1s       P2s       E1s       E2s       E3s         Ts  \
# 0      25.0  ...  0.544265  0.288326  0.379532  0.227411  0.477373   6.910318
# 1      26.0  ...  0.775604  0.160624  0.549165  0.469158  0.280565   8.040570
# 2      26.0  ...  0.827758  0.093458  0.551385  0.839105  0.727467  11.990690
# 3      14.0  ...  0.620621  0.250412  0.632803  0.524744  0.368019   3.660243
# 4      20.0  ...  0.772816  0.163920  0.527783  0.294689  0.402077   9.316639
# ...     ...  ...       ...       ...       ...       ...       ...        ...
# 2884   75.0  ...  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 2885  123.0  ...  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 2886   36.0  ...  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 2887   24.0  ...  0.497687  0.396409  0.597116  0.564741  0.348296   5.527263
# 2888   23.0  ...  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
#
#              As         Vs        Ks        Ds
# 0     14.149494  29.728772  0.316397  1.084316
# 1     11.914231  24.084743  0.663405  1.298889
# 2     21.557532  44.055494  0.741637  2.117957
# 3      3.587085   8.230182  0.430932  1.525566
# 4     16.139665  31.937263  0.659225  1.224549
# ...         ...        ...       ...       ...
# 2884   0.000000   0.000000  0.000000  0.000000
# 2885   0.000000   0.000000  0.000000  0.000000
# 2886   0.000000   0.000000  0.000000  0.000000
# 2887   8.920058  17.975450  0.341143  1.510153
# 2888   0.000000   0.000000  0.000000  0.000000
#
# [2889 rows x 1877 columns]

# %%
finalresults
# Out:
# [0.28773398077591283,
#  0.30460012749977394,
#  0.5670807236297686,
#  0.3986118512736629,
#  0.29711970815452493,
#  0.44005060438170496,
#  0.3352911848523585,
#  0.251259453814803,
#  0.4469870327993898,
#  0.2811893561157818,
#  0.28593358301364796,
#  0.38277695409216156,
#  0.05976143046671968,
#  0.39141202231490524,
#  0.2844346146728079,
#  0.3513428121407796,
#  0.5363984674329502,
#  0.3231106243154436,
#  0.22435634578416394,
#  0.4571130462814951,
#  0.3979630611312895,
#  0.4455215914051166]

# %%
temp = pd.DataFrame(finalresults, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Figure_Development/PaDEL/data/3D/padel_knn.csv')

# %%
resultframe
# Out:
#                                  Dataset       MCC
# 0            CarcinogenicityMorganfp.csv  0.300006
# 1                    morganfp_SR-p53.csv  0.392793
# 2                    morganfp_NR-AhR.csv  0.572339
# 3                 morganfp_NR-ER-LBD.csv  0.453839
# 4                  mutagenTTorsionfp.csv  0.514638
# 5             morganfp_NR-PPAR-gamma.csv  0.353500
# 6       Respiratory_ToxicityMorganfp.csv  0.421679
# 7                     mutagenMACCSfp.csv  0.614949
# 8    Reproductive_ToxicityTTorsionfp.csv  0.000000
# 9               CarcinogenicityAvafp.csv  0.269629
# 10         CarcinogenicityTTorsionfp.csv  0.337852
# 11            CarcinogenicityMACCSfp.csv  0.326857
# 12                    morganfp_NR-ER.csv  0.286975
# 13         Respiratory_ToxicityAvafp.csv  0.577049
# 14  Developmental_ToxicityTTorsionfp.csv  0.000000
# 15                 morganfp_SR-ATAD5.csv  0.337436
# 16    Developmental_ToxicityMorganfp.csv  0.035088
# 17                   mutagenMorganfp.csv  0.645710
# 18                      mutagenAvafp.csv  0.617388
# 19        Reproductive_ToxicityAvafp.csv  0.000000
# 20                   morganfp_SR-ARE.csv  0.359156
# 21       Developmental_ToxicityAvafp.csv  0.066396
# 22                    morganfp_NR-AR.csv  0.000000
# 23     Reproductive_ToxicityMorganfp.csv  0.000000
# 24     Developmental_ToxicityMACCSfp.csv  0.104713
# 25                   morganfp_SR-HSE.csv  0.309640
# 26                   morganfp_SR-MMP.csv  0.444228
# 27    Respiratory_ToxicityTTorsionfp.csv  0.449867
# 28       Respiratory_ToxicityMACCSfp.csv  0.491357
# 29             morganfp_NR-aromatase.csv  0.409273
# 30                morganfp_NR-AR-LBD.csv  0.607366
# 31      Reproductive_ToxicityMACCSfp.csv  0.202610

# %%
import os
import pandas as pd
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Padel/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

# %%
datasets[1]
# Out:
#       Toxicity_Value  nAcid   ALogP     ALogp2       AMR        apol  \
# 0                  0    0.0 -2.4371   5.939456   34.1807   20.039551
# 22                 1    0.0  4.0014  16.011202   43.4238   41.564758
# 33                 0    0.0  0.3494   0.122080   16.7967   29.250344
# 66                 0    0.0 -0.8075   0.652056   39.6471   49.714102
# 90                 1    0.0 -0.2952   0.087143   64.8328   48.247481
# ...              ...    ...     ...        ...       ...         ...
# 6269               1    0.0 -0.7769   0.603574   15.9147   37.474309
# 6270               0    0.0 -0.6722   0.451853   61.3223   63.497446
# 6282               1    0.0 -3.4627  11.990291  185.1441  128.750717
# 6303               0    0.0 -5.2280  27.331984   71.3748   68.005067
# 6304               1    0.0 -1.0077   1.015459   27.6579   40.290723
#
#       naAromAtom  nAromBond  nAtom  nHeavyAtom  ...        AMW      WTPT-1  \
# 0            0.0        0.0   19.0        12.0  ...   9.211803   23.026737
# 22          12.0       12.0   27.0        21.0  ...  14.957404   41.358336
# 33          11.0       11.0   25.0        17.0  ...   9.522665   33.919792
# 66          12.0       12.0   41.0        27.0  ...  10.269214   54.018524
# 90           6.0        6.0   41.0        24.0  ...   8.587106   48.337933
# ...          ...        ...    ...         ...  ...        ...         ...
# 6269        12.0       12.0   31.0        18.0  ...   7.776983   36.143595
# 6270        12.0       12.0   51.0        29.0  ...   8.394099   58.471448
# 6282         0.0        0.0  122.0        53.0  ...   6.143311  106.097356
# 6303        12.0       12.0   55.0        36.0  ...   9.655717   72.615360
# 6304        12.0       12.0   31.0        20.0  ...  10.709427   39.834351
#
#         WTPT-2     WTPT-3     WTPT-4     WTPT-5    WPATH   WPOL  XLogP  Zagreb
# 0     1.918895  15.370779  15.370779   0.000000    188.0   17.0 -0.178    58.0
# 22    1.969445  20.184704   5.072446   0.000000    860.0   38.0  3.768   110.0
# 33    1.995282  19.433820   2.414117  11.932677    537.0   23.0  0.821    86.0
# 66    2.000686  32.395517   9.793396   8.638308   1752.0   46.0  3.480   150.0
# 90    2.014081  19.320203  16.736492   0.000000   1137.0   50.0  0.911   132.0
# ...        ...        ...        ...        ...      ...    ...    ...     ...
# 6269  2.007977   7.893785   7.893785   0.000000    650.0   24.0  4.147    88.0
# 6270  2.016257  19.524183   9.950784   3.455758   2507.0   42.0  5.272   146.0
# 6282  2.001837  30.578223  30.578223   0.000000  11875.0  107.0  4.629   292.0
# 6303  2.017093  38.538093  19.623783  12.495163   4309.0   60.0  0.945   194.0
# 6304  1.991718  12.463358   7.375042   2.570194    830.0   30.0  3.203   100.0
#
# [365 rows x 1445 columns]
