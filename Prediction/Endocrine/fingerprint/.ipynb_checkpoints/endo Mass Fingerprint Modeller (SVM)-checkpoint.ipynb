# %%
#30/7/24 Creates a K fold KNN model for each file in a folder provided they are Fingerprints

import os
import pandas as pd
import numpy as np
import math
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Fingerprints/Endocrine/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df.drop(columns=['SMILES'], inplace=True)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
resultslist = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Values'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 4):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = mtry,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)


            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = bestmetrics,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)

        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    resultslist.append(results[12])
# Out:
# ========================================
# For dataset NR-AhRMACCSfp.csv
# for fold 1 test set mcc of 0.6557995716023093 valid set mcc of 0.5487436287421361
# for fold 2 test set mcc of 0.6158044629558921 valid set mcc of 0.5537714443208186
# for fold 3 test set mcc of 0.5981479673491854 valid set mcc of 0.5177907252376378
# for fold 4 test set mcc of 0.6587962962962963 valid set mcc of 0.5829537339804988
# for fold 5 test set mcc of 0.7302967433402214 valid set mcc of 0.6618585805502519
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.826865671641791
# mcc = 0.6489738401503108
# ========================================
# For dataset SR-MMPMACCSfp.csv
# for fold 1 test set mcc of 0.7507768411158209 valid set mcc of 0.5536247203513185
# for fold 2 test set mcc of 0.6321904444954543 valid set mcc of 0.6529677885713648
# for fold 3 test set mcc of 0.5784495923684765 valid set mcc of 0.5635918790978607
# for fold 4 test set mcc of 0.7378632681899948 valid set mcc of 0.6162506401498895
# for fold 5 test set mcc of 0.680517975697931 valid set mcc of 0.635601624934079
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7914691943127962
# mcc = 0.5760465348322249
# ========================================
# For dataset SR-AREAvafp.csv
# for fold 1 test set mcc of 0.5124376796278285 valid set mcc of 0.4807875238416249
# for fold 2 test set mcc of 0.48090781620769146 valid set mcc of 0.3108775298465349
# for fold 3 test set mcc of 0.3901073686509518 valid set mcc of 0.4517099656486265
# for fold 4 test set mcc of 0.315742656644419 valid set mcc of 0.46966760360471266
# for fold 5 test set mcc of 0.34345380351344046 valid set mcc of 0.2874986425606201
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.714622641509434
# mcc = 0.4111180676216692
# ========================================
# For dataset SR-HSEMorganfp.csv
# for fold 1 test set mcc of 0.31961465710466963 valid set mcc of 0.3083501537246893
# for fold 2 test set mcc of 0.30087815483526853 valid set mcc of 0.5272919760785556
# for fold 3 test set mcc of 0.5263199517127212 valid set mcc of 0.5530797881778003
# for fold 4 test set mcc of 0.40033353578260594 valid set mcc of 0.38122128787578263
# for fold 5 test set mcc of 0.5380945115300906 valid set mcc of 0.24571428571428572
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6907894736842105
# mcc = 0.38041092339753163
# ========================================
# For dataset NR-AhRTTorsionfp.csv
# for fold 1 test set mcc of 0.49063912815866306 valid set mcc of 0.42828771023776474
# for fold 2 test set mcc of 0.46575984990619135 valid set mcc of 0.4837282992317495
# for fold 3 test set mcc of 0.594380863414888 valid set mcc of 0.4757536722958662
# for fold 4 test set mcc of 0.6370460758082596 valid set mcc of 0.6222231129428143
# for fold 5 test set mcc of 0.6079365079365079 valid set mcc of 0.5778283952984204
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.7820895522388059
# mcc = 0.5562080306197227
# ========================================
# For dataset NR-PPAR-gammaAvafp.csv
# for fold 1 test set mcc of 0 valid set mcc of 0.3731012536223182
# for fold 2 test set mcc of 0.26891849420908714 valid set mcc of 0.30207927000959933
# for fold 3 test set mcc of 0.5508894960085645 valid set mcc of 0.6
# for fold 4 test set mcc of 0.4844813951249545 valid set mcc of 0.30207927000959933
# for fold 5 test set mcc of 0.24009801919951235 valid set mcc of 0.27754778174292477
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.7123287671232876
# mcc = 0.4275144419679629
# ========================================
# For dataset SR-p53MACCSfp.csv
# for fold 1 test set mcc of 0.4658468918976986 valid set mcc of 0.2491586046524587
# for fold 2 test set mcc of 0.39702853225495605 valid set mcc of 0.21726718565777636
# for fold 3 test set mcc of 0.47524179250002024 valid set mcc of 0.4384525375961447
# for fold 4 test set mcc of 0.6086177935592768 valid set mcc of 0.3578490074571519
# for fold 5 test set mcc of 0.4244373438135827 valid set mcc of 0.38933429041597706
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6764705882352942
# mcc = 0.35031363199652477
# ========================================
# For dataset NR-ER-LBDTTorsionfp.csv
# for fold 1 test set mcc of 0.3958771301467763 valid set mcc of 0.5305945608298307
# for fold 2 test set mcc of 0.5247368153167122 valid set mcc of 0.3731347888683499
# for fold 3 test set mcc of 0.40535891075800967 valid set mcc of 0.47390242621925555
# for fold 4 test set mcc of 0.5336538461538461 valid set mcc of 0.30861597282272785
# for fold 5 test set mcc of 0.5475708968190233 valid set mcc of 0.2464143038817129
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.6301369863013698
# mcc = 0.25870512438848814
# ========================================
# For dataset NR-PPAR-gammaTTorsionfp.csv
# for fold 1 test set mcc of 0.3860440160957241 valid set mcc of 0.5303300858899106
# for fold 2 test set mcc of 0.166742926870459 valid set mcc of 0.21821789023599236
# for fold 3 test set mcc of 0.20759971844307282 valid set mcc of 0.20180183819889375
# for fold 4 test set mcc of 0.37446543094704876 valid set mcc of 0.41349254254555623
# for fold 5 test set mcc of 0.5487954724560282 valid set mcc of 0.3161338044144022
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.6986301369863014
# mcc = 0.4178745439011128
# ========================================
# For dataset NR-AR-LBDAvafp.csv
# for fold 1 test set mcc of 0.6949822166446374 valid set mcc of 0.5464696078082152
# for fold 2 test set mcc of 0.5379289185083113 valid set mcc of 0.35087798113269913
# for fold 3 test set mcc of 0 valid set mcc of 0.3857583749052298
# for fold 4 test set mcc of 0.6153084570802658 valid set mcc of 0
# for fold 5 test set mcc of 0.6900721388834448 valid set mcc of 0.4268349027294209
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7291666666666666
# mcc = 0.4757475011684601
# ========================================
# For dataset NR-ER-LBDAvafp.csv
# for fold 1 test set mcc of 0.5285084312760371 valid set mcc of 0.5588199626086396
# for fold 2 test set mcc of 0.4706252173843803 valid set mcc of 0.49868262476599284
# for fold 3 test set mcc of 0.41884628049226685 valid set mcc of 0.47390242621925555
# for fold 4 test set mcc of 0.30861597282272785 valid set mcc of 0.34032507422130504
# for fold 5 test set mcc of 0.57186276940104 valid set mcc of 0.21889453648082105
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7123287671232876
# mcc = 0.4373789170951532
# ========================================
# For dataset SR-p53Avafp.csv
# for fold 1 test set mcc of 0.38071656446610136 valid set mcc of 0.3504094829253161
# for fold 2 test set mcc of 0.3760402398009496 valid set mcc of 0.3435830064841323
# for fold 3 test set mcc of 0.5594890746091223 valid set mcc of 0.3630067205194695
# for fold 4 test set mcc of 0.6849059214739163 valid set mcc of 0.34344361409879076
# for fold 5 test set mcc of 0.5873971250985845 valid set mcc of 0.45769615247608
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6705882352941176
# mcc = 0.34361410202722553
# ========================================
# For dataset NR-ERMorganfp.csv
# for fold 1 test set mcc of 0.3020047955773619 valid set mcc of 0.37591066617442503
# for fold 2 test set mcc of 0.3871040578953886 valid set mcc of 0.3400160011295003
# for fold 3 test set mcc of 0.4002715433620869 valid set mcc of 0.38319488484835124
# for fold 4 test set mcc of 0.2772219725115254 valid set mcc of 0.29884167511658744
# for fold 5 test set mcc of 0.47847133369733996 valid set mcc of 0.4786512960113325
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6929347826086957
# mcc = 0.360980546963335
# ========================================
# For dataset NR-aromataseMorganfp.csv
# for fold 1 test set mcc of 0.46694755428453877 valid set mcc of 0.48142508757077535
# for fold 2 test set mcc of 0.25304470070199 valid set mcc of 0.4153093381985166
# for fold 3 test set mcc of 0.7214317487579418 valid set mcc of 0.6619208318029215
# for fold 4 test set mcc of 0.4472135954999579 valid set mcc of 0.3098866597049237
# for fold 5 test set mcc of 0.4644039409141635 valid set mcc of 0.6581818181818182
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7768595041322314
# mcc = 0.5545779138333476
# ========================================
# For dataset NR-ARAvafp.csv
# for fold 1 test set mcc of 0.6929407109164757 valid set mcc of 0.38018014587802723
# for fold 2 test set mcc of 0.6082291325648282 valid set mcc of 0.5673665146135802
# for fold 3 test set mcc of 0.4193139346887674 valid set mcc of 0.5235175542131809
# for fold 4 test set mcc of 0.5537765319092597 valid set mcc of 0.30357629158881105
# for fold 5 test set mcc of 0.5830006053876384 valid set mcc of 0.4422689813358516
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.76
# mcc = 0.5515998041689789
# ========================================
# For dataset SR-AREMorganfp.csv
# for fold 1 test set mcc of 0.5012876446548541 valid set mcc of 0.487358735252068
# for fold 2 test set mcc of 0.46368541572137195 valid set mcc of 0.3872003967257013
# for fold 3 test set mcc of 0.39009474880274697 valid set mcc of 0.3936045483067371
# for fold 4 test set mcc of 0.39286394224759613 valid set mcc of 0.43381014769093557
# for fold 5 test set mcc of 0.43388413020882716 valid set mcc of 0.300582565025865
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7193396226415094
# mcc = 0.41851425113519997
# ========================================
# For dataset SR-p53TTorsionfp.csv
# for fold 1 test set mcc of 0.40585145885026774 valid set mcc of 0.17536875597932744
# for fold 2 test set mcc of 0.5540754699086263 valid set mcc of 0.25878179085145453
# for fold 3 test set mcc of 0.48012968482009577 valid set mcc of 0.39598696740852785
# for fold 4 test set mcc of 0.6988334233460395 valid set mcc of 0.2370942955749733
# for fold 5 test set mcc of 0.5700593993566241 valid set mcc of 0.4991154357965482
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6882352941176471
# mcc = 0.3798322278338627
# ========================================
# For dataset NR-ARMACCSfp.csv
# for fold 1 test set mcc of 0.5618006477335896 valid set mcc of 0.25423758993656337
# for fold 2 test set mcc of 0.6929407109164757 valid set mcc of 0.6180642325727469
# for fold 3 test set mcc of 0.5423695984263261 valid set mcc of 0.5618006477335896
# for fold 4 test set mcc of 0.4703764518024435 valid set mcc of 0.24251094575618398
# for fold 5 test set mcc of 0.5391800344720129 valid set mcc of 0.4136701519960153
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.736
# mcc = 0.4968030024467603
# ========================================
# For dataset SR-ATAD5Morganfp.csv
# for fold 1 test set mcc of 0.5893689584893059 valid set mcc of 0.5262013605584339
# for fold 2 test set mcc of 0.5095693779904307 valid set mcc of 0.2720637033616408
# for fold 3 test set mcc of 0.5038378351241242 valid set mcc of 0.6690386626313092
# for fold 4 test set mcc of 0.26745913993429266 valid set mcc of 0.5335783750799326
# for fold 5 test set mcc of 0.2033125151976111 valid set mcc of 0.4930493313022979
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7884615384615384
# mcc = 0.5775064742878283
# ========================================
# For dataset SR-p53Morganfp.csv
# for fold 1 test set mcc of 0.4310905281476511 valid set mcc of 0.4400457502263756
# for fold 2 test set mcc of 0.3247962274466209 valid set mcc of 0.3522537257978988
# for fold 3 test set mcc of 0.412096202564532 valid set mcc of 0.1027206926602045
# for fold 4 test set mcc of 0.5710896792935376 valid set mcc of 0.44715447154471544
# for fold 5 test set mcc of 0.5700593993566241 valid set mcc of 0.4806965115904965
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.7
# mcc = 0.4012427832875904
# ========================================
# For dataset NR-AR-LBDMACCSfp.csv
# for fold 1 test set mcc of 0.7385686213637485 valid set mcc of 0
# for fold 2 test set mcc of 0.477295345211795 valid set mcc of 0.29488391230979427
# for fold 3 test set mcc of 0.6546536707079772 valid set mcc of 0.2721794126179664
# for fold 4 test set mcc of 0.5955432118425306 valid set mcc of 0.37609021559644396
# for fold 5 test set mcc of 0.6428785635743144 valid set mcc of 0.5379289185083113
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7604166666666666
# mcc = 0.52819489242468
# ========================================
# For dataset NR-PPAR-gammaMACCSfp.csv
# for fold 1 test set mcc of 0.600099198148979 valid set mcc of 0.5232166435699436
# for fold 2 test set mcc of 0.4542199791661351 valid set mcc of 0.32732683535398854
# for fold 3 test set mcc of 0.4794833742895531 valid set mcc of 0.3333333333333333
# for fold 4 test set mcc of 0.4213324203089069 valid set mcc of 0.41349254254555623
# for fold 5 test set mcc of 0.31622776601683794 valid set mcc of 0.18499891602515212
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.726027397260274
# mcc = 0.45222086623314167
# ========================================
# For dataset NR-AR-LBDTTorsionfp.csv
# for fold 1 test set mcc of 0.5345820306956206 valid set mcc of 0.48122447405980645
# for fold 2 test set mcc of 0.6356048762998656 valid set mcc of 0.5846695269740967
# for fold 3 test set mcc of 0.610170215847752 valid set mcc of 0.49076687981751027
# for fold 4 test set mcc of 0.6153084570802658 valid set mcc of 0
# for fold 5 test set mcc of 0.6900721388834448 valid set mcc of 0.4893451639269458
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7604166666666666
# mcc = 0.5382727779055869
# ========================================
# For dataset NR-AR-LBDMorganfp.csv
# for fold 1 test set mcc of 0.710116428834481 valid set mcc of 0.5464696078082152
# for fold 2 test set mcc of 0.6958161056702072 valid set mcc of 0
# for fold 3 test set mcc of 0.6546536707079772 valid set mcc of 0.6086409915171404
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0.6900721388834448 valid set mcc of 0.5277790490704242
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.78125
# mcc = 0.5818429184443191
# ========================================
# For dataset NR-ERTTorsionfp.csv
# for fold 1 test set mcc of 0.39413219389143966 valid set mcc of 0.3254650490516791
# for fold 2 test set mcc of 0.28561934977401565 valid set mcc of 0.3548336407727115
# for fold 3 test set mcc of 0.3653078238295511 valid set mcc of 0.2550368526715523
# for fold 4 test set mcc of 0.31652061976424284 valid set mcc of 0.3178819766028755
# for fold 5 test set mcc of 0.34541066676088394 valid set mcc of 0.35162253307028496
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6902173913043478
# mcc = 0.3533285225013766
# ========================================
# For dataset SR-MMPTTorsionfp.csv
# for fold 1 test set mcc of 0.6211292742661544 valid set mcc of 0.5166228377841156
# for fold 2 test set mcc of 0.6216490953180368 valid set mcc of 0.5534623275537267
# for fold 3 test set mcc of 0.5429547183467229 valid set mcc of 0.550350964762303
# for fold 4 test set mcc of 0.7015859538778788 valid set mcc of 0.425
# for fold 5 test set mcc of 0.6495513335010573 valid set mcc of 0.554323591495114
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7914691943127962
# mcc = 0.5697954365297772
# ========================================
# For dataset NR-ARMorganfp.csv
# for fold 1 test set mcc of 0.6002099318605758 valid set mcc of 0.41306140597069063
# for fold 2 test set mcc of 0.5712060961522726 valid set mcc of 0.6333004963811236
# for fold 3 test set mcc of 0.5066710044155939 valid set mcc of 0.5862903896799836
# for fold 4 test set mcc of 0.5205674283520203 valid set mcc of 0.29569922175366314
# for fold 5 test set mcc of 0.5391800344720129 valid set mcc of 0
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.728
# mcc = 0.5045381731276043
# ========================================
# For dataset SR-HSEMACCSfp.csv
# for fold 1 test set mcc of 0.5178840884611257 valid set mcc of 0.29277002188455997
# for fold 2 test set mcc of 0.4474593028095495 valid set mcc of 0.7002255239802613
# for fold 3 test set mcc of 0.4415486789851282 valid set mcc of 0.6081811919603867
# for fold 4 test set mcc of 0.30844487625824785 valid set mcc of 0.4227235251262682
# for fold 5 test set mcc of 0.4599442350269685 valid set mcc of 0.3326121760930659
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6447368421052632
# mcc = 0.28772384072653456
# ========================================
# For dataset SR-ATAD5MACCSfp.csv
# for fold 1 test set mcc of 0.5961538461538461 valid set mcc of 0.42857142857142855
# for fold 2 test set mcc of 0.35950025121272106 valid set mcc of 0.2720637033616408
# for fold 3 test set mcc of 0.4005506475541372 valid set mcc of 0.41045042487741595
# for fold 4 test set mcc of 0.3262667427157852 valid set mcc of 0.40406101782088427
# for fold 5 test set mcc of 0.28735244660769566 valid set mcc of 0.6713171133426189
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7403846153846154
# mcc = 0.4836570552898968
# ========================================
# For dataset SR-ARETTorsionfp.csv
# for fold 1 test set mcc of 0.5124376796278285 valid set mcc of 0.38499525175450905
# for fold 2 test set mcc of 0.5271121985974822 valid set mcc of 0.4652568289913575
# for fold 3 test set mcc of 0.29277002188455997 valid set mcc of 0.36991724883426624
# for fold 4 test set mcc of 0.42031984228460867 valid set mcc of 0.4125991944224991
# for fold 5 test set mcc of 0.43366953679424136 valid set mcc of 0.2727547171322793
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.660377358490566
# mcc = 0.2907492244720892
# ========================================
# For dataset SR-ATAD5Avafp.csv
# for fold 1 test set mcc of 0.6085989058527203 valid set mcc of 0.38138503569823695
# for fold 2 test set mcc of 0.41113802341504757 valid set mcc of 0.12762257587800854
# for fold 3 test set mcc of 0.5196667888450939 valid set mcc of 0.2581988897471611
# for fold 4 test set mcc of 0.2591213417984878 valid set mcc of 0.4305283859114459
# for fold 5 test set mcc of 0.05723111976467626 valid set mcc of 0.38666666666666666
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7115384615384616
# mcc = 0.42442912588083087
# ========================================
# For dataset SR-AREMACCSfp.csv
# for fold 1 test set mcc of 0.4572358067571475 valid set mcc of 0.48029965226582394
# for fold 2 test set mcc of 0.40943506115317413 valid set mcc of 0.43427043787730374
# for fold 3 test set mcc of 0.39232849464507114 valid set mcc of 0.5067583033935739
# for fold 4 test set mcc of 0.39055960763167147 valid set mcc of 0.47479802762420287
# for fold 5 test set mcc of 0.4503137603732175 valid set mcc of 0.3772125939823055
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7075471698113207
# mcc = 0.3952000388814172
# ========================================
# For dataset NR-aromataseAvafp.csv
# for fold 1 test set mcc of 0.38731272671062317 valid set mcc of 0.42881613451059714
# for fold 2 test set mcc of 0.4232692231247351 valid set mcc of 0.46694755428453877
# for fold 3 test set mcc of 0.6672668106157719 valid set mcc of 0.5426085325608538
# for fold 4 test set mcc of 0.49913659061809706 valid set mcc of 0.35355339059327373
# for fold 5 test set mcc of 0.40398550724637683 valid set mcc of 0.5725011578657075
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7851239669421488
# mcc = 0.5745883153490607
# ========================================
# For dataset NR-PPAR-gammaMorganfp.csv
# for fold 1 test set mcc of 0.6804138174397717 valid set mcc of 0.6130060338328881
# for fold 2 test set mcc of 0.26891849420908714 valid set mcc of 0.3888888888888889
# for fold 3 test set mcc of 0.39573696328210756 valid set mcc of 0
# for fold 4 test set mcc of 0.3619137456499585 valid set mcc of 0.22171945701357465
# for fold 5 test set mcc of 0.4743416490252569 valid set mcc of 0.4241767985127718
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.726027397260274
# mcc = 0.46159787305178274
# ========================================
# For dataset NR-AhRMorganfp.csv
# for fold 1 test set mcc of 0.6892889335554799 valid set mcc of 0.4409077231272339
# for fold 2 test set mcc of 0.551015445038995 valid set mcc of 0.5048839721464334
# for fold 3 test set mcc of 0.6081385697683463 valid set mcc of 0.6957622169940441
# for fold 4 test set mcc of 0.6982390321941425 valid set mcc of 0.5778357190665774
# for fold 5 test set mcc of 0.6865236565629865 valid set mcc of 0.6439569789995535
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.8328358208955224
# mcc = 0.6603887227797506
# ========================================
# For dataset SR-MMPMorganfp.csv
# for fold 1 test set mcc of 0.6905993844120327 valid set mcc of 0.5045446148502305
# for fold 2 test set mcc of 0.548319641523525 valid set mcc of 0.5666453254629015
# for fold 3 test set mcc of 0.4687229150428678 valid set mcc of 0.5536703079206337
# for fold 4 test set mcc of 0.6311460486791397 valid set mcc of 0.4216370213557839
# for fold 5 test set mcc of 0.690679044975554 valid set mcc of 0.6724931642746674
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7843601895734598
# mcc = 0.5588983394823899
# ========================================
# For dataset NR-AhRAvafp.csv
# for fold 1 test set mcc of 0.685977161779064 valid set mcc of 0.4561862364790735
# for fold 2 test set mcc of 0.5914634146341463 valid set mcc of 0.4937347343378172
# for fold 3 test set mcc of 0.6397137338378576 valid set mcc of 0.6171428571428571
# for fold 4 test set mcc of 0.691999511687562 valid set mcc of 0.6975989317453373
# for fold 5 test set mcc of 0.6530185928422453 valid set mcc of 0.6980867617366788
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.844776119402985
# mcc = 0.6843146081974031
# ========================================
# For dataset NR-ER-LBDMorganfp.csv
# for fold 1 test set mcc of 0.5606060606060606 valid set mcc of 0.5383894762805824
# for fold 2 test set mcc of 0.4844813951249545 valid set mcc of 0
# for fold 3 test set mcc of 0.5080575455946181 valid set mcc of 0.5130434782608696
# for fold 4 test set mcc of 0.3779947574107829 valid set mcc of 0.4755624813414886
# for fold 5 test set mcc of 0.5026155365907202 valid set mcc of 0.30673732013152194
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7191780821917808
# mcc = 0.46270170053580656
# ========================================
# For dataset SR-HSEAvafp.csv
# for fold 1 test set mcc of 0.30087815483526853 valid set mcc of 0.2727428722967374
# for fold 2 test set mcc of 0.5678391358527431 valid set mcc of 0.46373626373626375
# for fold 3 test set mcc of 0.24892241379310345 valid set mcc of 0.4805296115423576
# for fold 4 test set mcc of 0.47587807481007366 valid set mcc of 0.5278234485917683
# for fold 5 test set mcc of 0.4472210669290514 valid set mcc of 0.35247760980938353
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6907894736842105
# mcc = 0.38041092339753163
# ========================================
# For dataset NR-ERAvafp.csv
# for fold 1 test set mcc of 0.2683949169273233 valid set mcc of 0.21398266546446335
# for fold 2 test set mcc of 0.2793045240898603 valid set mcc of 0.31001630357053045
# for fold 3 test set mcc of 0.3343999012234284 valid set mcc of 0.2736580053381785
# for fold 4 test set mcc of 0.338419883803869 valid set mcc of 0.318186300552335
# for fold 5 test set mcc of 0.31282475480231 valid set mcc of 0.43671629488422387
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6711956521739131
# mcc = 0.31071916168807684
# ========================================
# For dataset NR-ARTTorsionfp.csv
# for fold 1 test set mcc of 0.5974235104669887 valid set mcc of 0.37504578475079636
# for fold 2 test set mcc of 0.6082291325648282 valid set mcc of 0.600245047998781
# for fold 3 test set mcc of 0.4090172651337302 valid set mcc of 0.5235175542131809
# for fold 4 test set mcc of 0.5537765319092597 valid set mcc of 0.19218555339901838
# for fold 5 test set mcc of 0.5819358307200044 valid set mcc of 0
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.728
# mcc = 0.5045381731276043
# ========================================
# For dataset NR-aromataseTTorsionfp.csv
# for fold 1 test set mcc of 0.46911584571415993 valid set mcc of 0.4568413774141382
# for fold 2 test set mcc of 0.40931190049161525 valid set mcc of 0.5659258954891203
# for fold 3 test set mcc of 0.29488391230979427 valid set mcc of 0.6121670834108086
# for fold 4 test set mcc of 0.4074074074074074 valid set mcc of 0.5125215823282815
# for fold 5 test set mcc of 0.4078184960049932 valid set mcc of 0.5317613113292599
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.743801652892562
# mcc = 0.49117594088083466
# ========================================
# For dataset SR-HSETTorsionfp.csv
# for fold 1 test set mcc of 0.06318082788671024 valid set mcc of 0.2727428722967374
# for fold 2 test set mcc of 0.3123354539413192 valid set mcc of 0.24188272988967802
# for fold 3 test set mcc of 0.3720804971606606 valid set mcc of 0.4076632828893262
# for fold 4 test set mcc of 0.3668013525829027 valid set mcc of 0.46073950323568463
# for fold 5 test set mcc of 0.19725874207447544 valid set mcc of 0.0985031500635172
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6578947368421053
# mcc = 0.3139048072515881
# ========================================
# For dataset SR-MMPAvafp.csv
# for fold 1 test set mcc of 0.6442533144492408 valid set mcc of 0.5069938353868925
# for fold 2 test set mcc of 0.6576966872128501 valid set mcc of 0.6773347307441507
# for fold 3 test set mcc of 0.59544204852811 valid set mcc of 0.528291612390944
# for fold 4 test set mcc of 0.6991448175706009 valid set mcc of 0.5382918665200542
# for fold 5 test set mcc of 0.657974271830879 valid set mcc of 0.48413653375253796
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7748815165876777
# mcc = 0.5382015284992395
# ========================================
# For dataset SR-ATAD5TTorsionfp.csv
# for fold 1 test set mcc of 0.5408524452393346 valid set mcc of 0.38138503569823695
# for fold 2 test set mcc of 0.5126841617284027 valid set mcc of 0.2720637033616408
# for fold 3 test set mcc of 0.4806307859271526 valid set mcc of 0.3061862178478973
# for fold 4 test set mcc of 0.18988322962902904 valid set mcc of 0.4305283859114459
# for fold 5 test set mcc of 0.24333213169614382 valid set mcc of 0
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7115384615384616
# mcc = 0.42442912588083087
# ========================================
# For dataset NR-ER-LBDMACCSfp.csv
# for fold 1 test set mcc of 0.6111353196640859 valid set mcc of 0.49306167960817915
# for fold 2 test set mcc of 0.5569649872678669 valid set mcc of 0.42420801505049993
# for fold 3 test set mcc of 0.5745374140064684 valid set mcc of 0.4920615815501587
# for fold 4 test set mcc of 0.4055558216516248 valid set mcc of 0.4423076923076923
# for fold 5 test set mcc of 0.57186276940104 valid set mcc of 0.2834949882615359
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7123287671232876
# mcc = 0.4256477997707059
# ========================================
# For dataset NR-ERMACCSfp.csv
# for fold 1 test set mcc of 0.4842881427669486 valid set mcc of 0.4168699334603989
# for fold 2 test set mcc of 0.36001061358461217 valid set mcc of 0.3411183319962592
# for fold 3 test set mcc of 0.40134337725931823 valid set mcc of 0.29078044946149717
# for fold 4 test set mcc of 0.307431593917786 valid set mcc of 0.38871061168109244
# for fold 5 test set mcc of 0.4105824906780319 valid set mcc of 0.4643631700254545
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6739130434782609
# mcc = 0.3166807993523806
# ========================================
# For dataset NR-aromataseMACCSfp.csv
# for fold 1 test set mcc of 0.5666305975798628 valid set mcc of 0.51
# for fold 2 test set mcc of 0.5491495400993288 valid set mcc of 0.4313055684887501
# for fold 3 test set mcc of 0.5421374765483944 valid set mcc of 0.5516666666666666
# for fold 4 test set mcc of 0.5459486832355505 valid set mcc of 0.3919647479510927
# for fold 5 test set mcc of 0.4918338408540253 valid set mcc of 0.5727272727272728
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7520661157024794
# mcc = 0.5028800050111593

# %%
def setbalance(df):
    import pandas as pd
    import numpy as np
    #df = df.iloc[:,1:]
    toxvals = df['Toxicity_Values']

    zercount = 0
    for value in toxvals:
        if value == 0:
            zercount += 1

    poscount = len(toxvals)-zercount
    domval = 0

    if poscount > zercount:
        temp = poscount
        poscount = zercount
        poscount = temp
        domval = 1

    if poscount*4 < zercount:
        ratio = zercount / poscount
        factor = int(ratio) - 1

        loops = 0
        todel = []
        for value in toxvals:
            if loops % factor != 0 and value == domval:
                todel.append(loops)
            loops += 1

        df = df.drop(todel)
        
    return df

# %%
temp = pd.DataFrame(resultslist, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Data/Model_Outputs/Fingerprint/SVM_Fingerprint_Results')
