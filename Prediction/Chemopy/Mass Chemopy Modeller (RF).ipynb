# %%
#18/8/24 Creates a K fold RF model for chemopy data, a copy of the fingerprint one



import os
import pandas as pd
import numpy as np
import math
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Chemopy/datasets/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
finalresults = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 50):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = RandomForestClassifier(n_estimators=mtry, criterion='entropy', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                    max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                    verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)

            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = RandomForestClassifier(n_estimators=bestmetrics, criterion='entropy', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                    max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                    verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    finalresults.append(results[12])
    sets += 1
# Out:
# ========================================
# For dataset NR-ER_Chemopy.csv
# for fold 1 test set mcc of 0.5544438564695233 valid set mcc of 0.3052271750042236
# for fold 2 test set mcc of 0.35286853971326637 valid set mcc of 0.19009965237092094
# for fold 3 test set mcc of 0.43776776765761594 valid set mcc of 0.4291003792488758
# for fold 4 test set mcc of 0.4154119855855661 valid set mcc of 0.3276965172619955
# for fold 5 test set mcc of 0.42426760281746684 valid set mcc of 0.3933853611083057
#
# validation metrics of:
# positives in data 154
# negatives in data 209
# net accuracy = 0.7245179063360881
# mcc = 0.4277523419935659
# ========================================
# For dataset Developmental_Toxicity_Chemopy.csv
# for fold 1 test set mcc of 0 valid set mcc of 0.25
# for fold 2 test set mcc of 0 valid set mcc of 0.0
# for fold 3 test set mcc of 0 valid set mcc of 0.0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-aromatase_Chemopy.csv
# for fold 1 test set mcc of 0.4322654835582666 valid set mcc of 0.507606576998627
# for fold 2 test set mcc of 0.558389928096229 valid set mcc of 0.5025911034359737
# for fold 3 test set mcc of 0.6084656084656085 valid set mcc of 0.6761278203353551
# for fold 4 test set mcc of 0.5421374765483944 valid set mcc of 0.3557067007550456
# for fold 5 test set mcc of 0.7404795900698569 valid set mcc of 0.34815531191139565
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7851239669421488
# mcc = 0.5704130986882769
# ========================================
# For dataset SR-ATAD5_Chemopy.csv
# for fold 1 test set mcc of 0.5229763603684907 valid set mcc of 0.15328875514936824
# for fold 2 test set mcc of 0.6508140266182866 valid set mcc of 0.33249633682506924
# for fold 3 test set mcc of 0.68 valid set mcc of 0.7035264706814485
# for fold 4 test set mcc of 0.29621772025328 valid set mcc of 0.5680375574437545
# for fold 5 test set mcc of 0.6471421066338442 valid set mcc of 0.29292929292929293
#
# validation metrics of:
# positives in data 48
# negatives in data 52
# net accuracy = 0.76
# mcc = 0.5193656476805874
# ========================================
# For dataset SR-ARE_Chemopy.csv
# for fold 1 test set mcc of 0.5297019942218109 valid set mcc of 0.37360474869051474
# for fold 2 test set mcc of 0.6078057834013986 valid set mcc of 0.4519801350826027
# for fold 3 test set mcc of 0.5056809699596554 valid set mcc of 0.4118646339083779
# for fold 4 test set mcc of 0.528283827847772 valid set mcc of 0.5108340803071417
# for fold 5 test set mcc of 0.5587720507499664 valid set mcc of 0.5282804225676561
#
# validation metrics of:
# positives in data 175
# negatives in data 240
# net accuracy = 0.7108433734939759
# mcc = 0.4009971963710648
# ========================================
# For dataset SR-p53_Chemopy.csv
# for fold 1 test set mcc of 0.5262356074042633 valid set mcc of 0.3510216454424666
# for fold 2 test set mcc of 0.37136357696737443 valid set mcc of 0.011627925582571237
# for fold 3 test set mcc of 0.44641192917054984 valid set mcc of 0.22392991816084498
# for fold 4 test set mcc of 0.6302889101034144 valid set mcc of 0.5615580492529476
# for fold 5 test set mcc of 0.5607843137254902 valid set mcc of 0.505401342333075
#
# validation metrics of:
# positives in data 78
# negatives in data 88
# net accuracy = 0.7108433734939759
# mcc = 0.4217574776486372
# ========================================
# For dataset Cardiotoxicity-1_Chemopy.csv
# for fold 1 test set mcc of 0.46822799388406455 valid set mcc of 0.49929342052203435
# for fold 2 test set mcc of 0.46214796605085434 valid set mcc of 0.36327784859401147
# for fold 3 test set mcc of 0.5686835121310165 valid set mcc of 0.3965257928590721
# for fold 4 test set mcc of 0.3904085957987222 valid set mcc of 0.3463215415161186
# for fold 5 test set mcc of 0.4798622582560853 valid set mcc of 0.46513166560390873
#
# validation metrics of:
# positives in data 70
# negatives in data 240
# net accuracy = 0.8612903225806452
# mcc = 0.5626873454769584
# ========================================
# For dataset SR-HSE_Chemopy.csv
# for fold 1 test set mcc of 0.6468410147407356 valid set mcc of 0.22700461102727662
# for fold 2 test set mcc of 0.22816609348055633 valid set mcc of 0.2578004365829691
# for fold 3 test set mcc of 0.46330930891876604 valid set mcc of 0.40231648495856054
# for fold 4 test set mcc of 0.4331614421127332 valid set mcc of 0.356490077507127
# for fold 5 test set mcc of 0.578949230798827 valid set mcc of 0.12171612389003691
#
# validation metrics of:
# positives in data 67
# negatives in data 79
# net accuracy = 0.7191780821917808
# mcc = 0.4352177488656908
# ========================================
# For dataset Respiratory_Toxicity_Chemopy.csv
# for fold 1 test set mcc of 0.714897343211129 valid set mcc of 0.3934890254040881
# for fold 2 test set mcc of 0.49659101342415307 valid set mcc of 0.5973653665554882
# for fold 3 test set mcc of 0.6022938538200732 valid set mcc of 0.419391976325297
# for fold 4 test set mcc of 0.44328906859504436 valid set mcc of 0.545234602194383
# for fold 5 test set mcc of 0.5691789568838166 valid set mcc of 0.507330932619818
#
# validation metrics of:
# positives in data 161
# negatives in data 106
# net accuracy = 0.7865168539325843
# mcc = 0.550920217377371
# ========================================
# For dataset Carcinogenicity_Chemopy.csv
# for fold 1 test set mcc of 0.39129279043561477 valid set mcc of 0.2844525113371463
# for fold 2 test set mcc of 0.2729520365538821 valid set mcc of 0.24390258447372082
# for fold 3 test set mcc of 0.5006696431572245 valid set mcc of 0.2892346639593178
# for fold 4 test set mcc of 0.46458086638244267 valid set mcc of 0.20836123787759392
# for fold 5 test set mcc of 0.47041977931660633 valid set mcc of 0.576556660197055
#
# validation metrics of:
# positives in data 101
# negatives in data 103
# net accuracy = 0.6372549019607843
# mcc = 0.28343235895976254
# ========================================
# For dataset Cardiotoxicity-30_Chemopy.csv
# for fold 1 test set mcc of 0.6169526972391244 valid set mcc of 0.4666666666666667
# for fold 2 test set mcc of 0.40217391304347827 valid set mcc of 0.35526486051678746
# for fold 3 test set mcc of 0.40217391304347827 valid set mcc of 0.31429531333887006
# for fold 4 test set mcc of 0.6469387498951914 valid set mcc of 0.4587596979470412
# for fold 5 test set mcc of 0.5025129006975967 valid set mcc of 0.4041119295602435
#
# validation metrics of:
# positives in data 85
# negatives in data 53
# net accuracy = 0.7318840579710145
# mcc = 0.4313274102991624
# ========================================
# For dataset Cardiotoxicity-10_Chemopy.csv
# for fold 1 test set mcc of 0.45769436216330667 valid set mcc of 0.3203070968580258
# for fold 2 test set mcc of 0.5104863301909712 valid set mcc of 0.2816076829909289
# for fold 3 test set mcc of 0.45059153736639335 valid set mcc of 0.44025390587365365
# for fold 4 test set mcc of 0.5121224789687381 valid set mcc of 0.394643849651321
# for fold 5 test set mcc of 0.48964337663305935 valid set mcc of 0.3037165918033213
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.7387096774193549
# mcc = 0.43355498476206
# ========================================
# For dataset Cardiotoxicity-5_Chemopy.csv
# for fold 1 test set mcc of 0.4314486955449336 valid set mcc of 0.3754485372729465
# for fold 2 test set mcc of 0.661343579583779 valid set mcc of 0.4872082067904173
# for fold 3 test set mcc of 0.42123561267421306 valid set mcc of 0.4775994561305514
# for fold 4 test set mcc of 0.4045434552364592 valid set mcc of 0.41968532778808815
# for fold 5 test set mcc of 0.45225054688981425 valid set mcc of 0.4100018139538832
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.7483870967741936
# mcc = 0.4922314529301567
# ========================================
# For dataset NR-AR-LBD_Chemopy.csv
# for fold 1 test set mcc of 0.6898644619872631 valid set mcc of 0.5774657738960309
# for fold 2 test set mcc of 0.6935629705999945 valid set mcc of 0.41349254254555623
# for fold 3 test set mcc of 0.6696428571428571 valid set mcc of 0.572733256644269
# for fold 4 test set mcc of 0.7382129472480629 valid set mcc of 0.5085286605506111
# for fold 5 test set mcc of 0.5530100413375021 valid set mcc of 0.6202638734661827
#
# validation metrics of:
# positives in data 45
# negatives in data 49
# net accuracy = 0.7553191489361702
# mcc = 0.5316947973422216
# ========================================
# For dataset Ames_Mutagenicity_Chemopy.csv
# for fold 1 test set mcc of 0.683847970598678 valid set mcc of 0.6377752589459977
# for fold 2 test set mcc of 0.6308899719970773 valid set mcc of 0.6464629492789153
# for fold 3 test set mcc of 0.6421868463725344 valid set mcc of 0.6877582882060621
# for fold 4 test set mcc of 0.6859767635798173 valid set mcc of 0.6308359017106373
# for fold 5 test set mcc of 0.6490713996780497 valid set mcc of 0.5867106854580441
#
# validation metrics of:
# positives in data 840
# negatives in data 657
# net accuracy = 0.8396793587174348
# mcc = 0.6737881829840559
# ========================================
# For dataset Hepatotoxicity_Chemopy.csv
# for fold 1 test set mcc of 0.49749371855331 valid set mcc of 0.48146059391074914
# for fold 2 test set mcc of 0.4797297297297297 valid set mcc of 0.4198833387524375
# for fold 3 test set mcc of 0.4742231080640093 valid set mcc of 0.342365813592057
# for fold 4 test set mcc of 0.5648606431210795 valid set mcc of 0.49962475983074545
# for fold 5 test set mcc of 0.5812604981459968 valid set mcc of 0.49465900343674296
#
# validation metrics of:
# positives in data 293
# negatives in data 284
# net accuracy = 0.7521663778162911
# mcc = 0.5048008982645841
# ========================================
# For dataset NR-AR_Chemopy.csv
# for fold 1 test set mcc of 0.7027494842451595 valid set mcc of 0.1923885343897275
# for fold 2 test set mcc of 0.5256875053398457 valid set mcc of 0.5572196888072013
# for fold 3 test set mcc of 0.6082291325648282 valid set mcc of 0.4935249645415257
# for fold 4 test set mcc of 0.5250160815129379 valid set mcc of 0
# for fold 5 test set mcc of 0.5695970695970696 valid set mcc of 0.4
#
# validation metrics of:
# positives in data 60
# negatives in data 64
# net accuracy = 0.7580645161290323
# mcc = 0.5298488653151553
# ========================================
# For dataset Reproductive_Toxicity_Chemopy.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 5
# negatives in data 4
# net accuracy = 0.5555555555555556
# mcc = 0.05976143046671968
# ========================================
# For dataset NR-ER-LBD_Chemopy.csv
# for fold 1 test set mcc of 0.5392316586011221 valid set mcc of 0.6142709857998429
# for fold 2 test set mcc of 0.5097970656333187 valid set mcc of 0.3835643206677728
# for fold 3 test set mcc of 0.7879948914431673 valid set mcc of 0.34398976982097185
# for fold 4 test set mcc of 0.6310935441370223 valid set mcc of 0.22938830018319592
# for fold 5 test set mcc of 0.5499719409228703 valid set mcc of 0.4260242630921053
#
# validation metrics of:
# positives in data 66
# negatives in data 75
# net accuracy = 0.7588652482269503
# mcc = 0.5202356055210243
# ========================================
# For dataset NR-PPAR-gamma_Chemopy.csv
# for fold 1 test set mcc of 0.5017348819226064 valid set mcc of 0.18045073225950925
# for fold 2 test set mcc of 0.5708058152826189 valid set mcc of 0.13091876497307772
# for fold 3 test set mcc of 0.35805743701971643 valid set mcc of 0.25819888974716115
# for fold 4 test set mcc of 0.3858604196329899 valid set mcc of 0.36563621206356534
# for fold 5 test set mcc of 0.6601307189542484 valid set mcc of 0.49019607843137253
#
# validation metrics of:
# positives in data 33
# negatives in data 37
# net accuracy = 0.7857142857142857
# mcc = 0.5700338366611012
# ========================================
# For dataset NR-AhR_Chemopy.csv
# for fold 1 test set mcc of 0.6873010471583634 valid set mcc of 0.5300253000077804
# for fold 2 test set mcc of 0.6530185928422453 valid set mcc of 0.537440770812681
# for fold 3 test set mcc of 0.6111799621602831 valid set mcc of 0.5033502667650954
# for fold 4 test set mcc of 0.6135802443474231 valid set mcc of 0.4951481635009064
# for fold 5 test set mcc of 0.5529673894486816 valid set mcc of 0.5203682480917688
#
# validation metrics of:
# positives in data 148
# negatives in data 185
# net accuracy = 0.8078078078078078
# mcc = 0.6120399536911125
# ========================================
# For dataset SR-MMP_Chemopy.csv
# for fold 1 test set mcc of 0.650206829270671 valid set mcc of 0.6100555349241479
# for fold 2 test set mcc of 0.6879260642117019 valid set mcc of 0.7709408427236905
# for fold 3 test set mcc of 0.6505707258696386 valid set mcc of 0.6694704498573427
# for fold 4 test set mcc of 0.717938094006544 valid set mcc of 0.5282413713698413
# for fold 5 test set mcc of 0.7623269774501799 valid set mcc of 0.6866941169241324
#
# validation metrics of:
# positives in data 176
# negatives in data 239
# net accuracy = 0.8144578313253013
# mcc = 0.6182026210054122

# %%
len(finalresults)
# Out:
# 88

# %%
temp = pd.DataFrame(finalresults, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Model_Outputs/RF_Fingerprint_Results.csv')
