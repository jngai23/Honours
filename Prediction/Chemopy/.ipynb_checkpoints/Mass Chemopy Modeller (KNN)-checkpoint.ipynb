# %%
#23/8/24 Creates a K fold KNN model for each file in a folder provided they are chemopy

import os
import pandas as pd
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Chemopy/datasets/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
finalresults = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        
        length = len(xtrain)
        nneigh = 100
        if length < nneigh:
            nneigh = length
        for mtry in range(1, nneigh):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = KNeighborsClassifier(n_neighbors=mtry, weights='distance', 
                            algorithm='auto', leaf_size=100, p=2, metric='minkowski', 
                            metric_params=None, n_jobs=4)

            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = KNeighborsClassifier(n_neighbors=bestmetrics, weights='distance', 
                            algorithm='auto', leaf_size=100, p=2, metric='minkowski', 
                            metric_params=None, n_jobs=4)
        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    finalresults.append(results[12])
# Out:
# ========================================
# For dataset NR-ER_Chemopy.csv
# for fold 1 test set mcc of 0.5080553524011281 valid set mcc of 0.37707874867825847
# for fold 2 test set mcc of 0.3357554274319713 valid set mcc of 0.3027688849089313
# for fold 3 test set mcc of 0.3140747205739492 valid set mcc of 0.32672855120877364
# for fold 4 test set mcc of 0.43164207000260835 valid set mcc of 0.25804189473943945
# for fold 5 test set mcc of 0.3594425845307718 valid set mcc of 0.3936422464836486
#
# validation metrics of:
# positives in data 154
# negatives in data 209
# net accuracy = 0.7052341597796143
# mcc = 0.39166046248198466
# ========================================
# For dataset Developmental_Toxicity_Chemopy.csv
# for fold 1 test set mcc of 0.3333333333333333 valid set mcc of 0
# for fold 2 test set mcc of 0.16666666666666666 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0.0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 8
# negatives in data 6
# net accuracy = 0.42857142857142855
# mcc = -0.16666666666666666
# ========================================
# For dataset NR-aromatase_Chemopy.csv
# for fold 1 test set mcc of 0.2661399251711681 valid set mcc of 0.3860443241498841
# for fold 2 test set mcc of 0.4965034965034965 valid set mcc of 0.3983623083772261
# for fold 3 test set mcc of 0.4562184572445113 valid set mcc of 0.46911584571415993
# for fold 4 test set mcc of 0.5880554401268867 valid set mcc of 0.37902349574330746
# for fold 5 test set mcc of 0.6047916118572527 valid set mcc of 0.4810606060606061
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7520661157024794
# mcc = 0.5057440581688349
# ========================================
# For dataset SR-ATAD5_Chemopy.csv
# for fold 1 test set mcc of 0.42163702135578396 valid set mcc of 0.1617636294710456
# for fold 2 test set mcc of 0.5680375574437545 valid set mcc of 0.2335496832484569
# for fold 3 test set mcc of 0.6487491201346025 valid set mcc of 0.450563556889583
# for fold 4 test set mcc of 0.450563556889583 valid set mcc of 0.44114940169152966
# for fold 5 test set mcc of 0.6043558516497883 valid set mcc of 0.3710367131802156
#
# validation metrics of:
# positives in data 48
# negatives in data 52
# net accuracy = 0.68
# mcc = 0.358974358974359
# ========================================
# For dataset SR-ARE_Chemopy.csv
# for fold 1 test set mcc of 0.4115209955525529 valid set mcc of 0.313633895024948
# for fold 2 test set mcc of 0.569778183870016 valid set mcc of 0.23085674405117784
# for fold 3 test set mcc of 0.42149975877816986 valid set mcc of 0.31267710017741834
# for fold 4 test set mcc of 0.4800586836282502 valid set mcc of 0.42465871845405584
# for fold 5 test set mcc of 0.5006619107916614 valid set mcc of 0.39759027652381645
#
# validation metrics of:
# positives in data 175
# negatives in data 240
# net accuracy = 0.6867469879518072
# mcc = 0.3500925498464577
# ========================================
# For dataset SR-p53_Chemopy.csv
# for fold 1 test set mcc of 0.4327988156347182 valid set mcc of 0.46291497908108387
# for fold 2 test set mcc of 0.537328395407574 valid set mcc of 0.25134208374634753
# for fold 3 test set mcc of 0.37855476143881317 valid set mcc of 0.46291497908108387
# for fold 4 test set mcc of 0.5934602951767031 valid set mcc of 0.4844461958650483
# for fold 5 test set mcc of 0.5636018619766345 valid set mcc of 0.3505757849137574
#
# validation metrics of:
# positives in data 78
# negatives in data 88
# net accuracy = 0.7469879518072289
# mcc = 0.4915360719507396
# ========================================
# For dataset Cardiotoxicity-1_Chemopy.csv
# for fold 1 test set mcc of 0.49236596391733095 valid set mcc of 0.3613991691739721
# for fold 2 test set mcc of 0.4393106328077838 valid set mcc of 0.3092843110843075
# for fold 3 test set mcc of 0.5041157597966586 valid set mcc of 0.48010528983194795
# for fold 4 test set mcc of 0.3454630793579261 valid set mcc of 0.1949283979835804
# for fold 5 test set mcc of 0.4583816021105377 valid set mcc of 0.5172096161490397
#
# validation metrics of:
# positives in data 70
# negatives in data 240
# net accuracy = 0.8451612903225807
# mcc = 0.5152949810689438
# ========================================
# For dataset SR-HSE_Chemopy.csv
# for fold 1 test set mcc of 0.5234813066655082 valid set mcc of 0.19307819491773812
# for fold 2 test set mcc of 0.3466876226407682 valid set mcc of 0.23422351277998318
# for fold 3 test set mcc of 0.33258447906904054 valid set mcc of 0.423466849232862
# for fold 4 test set mcc of 0.40399422535529517 valid set mcc of 0.29351150176141827
# for fold 5 test set mcc of 0.500825961100672 valid set mcc of 0.1853123291652753
#
# validation metrics of:
# positives in data 67
# negatives in data 79
# net accuracy = 0.6506849315068494
# mcc = 0.2916707789196351
# ========================================
# For dataset Respiratory_Toxicity_Chemopy.csv
# for fold 1 test set mcc of 0.47999925238284696 valid set mcc of 0.2587276657423794
# for fold 2 test set mcc of 0.5214897180926453 valid set mcc of 0.4804854662346365
# for fold 3 test set mcc of 0.44026885731787874 valid set mcc of 0.3415516615519982
# for fold 4 test set mcc of 0.49968672939341796 valid set mcc of 0.47760728958628507
# for fold 5 test set mcc of 0.5892556509887895 valid set mcc of 0.40294944645464786
#
# validation metrics of:
# positives in data 161
# negatives in data 106
# net accuracy = 0.7602996254681648
# mcc = 0.4950240465278337
# ========================================
# For dataset Carcinogenicity_Chemopy.csv
# for fold 1 test set mcc of 0.29277002188455997 valid set mcc of 0.1389159685118722
# for fold 2 test set mcc of 0.2633958372214643 valid set mcc of 0.4968696334292462
# for fold 3 test set mcc of 0.4072611276428169 valid set mcc of 0.22422642623728006
# for fold 4 test set mcc of 0.40817579287356776 valid set mcc of 0.18199273790667697
# for fold 5 test set mcc of 0.4150834734729253 valid set mcc of 0.21049424296170535
#
# validation metrics of:
# positives in data 101
# negatives in data 103
# net accuracy = 0.6029411764705882
# mcc = 0.20567166072395598
# ========================================
# For dataset Cardiotoxicity-30_Chemopy.csv
# for fold 1 test set mcc of 0.47062521738438035 valid set mcc of 0.3797880669767327
# for fold 2 test set mcc of 0.5120333785422198 valid set mcc of 0.325166238571545
# for fold 3 test set mcc of 0.327445652173913 valid set mcc of 0.34149279673113603
# for fold 4 test set mcc of 0.5301696010973056 valid set mcc of 0.3333333333333333
# for fold 5 test set mcc of 0.5171156399255817 valid set mcc of 0.24566635507539325
#
# validation metrics of:
# positives in data 85
# negatives in data 53
# net accuracy = 0.6811594202898551
# mcc = 0.30884007484435444
# ========================================
# For dataset Cardiotoxicity-10_Chemopy.csv
# for fold 1 test set mcc of 0.41839855974472434 valid set mcc of 0.24541398451145194
# for fold 2 test set mcc of 0.5792028131754016 valid set mcc of 0.33335033970222955
# for fold 3 test set mcc of 0.40639835961540033 valid set mcc of 0.2990106267380258
# for fold 4 test set mcc of 0.5513737861380256 valid set mcc of 0.4086922324569841
# for fold 5 test set mcc of 0.4116766373766351 valid set mcc of 0.24363711485330747
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.7
# mcc = 0.346843987809648
# ========================================
# For dataset Cardiotoxicity-5_Chemopy.csv
# for fold 1 test set mcc of 0.36105073700264934 valid set mcc of 0.4593278240702394
# for fold 2 test set mcc of 0.549098387177294 valid set mcc of 0.35310428305676195
# for fold 3 test set mcc of 0.5219396252899683 valid set mcc of 0.31676970141970084
# for fold 4 test set mcc of 0.3565120479536904 valid set mcc of 0.43536254969533006
# for fold 5 test set mcc of 0.45409839408454516 valid set mcc of 0.34349600148869813
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.7290322580645161
# mcc = 0.453008142911731
# ========================================
# For dataset NR-AR-LBD_Chemopy.csv
# for fold 1 test set mcc of 0.7034432081838871 valid set mcc of 0.5529051454108082
# for fold 2 test set mcc of 0.6803548316418606 valid set mcc of 0.46678977660158144
# for fold 3 test set mcc of 0.6771863474748655 valid set mcc of 0.4845437118523489
# for fold 4 test set mcc of 0.6900721388834448 valid set mcc of 0.5085286605506111
# for fold 5 test set mcc of 0.6080052052987127 valid set mcc of 0.6625413488689132
#
# validation metrics of:
# positives in data 45
# negatives in data 49
# net accuracy = 0.723404255319149
# mcc = 0.45518969634282813
# ========================================
# For dataset Ames_Mutagenicity_Chemopy.csv
# for fold 1 test set mcc of 0.6273377055346614 valid set mcc of 0.5428103436529548
# for fold 2 test set mcc of 0.5659344234092826 valid set mcc of 0.4922365450212216
# for fold 3 test set mcc of 0.5530656357190423 valid set mcc of 0.6118159571255593
# for fold 4 test set mcc of 0.6121976439855634 valid set mcc of 0.5216302253246087
# for fold 5 test set mcc of 0.5784940083066806 valid set mcc of 0.5215995897786221
#
# validation metrics of:
# positives in data 840
# negatives in data 657
# net accuracy = 0.7969271877087508
# mcc = 0.5856171905444313
# ========================================
# For dataset Hepatotoxicity_Chemopy.csv
# for fold 1 test set mcc of 0.40095930561862864 valid set mcc of 0.36570551902088977
# for fold 2 test set mcc of 0.46634212223964394 valid set mcc of 0.28944959876782234
# for fold 3 test set mcc of 0.4228696273168689 valid set mcc of 0.4489648657659725
# for fold 4 test set mcc of 0.4998900391094172 valid set mcc of 0.3882464347777672
# for fold 5 test set mcc of 0.46170151429586137 valid set mcc of 0.5450123154819636
#
# validation metrics of:
# positives in data 293
# negatives in data 284
# net accuracy = 0.7400346620450606
# mcc = 0.48202742794382303
# ========================================
# For dataset NR-AR_Chemopy.csv
# for fold 1 test set mcc of 0.6210344279375828 valid set mcc of 0.4543694673976518
# for fold 2 test set mcc of 0.5674250444370365 valid set mcc of 0.4787162492387211
# for fold 3 test set mcc of 0.5590377675673656 valid set mcc of 0.3180732125814321
# for fold 4 test set mcc of 0.5250160815129379 valid set mcc of 0.5
# for fold 5 test set mcc of 0.7417582417582418 valid set mcc of 0.6643482831758064
#
# validation metrics of:
# positives in data 60
# negatives in data 64
# net accuracy = 0.7338709677419355
# mcc = 0.46732966267336906
# ========================================
# For dataset Reproductive_Toxicity_Chemopy.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-ER-LBD_Chemopy.csv
# for fold 1 test set mcc of 0.6422666065287005 valid set mcc of 0.4825811562050755
# for fold 2 test set mcc of 0.3808871733376949 valid set mcc of 0.5255329328629874
# for fold 3 test set mcc of 0.6116454004970334 valid set mcc of 0.27893761836967207
# for fold 4 test set mcc of 0.5588564482153123 valid set mcc of 0.306697048856629
# for fold 5 test set mcc of 0.5698028822981898 valid set mcc of 0.4913717616152507
#
# validation metrics of:
# positives in data 66
# negatives in data 75
# net accuracy = 0.7021276595744681
# mcc = 0.40306677267717433
# ========================================
# For dataset NR-PPAR-gamma_Chemopy.csv
# for fold 1 test set mcc of 0.4687501237868722 valid set mcc of 0.47079190906919977
# for fold 2 test set mcc of 0.7174348320524659 valid set mcc of 0.2119213177352503
# for fold 3 test set mcc of 0.5794871794871795 valid set mcc of 0.3949827793858816
# for fold 4 test set mcc of 0.4873877907780315 valid set mcc of 0.4555973021063105
# for fold 5 test set mcc of 0.5880064914496507 valid set mcc of 0.18712029714127992
#
# validation metrics of:
# positives in data 33
# negatives in data 37
# net accuracy = 0.6714285714285714
# mcc = 0.3397627175758013
# ========================================
# For dataset NR-AhR_Chemopy.csv
# for fold 1 test set mcc of 0.5877487145092779 valid set mcc of 0.5674021702591452
# for fold 2 test set mcc of 0.6503552809644588 valid set mcc of 0.4651491247330196
# for fold 3 test set mcc of 0.577563613507226 valid set mcc of 0.5030977512363758
# for fold 4 test set mcc of 0.6671734352185916 valid set mcc of 0.4981167541368988
# for fold 5 test set mcc of 0.5528686581318161 valid set mcc of 0.5858021811736859
#
# validation metrics of:
# positives in data 148
# negatives in data 185
# net accuracy = 0.7357357357357357
# mcc = 0.4799323580619452
# ========================================
# For dataset SR-MMP_Chemopy.csv
# for fold 1 test set mcc of 0.5402423454162114 valid set mcc of 0.5221671852535996
# for fold 2 test set mcc of 0.5955432674862072 valid set mcc of 0.5423261445466404
# for fold 3 test set mcc of 0.5240469711754625 valid set mcc of 0.403912278969798
# for fold 4 test set mcc of 0.6118365807204242 valid set mcc of 0.4530090506608791
# for fold 5 test set mcc of 0.6918874350625416 valid set mcc of 0.6336574389585725
#
# validation metrics of:
# positives in data 176
# negatives in data 239
# net accuracy = 0.7783132530120482
# mcc = 0.5468729769329064

# %%
#23/8/24 Creates a K fold KNN model for each file in a folder provided they are chemopy

import os
import pandas as pd
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Chemopy/datasets/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

# %%
datasets[10]
# Out:
#       Toxicity_Value   Weight  nH  nHal  nHet  nHA  nF  nCl  nBr  nI  ...  \
# 0                  1  148.150   4     0     5   10   0    0    0   0  ...
# 1                  0  392.198  16     6    16   28   6    0    0   0  ...
# 2                  0  249.040   7     2     9   16   0    2    0   0  ...
# 3                  1  388.264  21     2    24   30   2    0    0   0  ...
# 6                  1  342.253  27     0    20   27   0    0    0   0  ...
# ...              ...      ...  ..   ...   ...  ...  ..  ...  ...  ..  ...
# 1536               0  394.289  22     0    22   31   0    0    0   0  ...
# 1539               1  352.272  21     0    21   28   0    0    0   0  ...
# 1542               1  362.287  24     0    23   29   0    0    0   0  ...
# 1543               0  439.753  27     1    25   33   0    1    0   0  ...
# 1545               1  403.311  29     1    26   32   1    0    0   0  ...
#
#       VSAEstate0  VSAEstate1  VSAEstate2  VSAEstate3  VSAEstate4  VSAEstate5  \
# 0       0.547454   13.559583    0.000000    1.539352    0.000000    0.000000
# 1      79.365588   13.706120    6.623437    3.618548   -4.964313    0.501815
# 2       0.000000    3.800942    8.238624   11.965103    0.176914    5.134145
# 3      26.426309   14.554939   20.051051    2.034770   -1.100900   17.734904
# 6       7.947111   11.418944   15.242677    2.061951    1.967681    6.377731
# ...          ...         ...         ...         ...         ...         ...
# 1536    2.010483   34.894734   10.864036    8.679544   -0.497035   12.393945
# 1539    2.081292   22.837983   11.005589    3.737749    0.142924   13.350220
# 1542    2.126948   18.888857   11.077501    3.931990    0.196565   19.636096
# 1543    2.116340   26.333584   15.836239    3.421882   -0.736528   12.776628
# 1545   15.162470   21.379596    0.000000    5.203739    0.029218   13.726178
#
#       VSAEstate6  VSAEstate7  VSAEstate8  VSAEstate9
# 0       3.115231    0.000000         0.0    4.905046
# 1      -4.874915   -0.226280         0.0    0.000000
# 2       0.000000    0.000000         0.0   11.906493
# 3      -0.034407    0.000000         0.0    0.000000
# 6      10.473845    0.676726         0.0    0.000000
# ...          ...         ...         ...         ...
# 1536    5.612816    1.541477         0.0    0.000000
# 1539    7.897791    2.113118         0.0    0.000000
# 1542    5.457594    2.351115         0.0    0.000000
# 1543    4.340082    5.500209         0.0    6.356008
# 1545    9.481959    3.850174         0.0    0.000000
#
# [688 rows x 201 columns]

# %%
temp = pd.DataFrame(finalresults, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Figure_Development/Chemopy/resultsdata/chemopy_knn.csv')

# %%
import os
import pandas as pd
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Chemopy/datasets/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

# %%
datasets[14]
# Out:
#       Toxicity_Value   Weight  nH  nHal  nHet  nHA  nF  nCl  nBr  nI  ...  \
# 0                  0  168.060  14     0     6   12   0    0    0   0  ...
# 1                  0   84.030   8     0     3    6   0    0    0   0  ...
# 2                  1  222.045   5     0     3   15   0    0    0   0  ...
# 3                  0  196.373   1     5     2    7   3    1    1   0  ...
# 4                  0  182.475   2     6     3   10   5    1    0   0  ...
# ...              ...      ...  ..   ...   ...  ...  ..  ...  ...  ..  ...
# 7480               1  158.139   9     0    12   13   0    0    0   0  ...
# 7481               1  198.182   9     0    10   14   0    0    0   0  ...
# 7482               1  264.242  14     0    22   22   0    0    0   0  ...
# 7483               1  256.219  12     0    20   21   0    0    0   0  ...
# 7484               1  221.567   8     1     6   15   0    1    0   0  ...
#
#       VSAEstate0  VSAEstate1  VSAEstate2  VSAEstate3  VSAEstate4  VSAEstate5  \
# 0       0.000000    0.000000   52.176914    0.000000    0.000000    0.000000
# 1       0.000000    0.000000   24.016204    0.000000    0.000000    0.000000
# 2       0.000000   40.522482   25.547240    0.000000    0.000000    0.000000
# 3      31.081597    0.000000    0.000000    0.000000    0.000000    0.000000
# 4      58.597099    0.000000    0.000000   -2.937500    0.000000    0.000000
# ...          ...         ...         ...         ...         ...         ...
# 7480    0.000000    0.000000    6.375648    2.996481    0.000000   14.461204
# 7481   15.932546    0.000000    1.142792    0.000000    0.896481    6.027971
# 7482    0.000000    0.000000   10.542324    0.000000    0.000000   30.791009
# 7483    5.926524    0.000000    8.160341    2.794728    0.000000   22.045884
# 7484    0.000000   18.529892    8.685539   15.410626   -1.562279    0.000000
#
#       VSAEstate6  VSAEstate7  VSAEstate8  VSAEstate9
# 0      -6.391944   -1.451636         0.0    0.000000
# 1      -0.953704   -0.729167         0.0    0.000000
# 2      -1.545556   -1.690833         0.0    0.000000
# 3      -4.317901    0.000000         0.0    6.680748
# 4      -4.946443   -3.510069         0.0    4.324691
# ...          ...         ...         ...         ...
# 7480    0.000000    0.000000         0.0    0.000000
# 7481    2.172977    1.491392         0.0    1.502506
# 7482    0.000000    0.000000         0.0    0.000000
# 7483    0.572523    0.000000         0.0    0.000000
# 7484    0.000000    0.000000         0.0    5.547333
#
# [7485 rows x 201 columns]

# %%
namelist[14]
# Out:
# 'Ames_Mutagenicity_Chemopy.csv'
