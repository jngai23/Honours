# %%
#30/7/24 Creates a K fold RF model for each file in a folder provided they are Fingerprints

#3/7/24 For the implementation of K-Fold RF using combined Chemopy Mutagen Data

import os
import pandas as pd
import numpy as np
import math
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Fingerprints/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df.drop(columns=['SMILES'], inplace=True)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
finalresults = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 50):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = RandomForestClassifier(n_estimators=mtry, criterion='entropy', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                    max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                    verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)

            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = RandomForestClassifier(n_estimators=bestmetrics, criterion='entropy', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                    max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                    verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    finalresults.append(results[12])
    sets += 1
# Out:
# ========================================
# For dataset NR-AR-LBD_Avafp.csv
# for fold 1 test set mcc of 0.8957219251336899 valid set mcc of 0.6657142857142857
# for fold 2 test set mcc of 0.6888888888888889 valid set mcc of 0.35387166498534905
# for fold 3 test set mcc of 0.6546536707079772 valid set mcc of 0.4866237983169703
# for fold 4 test set mcc of 0.6888888888888889 valid set mcc of 0.26162797606709143
# for fold 5 test set mcc of 0.6754385964912281 valid set mcc of 0.5270462766947298
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.78125
# mcc = 0.5644444618109229
# ========================================
# For dataset SR-ATAD5_Morganfp.csv
# for fold 1 test set mcc of 0.5893689584893059 valid set mcc of 0.28867513459481287
# for fold 2 test set mcc of 0.6077927272100749 valid set mcc of 0.2722900593672232
# for fold 3 test set mcc of 0.64607127179228 valid set mcc of 0.5138888888888888
# for fold 4 test set mcc of 0.4879594489999274 valid set mcc of 0.5773502691896257
# for fold 5 test set mcc of 0.34877605543113943 valid set mcc of 0.49333333333333335
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7307692307692307
# mcc = 0.46325113915401156
# ========================================
# For dataset NR-aromatase_TTorsionfp.csv
# for fold 1 test set mcc of 0.5509189647176967 valid set mcc of 0.42833333333333334
# for fold 2 test set mcc of 0.5056205829602306 valid set mcc of 0.47403413168626635
# for fold 3 test set mcc of 0.5427786801746859 valid set mcc of 0.6959553154977629
# for fold 4 test set mcc of 0.5762536864918488 valid set mcc of 0.37107422226742265
# for fold 5 test set mcc of 0.532608695652174 valid set mcc of 0.4554218823344909
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.6942148760330579
# mcc = 0.4001866494902882
# ========================================
# For dataset NR-PPAR-gamma_Avafp.csv
# for fold 1 test set mcc of 0.5277777777777778 valid set mcc of 0.37796447300922725
# for fold 2 test set mcc of 0.4542199791661351 valid set mcc of 0.3860440160957241
# for fold 3 test set mcc of 0.5814571893892646 valid set mcc of 0.5345224838248488
# for fold 4 test set mcc of 0.4844813951249545 valid set mcc of 0.33295604590814587
# for fold 5 test set mcc of 0.55 valid set mcc of 0.2193817272381392
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.6986301369863014
# mcc = 0.39864983187849135
# ========================================
# For dataset NR-AhR_Morganfp.csv
# for fold 1 test set mcc of 0.6892889335554799 valid set mcc of 0.52
# for fold 2 test set mcc of 0.5361834956419664 valid set mcc of 0.45022516889074815
# for fold 3 test set mcc of 0.6251326146494808 valid set mcc of 0.6205281366778036
# for fold 4 test set mcc of 0.675363457216666 valid set mcc of 0.5500192414050356
# for fold 5 test set mcc of 0.6725585057370782 valid set mcc of 0.6368430022967195
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.8059701492537313
# mcc = 0.6057622340798641
# ========================================
# For dataset NR-AR_Avafp.csv
# for fold 1 test set mcc of 0.7655570205274012 valid set mcc of 0.5344402432698848
# for fold 2 test set mcc of 0.5561888604390448 valid set mcc of 0.5
# for fold 3 test set mcc of 0.4003203845127178 valid set mcc of 0.6389151433378876
# for fold 4 test set mcc of 0.5047443709236429 valid set mcc of 0.2573206596865631
# for fold 5 test set mcc of 0.5896179161012005 valid set mcc of 0.38507702310770275
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.752
# mcc = 0.5253335975112714
# ========================================
# For dataset Hepatotoxicity_Morganfp.csv
# for fold 1 test set mcc of 0.5019025460996324 valid set mcc of 0.41530246773150575
# for fold 2 test set mcc of 0.48942869995501576 valid set mcc of 0.49114188230100386
# for fold 3 test set mcc of 0.5539687875456115 valid set mcc of 0.46220551591231496
# for fold 4 test set mcc of 0.49853727661268743 valid set mcc of 0.42135093476636265
# for fold 5 test set mcc of 0.4677863958354595 valid set mcc of 0.4706426259824318
#
# validation metrics of:
# positives in data 293
# negatives in data 285
# net accuracy = 0.7664359861591695
# mcc = 0.5330317753634951
# ========================================
# For dataset Cardiotoxicity-5_Morganfp.csv
# for fold 1 test set mcc of 0.5342244506353423 valid set mcc of 0.3853987191542301
# for fold 2 test set mcc of 0.5091242594727236 valid set mcc of 0.34583610946177173
# for fold 3 test set mcc of 0.5645895715784651 valid set mcc of 0.340652371381841
# for fold 4 test set mcc of 0.4650727374434598 valid set mcc of 0.5566824782113727
# for fold 5 test set mcc of 0.43034547720415894 valid set mcc of 0.4100565260876024
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.7483870967741936
# mcc = 0.4976444945946108
# ========================================
# For dataset NR-PPAR-gamma_Morganfp.csv
# for fold 1 test set mcc of 0.4637130167514838 valid set mcc of 0.48911598804451845
# for fold 2 test set mcc of 0.6110340195925389 valid set mcc of 0.408248290463863
# for fold 3 test set mcc of 0.630537041003112 valid set mcc of 0.5091750772173156
# for fold 4 test set mcc of 0.40121296172898085 valid set mcc of 0.08597285067873303
# for fold 5 test set mcc of 0.55 valid set mcc of 0.19786096256684493
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.7534246575342466
# mcc = 0.5179467772872011
# ========================================
# For dataset Cardiotoxicity-10_MACCSfp.csv
# for fold 1 test set mcc of 0.5314350427970411 valid set mcc of 0.25502058143883927
# for fold 2 test set mcc of 0.4276217301981449 valid set mcc of 0.4144235296883577
# for fold 3 test set mcc of 0.3959886841971662 valid set mcc of 0.47501760999967235
# for fold 4 test set mcc of 0.3766120843491795 valid set mcc of 0.3726190476190476
# for fold 5 test set mcc of 0.5640485982074785 valid set mcc of 0.4155491906054957
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.7290322580645161
# mcc = 0.40987601537233415
# ========================================
# For dataset NR-PPAR-gamma_TTorsionfp.csv
# for fold 1 test set mcc of 0.43938802910487174 valid set mcc of 0.23782574707724705
# for fold 2 test set mcc of 0.36217963646349016 valid set mcc of 0.2721655269759087
# for fold 3 test set mcc of 0.47153204805450116 valid set mcc of 0.2721655269759087
# for fold 4 test set mcc of 0.40121296172898085 valid set mcc of 0.3861969258768566
# for fold 5 test set mcc of 0.2357797812857538 valid set mcc of 0.22927937978192153
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.821917808219178
# mcc = 0.655059004817089
# ========================================
# For dataset Cardiotoxicity-10_Morganfp.csv
# for fold 1 test set mcc of 0.49553213968872845 valid set mcc of 0.4041554243855289
# for fold 2 test set mcc of 0.42788946864244237 valid set mcc of 0.3643848375527829
# for fold 3 test set mcc of 0.38189893985001444 valid set mcc of 0.46039042670631547
# for fold 4 test set mcc of 0.4072348581950207 valid set mcc of 0.3043871389744471
# for fold 5 test set mcc of 0.4528263625274409 valid set mcc of 0.33303990745677836
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.7032258064516129
# mcc = 0.348065274025202
# ========================================
# For dataset SR-MMP_Morganfp.csv
# for fold 1 test set mcc of 0.647946162563876 valid set mcc of 0.4935701978558339
# for fold 2 test set mcc of 0.575999918656379 valid set mcc of 0.5511792679982325
# for fold 3 test set mcc of 0.4690753506235187 valid set mcc of 0.4624557019606478
# for fold 4 test set mcc of 0.5517557332192131 valid set mcc of 0.4511932837119264
# for fold 5 test set mcc of 0.6789411416740609 valid set mcc of 0.5397260273972603
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7985781990521327
# mcc = 0.5863241664917337
# ========================================
# For dataset SR-ARE_TTorsionfp.csv
# for fold 1 test set mcc of 0.38928242860203643 valid set mcc of 0.2763853991962833
# for fold 2 test set mcc of 0.4404685480398019 valid set mcc of 0.4542805688725504
# for fold 3 test set mcc of 0.29587391091205123 valid set mcc of 0.19704252732787805
# for fold 4 test set mcc of 0.4269638438330364 valid set mcc of 0.4305376651784708
# for fold 5 test set mcc of 0.42031984228460867 valid set mcc of 0.10332356489317869
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7287735849056604
# mcc = 0.43834684664047724
# ========================================
# For dataset Hepatotoxicity_Avafp.csv
# for fold 1 test set mcc of 0.5111010762399337 valid set mcc of 0.4083274708589348
# for fold 2 test set mcc of 0.43838210930399646 valid set mcc of 0.4131697832971825
# for fold 3 test set mcc of 0.5633929914272823 valid set mcc of 0.49094359531960197
# for fold 4 test set mcc of 0.4999875004687305 valid set mcc of 0.4214533830105551
# for fold 5 test set mcc of 0.46727688787185356 valid set mcc of 0.39430474208147803
#
# validation metrics of:
# positives in data 293
# negatives in data 285
# net accuracy = 0.7577854671280276
# mcc = 0.5155550564221328
# ========================================
# For dataset Reproductive_Toxicity_Morganfp.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 5
# negatives in data 4
# net accuracy = 0.5555555555555556
# mcc = 0.1
# ========================================
# For dataset NR-ER-LBD_MACCSfp.csv
# for fold 1 test set mcc of 0.6396021490668313 valid set mcc of 0.4214433884673491
# for fold 2 test set mcc of 0.6362282759137112 valid set mcc of 0.4304551074770279
# for fold 3 test set mcc of 0.5461422450332466 valid set mcc of 0.46638951701949494
# for fold 4 test set mcc of 0.44445779894466364 valid set mcc of 0.28520199881926267
# for fold 5 test set mcc of 0.6498440561375455 valid set mcc of 0.31888478212357624
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.684931506849315
# mcc = 0.3763865344406873
# ========================================
# For dataset Developmental_Toxicity_Avafp.csv
# for fold 1 test set mcc of 0.25 valid set mcc of 0
# for fold 2 test set mcc of 0.16666666666666666 valid set mcc of -0.3333333333333333
# for fold 3 test set mcc of 0 valid set mcc of -0.25
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0.16666666666666666 valid set mcc of 0
#
# validation metrics of:
# positives in data 8
# negatives in data 6
# net accuracy = 0.35714285714285715
# mcc = -0.28867513459481287
# ========================================
# For dataset Cardiotoxicity-1_Avafp.csv
# for fold 1 test set mcc of 0.40573896741507925 valid set mcc of 0.48420012470625223
# for fold 2 test set mcc of 0.46214796605085434 valid set mcc of 0.413015866396986
# for fold 3 test set mcc of 0.5168746236478836 valid set mcc of 0.5443078783958877
# for fold 4 test set mcc of 0.3674753838266859 valid set mcc of 0.4057220595560335
# for fold 5 test set mcc of 0.4742663992755643 valid set mcc of 0.4206397497182859
#
# validation metrics of:
# positives in data 70
# negatives in data 240
# net accuracy = 0.8387096774193549
# mcc = 0.4803666173028868
# ========================================
# For dataset Cardiotoxicity-30_TTorsionfp.csv
# for fold 1 test set mcc of 0.42804964166145 valid set mcc of 0.48980536649995393
# for fold 2 test set mcc of 0.35536966825016814 valid set mcc of 0.3857583749052298
# for fold 3 test set mcc of 0.35536966825016814 valid set mcc of 0.2419513346586043
# for fold 4 test set mcc of 0.5271527802754365 valid set mcc of 0.16666666666666666
# for fold 5 test set mcc of 0.5450329731399054 valid set mcc of 0.3012072483384371
#
# validation metrics of:
# positives in data 85
# negatives in data 53
# net accuracy = 0.6956521739130435
# mcc = 0.3481172026864979
# ========================================
# For dataset NR-ER-LBD_Morganfp.csv
# for fold 1 test set mcc of 0.6737856303945685 valid set mcc of 0.5072599298483808
# for fold 2 test set mcc of 0.5958460099157059 valid set mcc of 0.544561399794363
# for fold 3 test set mcc of 0.5348060148478825 valid set mcc of 0.46638951701949494
# for fold 4 test set mcc of 0.5461422450332466 valid set mcc of 0.2773500981126145
# for fold 5 test set mcc of 0.680009255387445 valid set mcc of 0.21889453648082105
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7328767123287672
# mcc = 0.487670425490951
# ========================================
# For dataset Reproductive_Toxicity_MACCSfp.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 5
# negatives in data 4
# net accuracy = 0.6666666666666666
# mcc = 0.31622776601683794
# ========================================
# For dataset Carcinogenicity_Morganfp.csv
# for fold 1 test set mcc of 0.5119346322228776 valid set mcc of 0.2824346666377309
# for fold 2 test set mcc of 0.47097849993618895 valid set mcc of 0.3996478966740781
# for fold 3 test set mcc of 0.4804608280736272 valid set mcc of 0.2973745360680655
# for fold 4 test set mcc of 0.36628971787912823 valid set mcc of 0.43414160625262144
# for fold 5 test set mcc of 0.37790697674418605 valid set mcc of 0.37433506329658833
#
# validation metrics of:
# positives in data 102
# negatives in data 103
# net accuracy = 0.6780487804878049
# mcc = 0.35608875107739485
# ========================================
# For dataset SR-MMP_MACCSfp.csv
# for fold 1 test set mcc of 0.6962811444545381 valid set mcc of 0.5545845443746958
# for fold 2 test set mcc of 0.7093628331838578 valid set mcc of 0.5551075310029744
# for fold 3 test set mcc of 0.5422133127250621 valid set mcc of 0.5927770575734872
# for fold 4 test set mcc of 0.6554036644500243 valid set mcc of 0.5863527298559493
# for fold 5 test set mcc of 0.6919364086666204 valid set mcc of 0.610321749219999
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7819905213270142
# mcc = 0.5500998413120546
# ========================================
# For dataset NR-AhR_MACCSfp.csv
# for fold 1 test set mcc of 0.6869778623593988 valid set mcc of 0.5019978493710154
# for fold 2 test set mcc of 0.5636291121802954 valid set mcc of 0.47439525430691426
# for fold 3 test set mcc of 0.5636291121802954 valid set mcc of 0.5750962956117134
# for fold 4 test set mcc of 0.6872040184525396 valid set mcc of 0.6464155840824328
# for fold 5 test set mcc of 0.6902771448249767 valid set mcc of 0.6062211225767399
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.817910447761194
# mcc = 0.6310887926727717
# ========================================
# For dataset NR-PPAR-gamma_MACCSfp.csv
# for fold 1 test set mcc of 0.6804138174397717 valid set mcc of 0.282842712474619
# for fold 2 test set mcc of 0.5421052631578948 valid set mcc of 0.4444444444444444
# for fold 3 test set mcc of 0.7070707070707071 valid set mcc of 0.3333333333333333
# for fold 4 test set mcc of 0.28749445424997294 valid set mcc of 0.3574660633484163
# for fold 5 test set mcc of 0.4743416490252569 valid set mcc of 0.29433147307547786
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.684931506849315
# mcc = 0.36964698637163457
# ========================================
# For dataset SR-ARE_Avafp.csv
# for fold 1 test set mcc of 0.49870340811077585 valid set mcc of 0.41767790061294374
# for fold 2 test set mcc of 0.5259628910919787 valid set mcc of 0.39058640286634894
# for fold 3 test set mcc of 0.37850977577505074 valid set mcc of 0.434650165839919
# for fold 4 test set mcc of 0.42214808920993185 valid set mcc of 0.5165095061766487
# for fold 5 test set mcc of 0.3680312494645138 valid set mcc of 0.2634923633531862
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7334905660377359
# mcc = 0.4489559509861441
# ========================================
# For dataset NR-ER-LBD_Avafp.csv
# for fold 1 test set mcc of 0.7464242299538343 valid set mcc of 0.4604038005406827
# for fold 2 test set mcc of 0.5331668756526732 valid set mcc of 0.4213468166472025
# for fold 3 test set mcc of 0.5745374140064684 valid set mcc of 0.403243452644148
# for fold 4 test set mcc of 0.2655425022718972 valid set mcc of 0.2773500981126145
# for fold 5 test set mcc of 0.7278253428740509 valid set mcc of 0.39968271447020604
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7534246575342466
# mcc = 0.5349625039671705
# ========================================
# For dataset NR-AR_Morganfp.csv
# for fold 1 test set mcc of 0.6454019345987071 valid set mcc of 0.4174393166995065
# for fold 2 test set mcc of 0.6572311106330365 valid set mcc of 0.5
# for fold 3 test set mcc of 0.3983947309100766 valid set mcc of 0.4348628431937505
# for fold 4 test set mcc of 0.5732640692227624 valid set mcc of 0.22999217148458131
# for fold 5 test set mcc of 0.6007744360777069 valid set mcc of 0.4576043153224294
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.736
# mcc = 0.4968030024467603
# ========================================
# For dataset Cardiotoxicity-5_MACCSfp.csv
# for fold 1 test set mcc of 0.46829046357897264 valid set mcc of 0.32795295365525273
# for fold 2 test set mcc of 0.4743500328037551 valid set mcc of 0.3941294733253171
# for fold 3 test set mcc of 0.4678027878792997 valid set mcc of 0.3695707803327116
# for fold 4 test set mcc of 0.3413011825185553 valid set mcc of 0.3092768564135433
# for fold 5 test set mcc of 0.39 valid set mcc of 0.3116429598265778
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.7387096774193549
# mcc = 0.4725186887370063
# ========================================
# For dataset Respiratory_Toxicity_Avafp.csv
# for fold 1 test set mcc of 0.569916489955748 valid set mcc of 0.4645052564894855
# for fold 2 test set mcc of 0.5590237723875837 valid set mcc of 0.43062471620064935
# for fold 3 test set mcc of 0.5720171248332295 valid set mcc of 0.6320858586337038
# for fold 4 test set mcc of 0.7515095949359234 valid set mcc of 0.46387749265376454
# for fold 5 test set mcc of 0.6507984289934835 valid set mcc of 0.5553395763729865
#
# validation metrics of:
# positives in data 164
# negatives in data 106
# net accuracy = 0.7481481481481481
# mcc = 0.46710684116286666
# ========================================
# For dataset NR-ER_Morganfp.csv
# for fold 1 test set mcc of 0.39413219389143966 valid set mcc of 0.41769913744540504
# for fold 2 test set mcc of 0.3130674412306567 valid set mcc of 0.4264906588562072
# for fold 3 test set mcc of 0.3912614228889506 valid set mcc of 0.2867702431803295
# for fold 4 test set mcc of 0.41240174410178804 valid set mcc of 0.33934742243624
# for fold 5 test set mcc of 0.44176344737127105 valid set mcc of 0.464250363159397
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.7146739130434783
# mcc = 0.4156946743886325
# ========================================
# For dataset SR-ARE_Morganfp.csv
# for fold 1 test set mcc of 0.4901251148684687 valid set mcc of 0.4873279974629188
# for fold 2 test set mcc of 0.49905397538651664 valid set mcc of 0.38636901725868833
# for fold 3 test set mcc of 0.4163347624210692 valid set mcc of 0.3414420235837817
# for fold 4 test set mcc of 0.32963809361719837 valid set mcc of 0.4879500364742666
# for fold 5 test set mcc of 0.4369169944449826 valid set mcc of 0.1951092137150611
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7358490566037735
# mcc = 0.45337872933527146
# ========================================
# For dataset NR-AR-LBD_Morganfp.csv
# for fold 1 test set mcc of 0.710116428834481 valid set mcc of 0.6592443967173135
# for fold 2 test set mcc of 0.7434307035293071 valid set mcc of 0.5846695269740967
# for fold 3 test set mcc of 0.6546536707079772 valid set mcc of 0.7010681840159741
# for fold 4 test set mcc of 0.5730112392805924 valid set mcc of 0.44508181954215625
# for fold 5 test set mcc of 0.6280763381828277 valid set mcc of 0.6356048762998656
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.78125
# mcc = 0.5818429184443191
# ========================================
# For dataset Ames_Mutagenicity_Avafp.csv
# for fold 1 test set mcc of 0.6377096048427107 valid set mcc of 0.6350735090908817
# for fold 2 test set mcc of 0.6722207393309969 valid set mcc of 0.6062538995465024
# for fold 3 test set mcc of 0.6990796504848649 valid set mcc of 0.6492790483609917
# for fold 4 test set mcc of 0.6853708423625068 valid set mcc of 0.648386094733996
# for fold 5 test set mcc of 0.6178223368034409 valid set mcc of 0.6475626960383355
#
# validation metrics of:
# positives in data 839
# negatives in data 658
# net accuracy = 0.8370073480293921
# mcc = 0.6690724240281898
# ========================================
# For dataset Reproductive_Toxicity_TTorsionfp.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 5
# negatives in data 4
# net accuracy = 0.3333333333333333
# mcc = -0.35
# ========================================
# For dataset Ames_Mutagenicity_Morganfp.csv
# for fold 1 test set mcc of 0.603650250611146 valid set mcc of 0.6195795147708203
# for fold 2 test set mcc of 0.6823639245219152 valid set mcc of 0.6767516838677182
# for fold 3 test set mcc of 0.6954543584619967 valid set mcc of 0.6245460541922347
# for fold 4 test set mcc of 0.6687298973476922 valid set mcc of 0.6481501753886127
# for fold 5 test set mcc of 0.6287947720990493 valid set mcc of 0.5994738355453837
#
# validation metrics of:
# positives in data 839
# negatives in data 658
# net accuracy = 0.8203072812291249
# mcc = 0.634433058924186
# ========================================
# For dataset Ames_Mutagenicity_TTorsionfp.csv
# for fold 1 test set mcc of 0.549323291727448 valid set mcc of 0.570324441616801
# for fold 2 test set mcc of 0.6159057146298359 valid set mcc of 0.5625263212709782
# for fold 3 test set mcc of 0.6164219115162083 valid set mcc of 0.5192397335463873
# for fold 4 test set mcc of 0.5857384995764378 valid set mcc of 0.5291556857807549
# for fold 5 test set mcc of 0.5635647306852729 valid set mcc of 0.5246492637364815
#
# validation metrics of:
# positives in data 839
# negatives in data 658
# net accuracy = 0.8056112224448898
# mcc = 0.6051449130576532
# ========================================
# For dataset NR-AR_MACCSfp.csv
# for fold 1 test set mcc of 0.48514197070501264 valid set mcc of 0.2153846153846154
# for fold 2 test set mcc of 0.5175363875271632 valid set mcc of 0.5267865840075201
# for fold 3 test set mcc of 0.24417741571907922 valid set mcc of 0.3983947309100766
# for fold 4 test set mcc of 0.6210344279375828 valid set mcc of 0.26704433012863377
# for fold 5 test set mcc of 0.6816381233958094 valid set mcc of 0.47259452835945337
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.712
# mcc = 0.42906546363827336
# ========================================
# For dataset Hepatotoxicity_MACCSfp.csv
# for fold 1 test set mcc of 0.4424167660013087 valid set mcc of 0.41175615470714905
# for fold 2 test set mcc of 0.482348087157108 valid set mcc of 0.439421547425546
# for fold 3 test set mcc of 0.5283124595514349 valid set mcc of 0.4508085733938899
# for fold 4 test set mcc of 0.474166005937882 valid set mcc of 0.4215697456510882
# for fold 5 test set mcc of 0.4497673367270506 valid set mcc of 0.4677668754385222
#
# validation metrics of:
# positives in data 293
# negatives in data 285
# net accuracy = 0.7560553633217993
# mcc = 0.5123582212962372
# ========================================
# For dataset NR-AR-LBD_MACCSfp.csv
# for fold 1 test set mcc of 0.7533395020117445 valid set mcc of 0.6622918857059334
# for fold 2 test set mcc of 0.5865557254410011 valid set mcc of 0.4231944290295931
# for fold 3 test set mcc of 0.6546536707079772 valid set mcc of 0.48261708906584017
# for fold 4 test set mcc of 0.6583050504534322 valid set mcc of 0.44508181954215625
# for fold 5 test set mcc of 0.6900721388834448 valid set mcc of 0.6490229342872016
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.8125
# mcc = 0.6373212392727375
# ========================================
# For dataset Ames_Mutagenicity_MACCSfp.csv
# for fold 1 test set mcc of 0.6475899167785328 valid set mcc of 0.6777515248101561
# for fold 2 test set mcc of 0.679412568719166 valid set mcc of 0.6211778850777255
# for fold 3 test set mcc of 0.6957693061656008 valid set mcc of 0.6579262258081537
# for fold 4 test set mcc of 0.6889010582947779 valid set mcc of 0.6652577370401516
# for fold 5 test set mcc of 0.6553721135667213 valid set mcc of 0.6624852125486851
#
# validation metrics of:
# positives in data 839
# negatives in data 658
# net accuracy = 0.824315297261189
# mcc = 0.6432476438352981
# ========================================
# For dataset NR-AR_TTorsionfp.csv
# for fold 1 test set mcc of 0.5561888604390448 valid set mcc of 0.4174393166995065
# for fold 2 test set mcc of 0.6821865008193587 valid set mcc of 0.6078306738548308
# for fold 3 test set mcc of 0.27884615384615385 valid set mcc of 0.3540943975098861
# for fold 4 test set mcc of 0.6553607444452058 valid set mcc of 0.26704433012863377
# for fold 5 test set mcc of 0.5331260496981621 valid set mcc of 0.4466625002869187
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.696
# mcc = 0.4014489672896009
# ========================================
# For dataset NR-ER_Avafp.csv
# for fold 1 test set mcc of 0.3336862549221735 valid set mcc of 0.2362030105219912
# for fold 2 test set mcc of 0.3469691065222919 valid set mcc of 0.21751323662259966
# for fold 3 test set mcc of 0.36283066205618947 valid set mcc of 0.4408548705711836
# for fold 4 test set mcc of 0.3378642163460113 valid set mcc of 0.25041709177206134
# for fold 5 test set mcc of 0.3874584745219908 valid set mcc of 0.44940035122968214
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6657608695652174
# mcc = 0.29805012344291293
# ========================================
# For dataset SR-p53_MACCSfp.csv
# for fold 1 test set mcc of 0.5414123801220575 valid set mcc of 0.35568760611205436
# for fold 2 test set mcc of 0.46559102714931194 valid set mcc of 0.33641370682494404
# for fold 3 test set mcc of 0.6179143806533247 valid set mcc of 0.3224970216983856
# for fold 4 test set mcc of 0.5884023470050311 valid set mcc of 0.4410632460131757
# for fold 5 test set mcc of 0.6092964849398389 valid set mcc of 0.5746424382581968
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6470588235294118
# mcc = 0.2906539344946665
# ========================================
# For dataset Cardiotoxicity-5_TTorsionfp.csv
# for fold 1 test set mcc of 0.6031628920578316 valid set mcc of 0.3827967678684109
# for fold 2 test set mcc of 0.506892717914145 valid set mcc of 0.24042539747019134
# for fold 3 test set mcc of 0.5032175786762632 valid set mcc of 0.43786701991729615
# for fold 4 test set mcc of 0.4736367585881373 valid set mcc of 0.4902205682482089
# for fold 5 test set mcc of 0.2892106701640853 valid set mcc of 0.375909949698622
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.7129032258064516
# mcc = 0.4207143632165022
# ========================================
# For dataset NR-ER-LBD_TTorsionfp.csv
# for fold 1 test set mcc of 0.5606060606060606 valid set mcc of 0.5258317861910623
# for fold 2 test set mcc of 0.5247368153167122 valid set mcc of 0.35680792094703495
# for fold 3 test set mcc of 0.5336538461538461 valid set mcc of 0.6274976712450203
# for fold 4 test set mcc of 0.6033653846153846 valid set mcc of 0.16985840364661764
# for fold 5 test set mcc of 0.6761234037828132 valid set mcc of 0.17703551929365782
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.6643835616438356
# mcc = 0.3304190920484979
# ========================================
# For dataset Hepatotoxicity_TTorsionfp.csv
# for fold 1 test set mcc of 0.4000527676919298 valid set mcc of 0.32192472255605914
# for fold 2 test set mcc of 0.46546053002220283 valid set mcc of 0.41334093045903303
# for fold 3 test set mcc of 0.40705369228455407 valid set mcc of 0.43559487757317794
# for fold 4 test set mcc of 0.395672498824296 valid set mcc of 0.41350591652204904
# for fold 5 test set mcc of 0.4247831163867526 valid set mcc of 0.33482042878983115
#
# validation metrics of:
# positives in data 293
# negatives in data 285
# net accuracy = 0.7335640138408305
# mcc = 0.46747551605967624
# ========================================
# For dataset NR-AhR_Avafp.csv
# for fold 1 test set mcc of 0.6588055285731584 valid set mcc of 0.3651483716701107
# for fold 2 test set mcc of 0.5715732707663089 valid set mcc of 0.523753089329318
# for fold 3 test set mcc of 0.7290396814859459 valid set mcc of 0.5821543218812774
# for fold 4 test set mcc of 0.7034153224222468 valid set mcc of 0.5995886347424487
# for fold 5 test set mcc of 0.6102813604078444 valid set mcc of 0.6745996545655429
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.8208955223880597
# mcc = 0.6368694898106663
# ========================================
# For dataset Reproductive_Toxicity_Avafp.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset SR-ATAD5_MACCSfp.csv
# for fold 1 test set mcc of 0.6660869978853965 valid set mcc of 0.38138503569823695
# for fold 2 test set mcc of 0.6133669020106273 valid set mcc of 0.4199942951621736
# for fold 3 test set mcc of 0.5062173827984802 valid set mcc of 0.5172935265326569
# for fold 4 test set mcc of 0.5541923614671027 valid set mcc of 0.38138503569823695
# for fold 5 test set mcc of 0.36791434134434736 valid set mcc of 0.36
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7788461538461539
# mcc = 0.5646356569920906
# ========================================
# For dataset Cardiotoxicity-10_TTorsionfp.csv
# for fold 1 test set mcc of 0.41202213488556333 valid set mcc of 0.2569970264812942
# for fold 2 test set mcc of 0.3277466847112923 valid set mcc of 0.4124616456743348
# for fold 3 test set mcc of 0.3933696713655566 valid set mcc of 0.3900153060617188
# for fold 4 test set mcc of 0.4008667555362451 valid set mcc of 0.3535839999514189
# for fold 5 test set mcc of 0.5289211507207574 valid set mcc of 0.3172260492607262
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.7290322580645161
# mcc = 0.4091359893952855
# ========================================
# For dataset SR-ARE_MACCSfp.csv
# for fold 1 test set mcc of 0.5624029251321191 valid set mcc of 0.37981508181241624
# for fold 2 test set mcc of 0.4903774884479323 valid set mcc of 0.44385001838699967
# for fold 3 test set mcc of 0.32993526681131213 valid set mcc of 0.516765919896461
# for fold 4 test set mcc of 0.5139341077745376 valid set mcc of 0.47900879304624566
# for fold 5 test set mcc of 0.3325083866171257 valid set mcc of 0.3016267238605162
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7311320754716981
# mcc = 0.4438894849257133
# ========================================
# For dataset Carcinogenicity_TTorsionfp.csv
# for fold 1 test set mcc of 0.3196072738906446 valid set mcc of 0.35522903205019996
# for fold 2 test set mcc of 0.47097849993618895 valid set mcc of 0.30123610229787867
# for fold 3 test set mcc of 0.36718832257988404 valid set mcc of 0.4429076782731746
# for fold 4 test set mcc of 0.4151283469296787 valid set mcc of 0.25801075224043657
# for fold 5 test set mcc of 0.3627049040604059 valid set mcc of 0.2858631495214548
#
# validation metrics of:
# positives in data 102
# negatives in data 103
# net accuracy = 0.624390243902439
# mcc = 0.25032160515180923
# ========================================
# For dataset Carcinogenicity_Avafp.csv
# for fold 1 test set mcc of 0.5473237306811041 valid set mcc of 0.35955260905516806
# for fold 2 test set mcc of 0.4219057718615162 valid set mcc of 0.44232586846469135
# for fold 3 test set mcc of 0.5248744383124423 valid set mcc of 0.20273958938337897
# for fold 4 test set mcc of 0.46845798908546105 valid set mcc of 0.20091338688301238
# for fold 5 test set mcc of 0.47392389864375034 valid set mcc of 0.44965603502188867
#
# validation metrics of:
# positives in data 102
# negatives in data 103
# net accuracy = 0.6682926829268293
# mcc = 0.34024141190501267
# ========================================
# For dataset Respiratory_Toxicity_Morganfp.csv
# for fold 1 test set mcc of 0.5133880625403892 valid set mcc of 0.486464257689751
# for fold 2 test set mcc of 0.5595637103925328 valid set mcc of 0.5469363768841913
# for fold 3 test set mcc of 0.6320981451910299 valid set mcc of 0.5153044861884355
# for fold 4 test set mcc of 0.629996193376475 valid set mcc of 0.6802599137268581
# for fold 5 test set mcc of 0.6634920634920635 valid set mcc of 0.4772646135531731
#
# validation metrics of:
# positives in data 164
# negatives in data 106
# net accuracy = 0.7703703703703704
# mcc = 0.5085112938598969
# ========================================
# For dataset Respiratory_Toxicity_TTorsionfp.csv
# for fold 1 test set mcc of 0.4321486328636683 valid set mcc of 0.39042301207067415
# for fold 2 test set mcc of 0.651814018410781 valid set mcc of 0.5095126458715644
# for fold 3 test set mcc of 0.569916489955748 valid set mcc of 0.5545454545454546
# for fold 4 test set mcc of 0.5800301061501532 valid set mcc of 0.5224337683294346
# for fold 5 test set mcc of 0.5978168152437366 valid set mcc of 0.3740493139008071
#
# validation metrics of:
# positives in data 164
# negatives in data 106
# net accuracy = 0.762962962962963
# mcc = 0.4961090462142322
# ========================================
# For dataset NR-AR-LBD_TTorsionfp.csv
# for fold 1 test set mcc of 0.7420317739506375 valid set mcc of 0.6000077303150751
# for fold 2 test set mcc of 0.7434307035293071 valid set mcc of 0.46046933104270676
# for fold 3 test set mcc of 0.610170215847752 valid set mcc of 0.5873015873015873
# for fold 4 test set mcc of 0.6153084570802658 valid set mcc of 0.4542199791661351
# for fold 5 test set mcc of 0.7382129472480629 valid set mcc of 0.6356048762998656
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7708333333333334
# mcc = 0.5516909538001233
# ========================================
# For dataset Developmental_Toxicity_MACCSfp.csv
# for fold 1 test set mcc of 0.25 valid set mcc of 0
# for fold 2 test set mcc of 0.16666666666666666 valid set mcc of 0.0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0.16666666666666666
#
# validation metrics of:
# positives in data 8
# negatives in data 6
# net accuracy = 0.5714285714285714
# mcc = 0.09128709291752768
# ========================================
# For dataset SR-HSE_Morganfp.csv
# for fold 1 test set mcc of 0.46536934519903694 valid set mcc of 0.2628966471502125
# for fold 2 test set mcc of 0.4474593028095495 valid set mcc of 0.499373763083833
# for fold 3 test set mcc of 0.5949581849170845 valid set mcc of 0.5200380175616863
# for fold 4 test set mcc of 0.2735614162016395 valid set mcc of 0.5584400252983859
# for fold 5 test set mcc of 0.4599442350269685 valid set mcc of 0.301227212573792
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6578947368421053
# mcc = 0.314423761344636
# ========================================
# For dataset NR-aromatase_MACCSfp.csv
# for fold 1 test set mcc of 0.6023523847691574 valid set mcc of 0.5943247013318183
# for fold 2 test set mcc of 0.4855079189360899 valid set mcc of 0.2597056905574371
# for fold 3 test set mcc of 0.7586092837890653 valid set mcc of 0.5283788513238544
# for fold 4 test set mcc of 0.558389928096229 valid set mcc of 0.47
# for fold 5 test set mcc of 0.6177536231884058 valid set mcc of 0.6581818181818182
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7520661157024794
# mcc = 0.503031466565012
# ========================================
# For dataset NR-aromatase_Morganfp.csv
# for fold 1 test set mcc of 0.5125215823282815 valid set mcc of 0.35355339059327373
# for fold 2 test set mcc of 0.3768673314407159 valid set mcc of 0.4153093381985166
# for fold 3 test set mcc of 0.5772574469240125 valid set mcc of 0.6959553154977629
# for fold 4 test set mcc of 0.7027642214999339 valid set mcc of 0.2710575994548432
# for fold 5 test set mcc of 0.4945491263770958 valid set mcc of 0.7007345938577394
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7603305785123967
# mcc = 0.525117853414576
# ========================================
# For dataset NR-ER_MACCSfp.csv
# for fold 1 test set mcc of 0.4551956339137048 valid set mcc of 0.40142936050686406
# for fold 2 test set mcc of 0.2936139760049908 valid set mcc of 0.3401767248973789
# for fold 3 test set mcc of 0.4172539101938998 valid set mcc of 0.3134361424646406
# for fold 4 test set mcc of 0.31196681340135274 valid set mcc of 0.3304176482446333
# for fold 5 test set mcc of 0.4009445113504275 valid set mcc of 0.35342184623645134
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6711956521739131
# mcc = 0.31053105715103674
# ========================================
# For dataset Cardiotoxicity-10_Avafp.csv
# for fold 1 test set mcc of 0.4676219297715273 valid set mcc of 0.2513202142803002
# for fold 2 test set mcc of 0.45084676568356546 valid set mcc of 0.34672391405355574
# for fold 3 test set mcc of 0.35804939485144055 valid set mcc of 0.457466241725923
# for fold 4 test set mcc of 0.3493883419646181 valid set mcc of 0.25575086419978976
# for fold 5 test set mcc of 0.4528263625274409 valid set mcc of 0.4604826715899453
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.7225806451612903
# mcc = 0.3950842150503989
# ========================================
# For dataset SR-p53_Avafp.csv
# for fold 1 test set mcc of 0.4658468918976986 valid set mcc of 0.4420809305666707
# for fold 2 test set mcc of 0.43550706842063464 valid set mcc of 0.2986111111111111
# for fold 3 test set mcc of 0.5878787878787879 valid set mcc of 0.23570226039551584
# for fold 4 test set mcc of 0.5457211218844579 valid set mcc of 0.2600232013719527
# for fold 5 test set mcc of 0.575649675601062 valid set mcc of 0.52605502026234
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.7176470588235294
# mcc = 0.4356814142956374
# ========================================
# For dataset SR-p53_TTorsionfp.csv
# for fold 1 test set mcc of 0.47714263971357723 valid set mcc of 0.4501746992534254
# for fold 2 test set mcc of 0.49497389704031963 valid set mcc of 0.408248290463863
# for fold 3 test set mcc of 0.5029166631441309 valid set mcc of 0.408491223118783
# for fold 4 test set mcc of 0.5457211218844579 valid set mcc of 0.2514636468219414
# for fold 5 test set mcc of 0.5873971250985845 valid set mcc of 0.44109333638747783
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6235294117647059
# mcc = 0.24289060064827372
# ========================================
# For dataset Cardiotoxicity-30_MACCSfp.csv
# for fold 1 test set mcc of 0.21602468994692867 valid set mcc of 0.4472135954999579
# for fold 2 test set mcc of 0.5085163689750095 valid set mcc of 0.41727646454016987
# for fold 3 test set mcc of 0.35526486051678746 valid set mcc of 0.30817554274731757
# for fold 4 test set mcc of 0.571233151503201 valid set mcc of 0.30056669865495805
# for fold 5 test set mcc of 0.4117550274501065 valid set mcc of 0.4780613210960605
#
# validation metrics of:
# positives in data 85
# negatives in data 53
# net accuracy = 0.6666666666666666
# mcc = 0.29544950055493896
# ========================================
# For dataset Developmental_Toxicity_TTorsionfp.csv
# for fold 1 test set mcc of 0.25 valid set mcc of 0
# for fold 2 test set mcc of 0.16666666666666666 valid set mcc of -0.3333333333333333
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of -0.16666666666666666
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset SR-p53_Morganfp.csv
# for fold 1 test set mcc of 0.42284219703574544 valid set mcc of 0.29342186976053325
# for fold 2 test set mcc of 0.4037902956458651 valid set mcc of 0.2911484876492837
# for fold 3 test set mcc of 0.4749079974325668 valid set mcc of 0.30366908351147925
# for fold 4 test set mcc of 0.5952185845594824 valid set mcc of 0.3790039349876511
# for fold 5 test set mcc of 0.5339704433666158 valid set mcc of 0.5038350609598345
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6882352941176471
# mcc = 0.3838460077003889
# ========================================
# For dataset Cardiotoxicity-1_Morganfp.csv
# for fold 1 test set mcc of 0.4626060143539575 valid set mcc of 0.2809757434745082
# for fold 2 test set mcc of 0.5960639614578351 valid set mcc of 0.6164723254424371
# for fold 3 test set mcc of 0.566025278043848 valid set mcc of 0.6738510862317519
# for fold 4 test set mcc of 0.40351515259859955 valid set mcc of 0.36540133212419124
# for fold 5 test set mcc of 0.5683929140987454 valid set mcc of 0.3027643231982266
#
# validation metrics of:
# positives in data 70
# negatives in data 240
# net accuracy = 0.8580645161290322
# mcc = 0.5511343174274512
# ========================================
# For dataset SR-MMP_Avafp.csv
# for fold 1 test set mcc of 0.691237288320042 valid set mcc of 0.4046741059499205
# for fold 2 test set mcc of 0.6200772835179245 valid set mcc of 0.6280914233169552
# for fold 3 test set mcc of 0.578607786813465 valid set mcc of 0.5927770575734872
# for fold 4 test set mcc of 0.732438050383516 valid set mcc of 0.38929198487143646
# for fold 5 test set mcc of 0.714414505949075 valid set mcc of 0.6348455602386452
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7962085308056872
# mcc = 0.5801073702259036
# ========================================
# For dataset Cardiotoxicity-1_TTorsionfp.csv
# for fold 1 test set mcc of 0.4663831122579669 valid set mcc of 0.4097516033588601
# for fold 2 test set mcc of 0.48283777191037763 valid set mcc of 0.5240783350431796
# for fold 3 test set mcc of 0.5168746236478836 valid set mcc of 0.5689750414966135
# for fold 4 test set mcc of 0.3927693423233237 valid set mcc of 0.2616936719096207
# for fold 5 test set mcc of 0.5386248617532305 valid set mcc of 0.2986331829759507
#
# validation metrics of:
# positives in data 70
# negatives in data 240
# net accuracy = 0.8258064516129032
# mcc = 0.42342227492480167
# ========================================
# For dataset SR-ATAD5_TTorsionfp.csv
# for fold 1 test set mcc of 0.6516425469916569 valid set mcc of 0.3333333333333333
# for fold 2 test set mcc of 0.6077927272100749 valid set mcc of 0.15331807780320367
# for fold 3 test set mcc of 0.5429187467294155 valid set mcc of 0.4620924277292432
# for fold 4 test set mcc of 0.36226673028138096 valid set mcc of 0.6735753140545634
# for fold 5 test set mcc of 0.4083333333333333 valid set mcc of 0.5614802018328859
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7403846153846154
# mcc = 0.48085815507051266
# ========================================
# For dataset SR-HSE_TTorsionfp.csv
# for fold 1 test set mcc of 0.20261437908496732 valid set mcc of 0.39476289403185955
# for fold 2 test set mcc of 0.29098960019224995 valid set mcc of 0.2792896329177484
# for fold 3 test set mcc of 0.3720804971606606 valid set mcc of 0.19810603353891412
# for fold 4 test set mcc of 0.2957218659657171 valid set mcc of 0.49058177521232704
# for fold 5 test set mcc of 0.3060406448966426 valid set mcc of 0.3326121760930659
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.5986842105263158
# mcc = 0.19371478756036667
# ========================================
# For dataset NR-AhR_TTorsionfp.csv
# for fold 1 test set mcc of 0.498282282707685 valid set mcc of 0.4102765967979131
# for fold 2 test set mcc of 0.491903865304106 valid set mcc of 0.43135096127703215
# for fold 3 test set mcc of 0.622962553111713 valid set mcc of 0.5533998036160838
# for fold 4 test set mcc of 0.6412519283220873 valid set mcc of 0.5778357190665774
# for fold 5 test set mcc of 0.6378109223885032 valid set mcc of 0.5826716278675745
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.7791044776119403
# mcc = 0.5521390374331551
# ========================================
# For dataset Cardiotoxicity-5_Avafp.csv
# for fold 1 test set mcc of 0.4861527926641233 valid set mcc of 0.40965227344790317
# for fold 2 test set mcc of 0.5415132535704598 valid set mcc of 0.2608991571569846
# for fold 3 test set mcc of 0.46031716445500037 valid set mcc of 0.35053237924372316
# for fold 4 test set mcc of 0.43152473311362327 valid set mcc of 0.49291296127800205
# for fold 5 test set mcc of 0.3620217653823299 valid set mcc of 0.3820230387240228
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.7290322580645161
# mcc = 0.4554409422980496
# ========================================
# For dataset Respiratory_Toxicity_MACCSfp.csv
# for fold 1 test set mcc of 0.5305364637783835 valid set mcc of 0.4829835866872821
# for fold 2 test set mcc of 0.46794225287458513 valid set mcc of 0.5065512624719348
# for fold 3 test set mcc of 0.6265402377113659 valid set mcc of 0.5330017908890261
# for fold 4 test set mcc of 0.6711077274457556 valid set mcc of 0.5690536925199107
# for fold 5 test set mcc of 0.6270085422266278 valid set mcc of 0.519240403370459
#
# validation metrics of:
# positives in data 164
# negatives in data 106
# net accuracy = 0.7703703703703704
# mcc = 0.5238519622740018
# ========================================
# For dataset SR-HSE_Avafp.csv
# for fold 1 test set mcc of 0.3268292468128557 valid set mcc of 0.30046460736496117
# for fold 2 test set mcc of 0.4805296115423576 valid set mcc of 0.6298438669252061
# for fold 3 test set mcc of 0.34989282473966105 valid set mcc of 0.38371832051364707
# for fold 4 test set mcc of 0.5115058168786555 valid set mcc of 0.29337146314889534
# for fold 5 test set mcc of 0.5773262244498369 valid set mcc of 0.45175395145262565
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.7105263157894737
# mcc = 0.4196558106168639
# ========================================
# For dataset SR-MMP_TTorsionfp.csv
# for fold 1 test set mcc of 0.5856333202565441 valid set mcc of 0.41692628102075213
# for fold 2 test set mcc of 0.566498715809484 valid set mcc of 0.5271121985974822
# for fold 3 test set mcc of 0.4697032572244759 valid set mcc of 0.611394653284831
# for fold 4 test set mcc of 0.7242423238423661 valid set mcc of 0.5388721563983924
# for fold 5 test set mcc of 0.6151482796513269 valid set mcc of 0.602575593241839
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7867298578199052
# mcc = 0.5617225988868101
# ========================================
# For dataset NR-aromatase_Avafp.csv
# for fold 1 test set mcc of 0.38423035128728983 valid set mcc of 0.5125215823282815
# for fold 2 test set mcc of 0.32945416337722977 valid set mcc of 0.31719576756473444
# for fold 3 test set mcc of 0.5860869565217391 valid set mcc of 0.47
# for fold 4 test set mcc of 0.4530333378893933 valid set mcc of 0.06010025069647601
# for fold 5 test set mcc of 0.44874504439435503 valid set mcc of 0.4464617153139861
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7520661157024794
# mcc = 0.5028800050111593
# ========================================
# For dataset Cardiotoxicity-1_MACCSfp.csv
# for fold 1 test set mcc of 0.4517901482357816 valid set mcc of 0.36891438072857313
# for fold 2 test set mcc of 0.4393106328077838 valid set mcc of 0.5101413079038405
# for fold 3 test set mcc of 0.49134498022597545 valid set mcc of 0.512491112209713
# for fold 4 test set mcc of 0.39351430135252935 valid set mcc of 0.4320333397468379
# for fold 5 test set mcc of 0.5373731305853026 valid set mcc of 0.4558176802725439
#
# validation metrics of:
# positives in data 70
# negatives in data 240
# net accuracy = 0.832258064516129
# mcc = 0.4507124667559986
# ========================================
# For dataset NR-ER_TTorsionfp.csv
# for fold 1 test set mcc of 0.439717444124798 valid set mcc of 0.28597444861729077
# for fold 2 test set mcc of 0.36957849064925835 valid set mcc of 0.416526080700374
# for fold 3 test set mcc of 0.2853208080221112 valid set mcc of 0.24558562098038908
# for fold 4 test set mcc of 0.38178403885786744 valid set mcc of 0.23468551538159038
# for fold 5 test set mcc of 0.40966140749812224 valid set mcc of 0.4203668179315539
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6766304347826086
# mcc = 0.3226637999560818
# ========================================
# For dataset SR-HSE_MACCSfp.csv
# for fold 1 test set mcc of 0.38570446755682164 valid set mcc of 0.4095238095238095
# for fold 2 test set mcc of 0.4741706566921629 valid set mcc of 0.5734769026410975
# for fold 3 test set mcc of 0.5930673884164135 valid set mcc of 0.5909167880440763
# for fold 4 test set mcc of 0.38954291055419554 valid set mcc of 0.4747252747252747
# for fold 5 test set mcc of 0.41759137001809177 valid set mcc of 0.2484646732989441
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6447368421052632
# mcc = 0.28700381737895997
# ========================================
# For dataset Developmental_Toxicity_Morganfp.csv
# for fold 1 test set mcc of 0.25 valid set mcc of 0
# for fold 2 test set mcc of 0.16666666666666666 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 8
# negatives in data 6
# net accuracy = 0.6428571428571429
# mcc = 0.251259453814803
# ========================================
# For dataset Cardiotoxicity-30_Avafp.csv
# for fold 1 test set mcc of 0.44307094023030213 valid set mcc of 0.2689685595408976
# for fold 2 test set mcc of 0.2728081531385263 valid set mcc of 0.43937477516374684
# for fold 3 test set mcc of 0.3912540225287499 valid set mcc of 0.40465131911125596
# for fold 4 test set mcc of 0.4161302305621534 valid set mcc of 0.06988565578146122
# for fold 5 test set mcc of 0.5025129006975967 valid set mcc of 0.24330705965545607
#
# validation metrics of:
# positives in data 85
# negatives in data 53
# net accuracy = 0.6594202898550725
# mcc = 0.2776001824549361
# ========================================
# For dataset SR-ATAD5_Avafp.csv
# for fold 1 test set mcc of 0.7515293607641007 valid set mcc of 0.4902903378454601
# for fold 2 test set mcc of 0.6076555023923444 valid set mcc of 0.2919059268087842
# for fold 3 test set mcc of 0.4806307859271526 valid set mcc of 0.3194444444444444
# for fold 4 test set mcc of 0.44114814843152456 valid set mcc of 0.28867513459481287
# for fold 5 test set mcc of 0.5204800389058843 valid set mcc of 0.19389168358237033
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7884615384615384
# mcc = 0.5767665556788754
# ========================================
# For dataset Cardiotoxicity-30_Morganfp.csv
# for fold 1 test set mcc of 0.2041241452319315 valid set mcc of 0.48980536649995393
# for fold 2 test set mcc of 0.4299227963073111 valid set mcc of 0.47062521738438035
# for fold 3 test set mcc of 0.5496472302018778 valid set mcc of 0.3278050340535929
# for fold 4 test set mcc of 0.5160898219748689 valid set mcc of 0.21245914639969937
# for fold 5 test set mcc of 0.4848966613672496 valid set mcc of 0.4490132550669373
#
# validation metrics of:
# positives in data 85
# negatives in data 53
# net accuracy = 0.717391304347826
# mcc = 0.38216869538298137
# ========================================
# For dataset Carcinogenicity_MACCSfp.csv
# for fold 1 test set mcc of 0.49265895172303803 valid set mcc of 0.44243006570095994
# for fold 2 test set mcc of 0.385976276239604 valid set mcc of 0.2530481037386396
# for fold 3 test set mcc of 0.4247821035644882 valid set mcc of 0.3637519089328994
# for fold 4 test set mcc of 0.4879500364742666 valid set mcc of 0.27876067571135493
# for fold 5 test set mcc of 0.31660467647960244 valid set mcc of 0.439004122479377
#
# validation metrics of:
# positives in data 102
# negatives in data 103
# net accuracy = 0.6780487804878049
# mcc = 0.35748270369582325

# %%
len(finalresults)
# Out:
# 88

# %%
temp = pd.DataFrame(finalresults, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Model_Outputs/RF_Fingerprint_Results.csv')
