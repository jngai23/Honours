# %%
#30/7/24 Creates a K fold KNN model for each file in a folder provided they are Fingerprints
import os
import pandas as pd
import numpy as np
import math
import sys

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Fingerprints/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df.drop(columns=['SMILES'], inplace=True)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    threshlist = []
    finalresults = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        
        
        keras.utils.set_random_seed(seed)
        tf.config.experimental.enable_op_determinism()
        length = len(xtrain.columns)
        sampcount = len(ytrain)
        temp = length
        # Encoder Creation
        enc_in = keras.Input(shape=(length, 1))
        x = keras.layers.Flatten()(enc_in)
        # Additional encoder layers
        
        layer1 = math.sqrt(3*sampcount) + 2*(math.sqrt(sampcount/(3)))
        x = keras.layers.Dense(layer1, activation="relu")(x)
        
        layer2 = math.sqrt(sampcount / 3)
        x = keras.layers.Dense(layer2, activation="relu")(x)
        
        enc_out = keras.layers.Dense(1, activation="sigmoid")(x)
        autoencoder = keras.Model(enc_in, enc_out, name='autoencoder')
        # Optimiser
        
        optimise = tf.keras.optimizers.legacy.Adam(learning_rate=0.0001)

        autoencoder.compile(optimise, loss='binary_crossentropy')
        #autoencoder.summary()
        
        ytrain = np.array(ytrain)
        epochs = 500
        batchsize = 16
        losshistory = []

        minloss = 1
        bestepoch = 0
        for epoch in range(epochs):
            verb = 0
            logs = autoencoder.fit(
            xtrain,
            ytrain,
            verbose = verb,
            epochs=1,
            batch_size=batchsize),
            validation_split=0.2,

            #autoencoder.save(str(f"models/AE-{epoch+1}.keras"))
            loss = logs[0].history['loss'][0]
            losshistory.append(loss)
            if loss < minloss:
                minloss = loss
                bestepoch = epoch

        model_list.append(autoencoder)
    
        preds = autoencoder.predict(xtest)

        epochcount = range(epochs)

        acclist = []
        thresholdlist = []
        maxval = 0
        bestthresh = 0
        for threshold in np.arange(0, 1, 0.01):
            newval = nnmetrics(preds, ytest, threshold)[12]
            acclist.append(newval)
            thresholdlist.append(threshold)
            if newval > maxval:
                maxval = newval
                bestthresh = threshold
        threshlist.append(bestthresh)
        testdat.append(maxval)
        y_values = acclist
        x_values = thresholdlist
        preds = autoencoder.predict(xvalid)
        results = nnmetrics(preds, yvalid, bestthresh)
        validlist.append(results)
        print('for fold', split + 1, 'optimal test mcc of', maxval, 'validation mcc of', results[12])

        iteration = iteration + 1

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        

    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []

    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        fp = np.asarray(fp).astype('float32')
        #appends each model's prediction to a list
        predlist = []
        for model in model_list:
            preds = model.predict(fp, verbose = 0)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        loops = 0
        for modelpreds in predlist:
            if modelpreds < threshlist[loops]:
                zercount = zercount + 1
        loops = loops + 1

        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)

    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    finalresults.append(results[12])
    del autoencoder
    gc.collect
    
    sets += 1
# Out:
# ========================================
# For dataset NR-AR-LBD_Avafp.csv
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 792us/step
# for fold 1 optimal test mcc of 0.6871657754010695 validation mcc of 0.48122447405980645
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 732us/step
# for fold 2 optimal test mcc of 0.5786882152809495 validation mcc of 0.46046933104270676
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 707us/step
# for fold 3 optimal test mcc of 0.610170215847752 validation mcc of 0.4308571590681121
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 789us/step
# for fold 4 optimal test mcc of 0.7378647873726218 validation mcc of 0.4947753344488257
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 758us/step
# for fold 5 optimal test mcc of 0.5693438283463509 validation mcc of 0.5786882152809495
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2fcc5ade0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x29e41d1c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7604166666666666
# mcc = 0.5248138373964939
# ========================================
# For dataset SR-ATAD5_Morganfp.csv
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 838us/step
# for fold 1 optimal test mcc of 0.6431758808251548 validation mcc of 0.3922322702763681
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 844us/step
# for fold 2 optimal test mcc of 0.5155145946859746 validation mcc of 0.4735570640442169
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 1ms/step
# for fold 3 optimal test mcc of 0.435 validation mcc of 0.5784074945196682
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 850us/step
# for fold 4 optimal test mcc of 0.30158730158730157 validation mcc of 0.4472135954999579
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 864us/step
# for fold 5 optimal test mcc of 0.28735244660769566 validation mcc of 0.42163702135578396
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7596153846153846
# mcc = 0.5204516811898856
# ========================================
# For dataset NR-aromatase_TTorsionfp.csv
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 715us/step
# for fold 1 optimal test mcc of 0.42497294818489706 validation mcc of 0.5509189647176967
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 812us/step
# for fold 2 optimal test mcc of 0.3768673314407159 validation mcc of 0.38731272671062317
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 753us/step
# for fold 3 optimal test mcc of 0.16167794359700183 validation mcc of 0.37107422226742265
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 863us/step
# for fold 4 optimal test mcc of 0.5420948727258311 validation mcc of 0.30641293851417056
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 915us/step
# for fold 5 optimal test mcc of 0.36612568497742837 validation mcc of 0.3761626197515065
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7520661157024794
# mcc = 0.503031466565012
# ========================================
# For dataset NR-PPAR-gamma_Avafp.csv
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 12ms/step
# for fold 1 optimal test mcc of 0.7364853795464743 validation mcc of 0.14433756729740643
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 2 optimal test mcc of 0.3458371816572483 validation mcc of 0.3888888888888889
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 3 optimal test mcc of 0.41884628049226685 validation mcc of 0.4708709557974187
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 4 optimal test mcc of 0.5296011094822547 validation mcc of 0.27865801780244004
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 5 optimal test mcc of 0.43822991060110733 validation mcc of 0.29554023164452436
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.6438356164383562
# mcc = 0.2903498804081948
# ========================================
# For dataset NR-AhR_Morganfp.csv
# 5/5 [==============================] - 0s 741us/step
# 5/5 [==============================] - 0s 602us/step
# for fold 1 optimal test mcc of 0.5361333036005725 validation mcc of 0.46
# 5/5 [==============================] - 0s 602us/step
# 5/5 [==============================] - 0s 523us/step
# for fold 2 optimal test mcc of 0.551015445038995 validation mcc of 0.4704083171859687
# 5/5 [==============================] - 0s 754us/step
# 5/5 [==============================] - 0s 524us/step
# for fold 3 optimal test mcc of 0.5330040553840283 validation mcc of 0.465781704427852
# 5/5 [==============================] - 0s 628us/step
# 5/5 [==============================] - 0s 634us/step
# for fold 4 optimal test mcc of 0.5321641669416961 validation mcc of 0.4549152542372881
# 5/5 [==============================] - 0s 878us/step
# 5/5 [==============================] - 0s 572us/step
# for fold 5 optimal test mcc of 0.5380952380952381 validation mcc of 0.5778283952984204
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.7850746268656716
# mcc = 0.5705114240311229
# ========================================
# For dataset NR-AR_Avafp.csv
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 773us/step
# for fold 1 optimal test mcc of 0.5169082125603864 validation mcc of 0.4174393166995065
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 792us/step
# for fold 2 optimal test mcc of 0.4341670042753564 validation mcc of 0.4457424941602093
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 807us/step
# for fold 3 optimal test mcc of 0.3200013331999566 validation mcc of 0.3521892988603379
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 739us/step
# for fold 4 optimal test mcc of 0.6553607444452058 validation mcc of 0.22017621148199482
# 2/2 [==============================] - 0s 957us/step
# 2/2 [==============================] - 0s 822us/step
# for fold 5 optimal test mcc of 0.5391800344720129 validation mcc of 0.5293777781178295
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.68
# mcc = 0.37114010115392376
# ========================================
# For dataset Hepatotoxicity_Morganfp.csv
# 8/8 [==============================] - 0s 714us/step
# 8/8 [==============================] - 0s 489us/step
# for fold 1 optimal test mcc of 0.45418633434205224 validation mcc of 0.35032448485149137
# 8/8 [==============================] - 0s 779us/step
# 8/8 [==============================] - 0s 565us/step
# for fold 2 optimal test mcc of 0.48374383424080136 validation mcc of 0.35441354799467134
# 8/8 [==============================] - 0s 681us/step
# 8/8 [==============================] - 0s 498us/step
# for fold 3 optimal test mcc of 0.45268663757863004 validation mcc of 0.3872723137560331
# 8/8 [==============================] - 0s 829us/step
# 8/8 [==============================] - 0s 673us/step
# for fold 4 optimal test mcc of 0.3436856069281347 validation mcc of 0.3781359338351391
# 8/8 [==============================] - 0s 632us/step
# 8/8 [==============================] - 0s 507us/step
# for fold 5 optimal test mcc of 0.4294542524608862 validation mcc of 0.42290140816864585
#
# validation metrics of:
# positives in data 293
# negatives in data 285
# net accuracy = 0.7024221453287197
# mcc = 0.41026516352225684
# ========================================
# For dataset Cardiotoxicity-5_Morganfp.csv
# 4/4 [==============================] - 0s 857us/step
# 4/4 [==============================] - 0s 587us/step
# for fold 1 optimal test mcc of 0.4678027878792997 validation mcc of 0.2492308004498208
# 4/4 [==============================] - 0s 645us/step
# 4/4 [==============================] - 0s 556us/step
# for fold 2 optimal test mcc of 0.4772068511198946 validation mcc of 0.3097573725546186
# 4/4 [==============================] - 0s 850us/step
# 4/4 [==============================] - 0s 720us/step
# for fold 3 optimal test mcc of 0.4678027878792997 validation mcc of 0.30850705806585615
# 4/4 [==============================] - 0s 734us/step
# 4/4 [==============================] - 0s 596us/step
# for fold 4 optimal test mcc of 0.48882701686587343 validation mcc of 0.44954746199884665
# 4/4 [==============================] - 0s 834us/step
# 4/4 [==============================] - 0s 606us/step
# for fold 5 optimal test mcc of 0.3222330522753963 validation mcc of 0.37697420773644663
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.6935483870967742
# mcc = 0.38162138987548994
# ========================================
# For dataset NR-PPAR-gamma_Morganfp.csv
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 1 optimal test mcc of 0.600099198148979 validation mcc of 0.533001790889026
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 2 optimal test mcc of 0.34097383755170546 validation mcc of 0.3860440160957241
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 3 optimal test mcc of 0.5554932406347733 validation mcc of 0.45226701686664544
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 4 optimal test mcc of 0.3234929166885531 validation mcc of 0.3574660633484163
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 10ms/step
# for fold 5 optimal test mcc of 0.55 validation mcc of 0.24046373977128355
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.7534246575342466
# mcc = 0.5345278582597408
# ========================================
# For dataset Cardiotoxicity-10_MACCSfp.csv
# 4/4 [==============================] - 0s 867us/step
# 4/4 [==============================] - 0s 635us/step
# for fold 1 optimal test mcc of 0.36631641274500887 validation mcc of 0.30012252399939043
# 4/4 [==============================] - 0s 694us/step
# 4/4 [==============================] - 0s 481us/step
# for fold 2 optimal test mcc of 0.4276217301981449 validation mcc of 0.3725954832386315
# 4/4 [==============================] - 0s 710us/step
# 4/4 [==============================] - 0s 506us/step
# for fold 3 optimal test mcc of 0.2656940066982718 validation mcc of 0.27595802701601524
# 4/4 [==============================] - 0s 653us/step
# 4/4 [==============================] - 0s 562us/step
# for fold 4 optimal test mcc of 0.30303119009885726 validation mcc of 0.29497937809649544
# 4/4 [==============================] - 0s 732us/step
# 4/4 [==============================] - 0s 536us/step
# for fold 5 optimal test mcc of 0.49379385839759304 validation mcc of 0.3456725946836821
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.7032258064516129
# mcc = 0.34692828577852175
# ========================================
# For dataset NR-PPAR-gamma_TTorsionfp.csv
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 1 optimal test mcc of 0.5766967882001441 validation mcc of 0.14433756729740643
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 10ms/step
# for fold 2 optimal test mcc of 0.24503848605703313 validation mcc of 0.14433756729740643
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 3 optimal test mcc of 0.20116856232719482 validation mcc of 0.48420012470625223
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 4 optimal test mcc of 0.48214285714285715 validation mcc of 0.3082573996425538
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 5 optimal test mcc of 0.4 validation mcc of 0.04222003309207491
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.6027397260273972
# mcc = 0.20578403867374412
# ========================================
# For dataset Cardiotoxicity-10_Morganfp.csv
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 737us/step
# for fold 1 optimal test mcc of 0.3812452624810589 validation mcc of 0.34710810562170585
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 690us/step
# for fold 2 optimal test mcc of 0.48234438358940424 validation mcc of 0.349236740635355
# 4/4 [==============================] - 0s 847us/step
# 4/4 [==============================] - 0s 629us/step
# for fold 3 optimal test mcc of 0.40855791854023066 validation mcc of 0.4902205682482089
# 4/4 [==============================] - 0s 738us/step
# 4/4 [==============================] - 0s 574us/step
# for fold 4 optimal test mcc of 0.33110182889466505 validation mcc of 0.4951157386963296
# 4/4 [==============================] - 0s 842us/step
# 4/4 [==============================] - 0s 620us/step
# for fold 5 optimal test mcc of 0.4705962533382046 validation mcc of 0.3853307035500116
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.6838709677419355
# mcc = 0.3142734621478508
# ========================================
# For dataset SR-MMP_Morganfp.csv
# 6/6 [==============================] - 0s 729us/step
# 6/6 [==============================] - 0s 541us/step
# for fold 1 optimal test mcc of 0.5952836019672005 validation mcc of 0.4541972990585293
# 6/6 [==============================] - 0s 717us/step
# 6/6 [==============================] - 0s 527us/step
# for fold 2 optimal test mcc of 0.6055743719775049 validation mcc of 0.5402864288560627
# 6/6 [==============================] - 0s 903us/step
# 6/6 [==============================] - 0s 563us/step
# for fold 3 optimal test mcc of 0.38002736295523465 validation mcc of 0.5023153818963965
# 6/6 [==============================] - 0s 844us/step
# 6/6 [==============================] - 0s 610us/step
# for fold 4 optimal test mcc of 0.5736572862117751 validation mcc of 0.4581358460345214
# 6/6 [==============================] - 0s 703us/step
# 6/6 [==============================] - 0s 529us/step
# for fold 5 optimal test mcc of 0.651575722936976 validation mcc of 0.4991808207651263
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7582938388625592
# mcc = 0.5008608532677481
# ========================================
# For dataset SR-ARE_TTorsionfp.csv
# 6/6 [==============================] - 0s 590us/step
# 6/6 [==============================] - 0s 437us/step
# for fold 1 optimal test mcc of 0.38606481356256656 validation mcc of 0.2594286294661387
# 6/6 [==============================] - 0s 724us/step
# 6/6 [==============================] - 0s 507us/step
# for fold 2 optimal test mcc of 0.3242318758419489 validation mcc of 0.3147876717164867
# 6/6 [==============================] - 0s 594us/step
# 6/6 [==============================] - 0s 467us/step
# for fold 3 optimal test mcc of 0.2100906102931654 validation mcc of 0.17014497764136072
# 6/6 [==============================] - 0s 547us/step
# 6/6 [==============================] - 0s 484us/step
# for fold 4 optimal test mcc of 0.3246861882798744 validation mcc of 0.3324967857801223
# 6/6 [==============================] - 0s 590us/step
# 6/6 [==============================] - 0s 425us/step
# for fold 5 optimal test mcc of 0.36699012778230794 validation mcc of 0.1999417458294882
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.6768867924528302
# mcc = 0.3257074870725125
# ========================================
# For dataset Hepatotoxicity_Avafp.csv
# 8/8 [==============================] - 0s 749us/step
# 8/8 [==============================] - 0s 423us/step
# for fold 1 optimal test mcc of 0.5001403571054212 validation mcc of 0.3698967791053061
# 8/8 [==============================] - 0s 559us/step
# 8/8 [==============================] - 0s 397us/step
# for fold 2 optimal test mcc of 0.4205355429582196 validation mcc of 0.37892501786237764
# 8/8 [==============================] - 0s 450us/step
# 8/8 [==============================] - 0s 430us/step
# for fold 3 optimal test mcc of 0.477989475373324 validation mcc of 0.3701234072753513
# 8/8 [==============================] - 0s 512us/step
# 8/8 [==============================] - 0s 480us/step
# for fold 4 optimal test mcc of 0.4391212619379937 validation mcc of 0.4043020583292216
# 8/8 [==============================] - 0s 603us/step
# 8/8 [==============================] - 0s 467us/step
# for fold 5 optimal test mcc of 0.3717156459176547 validation mcc of 0.44207318084940267
#
# validation metrics of:
# positives in data 293
# negatives in data 285
# net accuracy = 0.740484429065744
# mcc = 0.4875738682371073
# ========================================
# For dataset Reproductive_Toxicity_Morganfp.csv
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 1 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 2 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 3 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 4 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 10ms/step
# for fold 5 optimal test mcc of 0 validation mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-ER-LBD_MACCSfp.csv
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 797us/step
# for fold 1 optimal test mcc of 0.5940360703516688 validation mcc of 0.4214433884673491
# 2/2 [==============================] - 0s 881us/step
# 2/2 [==============================] - 0s 739us/step
# for fold 2 optimal test mcc of 0.6783484662059833 validation mcc of 0.3434840149394188
# 2/2 [==============================] - 0s 968us/step
# 2/2 [==============================] - 0s 740us/step
# for fold 3 optimal test mcc of 0.4814165682409486 validation mcc of 0.5180912448437586
# 2/2 [==============================] - 0s 796us/step
# 2/2 [==============================] - 0s 751us/step
# for fold 4 optimal test mcc of 0.40323139339254793 validation mcc of 0.4055558216516248
# 2/2 [==============================] - 0s 863us/step
# 2/2 [==============================] - 0s 725us/step
# for fold 5 optimal test mcc of 0.50709255283711 validation mcc of 0.41300383394253937
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.684931506849315
# mcc = 0.3723019609620799
# ========================================
# For dataset Developmental_Toxicity_Avafp.csv
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 1 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 2 optimal test mcc of 0.16666666666666666 validation mcc of 0.0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 3 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 4 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 5 optimal test mcc of 0 validation mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Cardiotoxicity-1_Avafp.csv
# 4/4 [==============================] - 0s 552us/step
# 4/4 [==============================] - 0s 570us/step
# for fold 1 optimal test mcc of 0.4012572858800745 validation mcc of 0.5345490800747327
# 4/4 [==============================] - 0s 667us/step
# 4/4 [==============================] - 0s 508us/step
# for fold 2 optimal test mcc of 0.46905320708288617 validation mcc of 0.5387274194264797
# 4/4 [==============================] - 0s 585us/step
# 4/4 [==============================] - 0s 507us/step
# for fold 3 optimal test mcc of 0.45712221373944584 validation mcc of 0.3262834983100309
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 607us/step
# for fold 4 optimal test mcc of 0.44824018338037624 validation mcc of 0.29855619650098675
# 4/4 [==============================] - 0s 763us/step
# 4/4 [==============================] - 0s 516us/step
# for fold 5 optimal test mcc of 0.47367006517174803 validation mcc of 0.490842415109619
#
# validation metrics of:
# positives in data 70
# negatives in data 240
# net accuracy = 0.8290322580645161
# mcc = 0.4678893577153772
# ========================================
# For dataset Cardiotoxicity-30_TTorsionfp.csv
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 972us/step
# for fold 1 optimal test mcc of 0.408248290463863 validation mcc of 0.408248290463863
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 855us/step
# for fold 2 optimal test mcc of 0.4446177584499821 validation mcc of 0.3779644730092272
# 2/2 [==============================] - 0s 968us/step
# 2/2 [==============================] - 0s 739us/step
# for fold 3 optimal test mcc of 0.25271739130434784 validation mcc of 0.4214636152117623
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 765us/step
# for fold 4 optimal test mcc of 0.5318302387267905 validation mcc of 0.12222646627042816
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 818us/step
# for fold 5 optimal test mcc of 0.598089167121675 validation mcc of 0.42401356865129874
#
# validation metrics of:
# positives in data 85
# negatives in data 53
# net accuracy = 0.6666666666666666
# mcc = 0.28135195342834307
# ========================================
# For dataset NR-ER-LBD_Morganfp.csv
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 896us/step
# for fold 1 optimal test mcc of 0.5247368153167122 validation mcc of 0.35334967211447943
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 802us/step
# for fold 2 optimal test mcc of 0.4208513887366961 validation mcc of 0.4446141198869673
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# for fold 3 optimal test mcc of 0.3763493004997114 validation mcc of 0.5379519296838619
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# for fold 4 optimal test mcc of 0.42420801505049993 validation mcc of 0.40982808233692364
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# for fold 5 optimal test mcc of 0.6349812749303677 validation mcc of 0.3802528761961016
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.6301369863013698
# mcc = 0.25828342543771304
# ========================================
# For dataset Reproductive_Toxicity_MACCSfp.csv
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 1 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 2 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 3 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 4 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 5 optimal test mcc of 0 validation mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Carcinogenicity_Morganfp.csv
# 3/3 [==============================] - 0s 767us/step
# 3/3 [==============================] - 0s 802us/step
# for fold 1 optimal test mcc of 0.29277002188455997 validation mcc of 0.36589300212854187
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# for fold 2 optimal test mcc of 0.3544008793513255 validation mcc of 0.4855072463768116
# 3/3 [==============================] - 0s 900us/step
# 3/3 [==============================] - 0s 835us/step
# for fold 3 optimal test mcc of 0.36882995975881117 validation mcc of 0.008213708208229555
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 859us/step
# for fold 4 optimal test mcc of 0.35 validation mcc of 0.2625073660650015
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# for fold 5 optimal test mcc of 0.3838260248329035 validation mcc of 0.12268281700245945
#
# validation metrics of:
# positives in data 102
# negatives in data 103
# net accuracy = 0.6487804878048781
# mcc = 0.2978546746688482
# ========================================
# For dataset SR-MMP_MACCSfp.csv
# 6/6 [==============================] - 0s 514us/step
# 6/6 [==============================] - 0s 416us/step
# for fold 1 optimal test mcc of 0.6507380384048327 validation mcc of 0.533047672401551
# 6/6 [==============================] - 0s 414us/step
# 6/6 [==============================] - 0s 393us/step
# for fold 2 optimal test mcc of 0.5649670829091727 validation mcc of 0.5570762958648806
# 6/6 [==============================] - 0s 551us/step
# 6/6 [==============================] - 0s 416us/step
# for fold 3 optimal test mcc of 0.5302629430525103 validation mcc of 0.5777058286086858
# 6/6 [==============================] - 0s 448us/step
# 6/6 [==============================] - 0s 400us/step
# for fold 4 optimal test mcc of 0.6673832181543405 validation mcc of 0.5300865661660354
# 6/6 [==============================] - 0s 551us/step
# 6/6 [==============================] - 0s 400us/step
# for fold 5 optimal test mcc of 0.6394628789325651 validation mcc of 0.589218536892646
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7464454976303317
# mcc = 0.5090794223278491
# ========================================
# For dataset NR-AhR_MACCSfp.csv
# 5/5 [==============================] - 0s 803us/step
# 5/5 [==============================] - 0s 493us/step
# for fold 1 optimal test mcc of 0.5978387186085153 validation mcc of 0.534284017391466
# 5/5 [==============================] - 0s 616us/step
# 5/5 [==============================] - 0s 485us/step
# for fold 2 optimal test mcc of 0.5672330152685972 validation mcc of 0.5373737773623342
# 5/5 [==============================] - 0s 810us/step
# 5/5 [==============================] - 0s 489us/step
# for fold 3 optimal test mcc of 0.5608349278890049 validation mcc of 0.6457292047268526
# 5/5 [==============================] - 0s 623us/step
# 5/5 [==============================] - 0s 415us/step
# for fold 4 optimal test mcc of 0.6256052969545892 validation mcc of 0.6208547669692656
# 5/5 [==============================] - 0s 628us/step
# 5/5 [==============================] - 0s 432us/step
# for fold 5 optimal test mcc of 0.5477225575051661 validation mcc of 0.6042625676811025
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.8059701492537313
# mcc = 0.606896694544224
# ========================================
# For dataset NR-PPAR-gamma_MACCSfp.csv
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 1 optimal test mcc of 0.6533052580081484 validation mcc of 0.22291128503014115
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 2 optimal test mcc of 0.5688871689000486 validation mcc of 0.3844645254667628
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 3 optimal test mcc of 0.4794833742895531 validation mcc of 0.565685424949238
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 4 optimal test mcc of 0.5865557254410011 validation mcc of 0.23782574707724705
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 5 optimal test mcc of 0.4183300132670378 validation mcc of 0.22927937978192153
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.5068493150684932
# mcc = 0.029432140021596564
# ========================================
# For dataset SR-ARE_Avafp.csv
# 6/6 [==============================] - 0s 705us/step
# 6/6 [==============================] - 0s 508us/step
# for fold 1 optimal test mcc of 0.4309160915979127 validation mcc of 0.42905711039729555
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 613us/step
# for fold 2 optimal test mcc of 0.3772682274687783 validation mcc of 0.3765562564133454
# 6/6 [==============================] - 0s 605us/step
# 6/6 [==============================] - 0s 518us/step
# for fold 3 optimal test mcc of 0.47336692165683214 validation mcc of 0.5176894836105813
# 6/6 [==============================] - 0s 643us/step
# 6/6 [==============================] - 0s 497us/step
# for fold 4 optimal test mcc of 0.2830419100869371 validation mcc of 0.48401760714786146
# 6/6 [==============================] - 0s 578us/step
# 6/6 [==============================] - 0s 441us/step
# for fold 5 optimal test mcc of 0.36933150872689186 validation mcc of 0.44101158226470627
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7099056603773585
# mcc = 0.3980202239421227
# ========================================
# For dataset NR-ER-LBD_Avafp.csv
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 758us/step
# for fold 1 optimal test mcc of 0.5285084312760371 validation mcc of 0.46668523451860866
# 2/2 [==============================] - 0s 896us/step
# 2/2 [==============================] - 0s 787us/step
# for fold 2 optimal test mcc of 0.5331668756526732 validation mcc of 0.3434840149394188
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 759us/step
# for fold 3 optimal test mcc of 0.4423076923076923 validation mcc of 0.3740052566820346
# 2/2 [==============================] - 0s 948us/step
# 2/2 [==============================] - 0s 912us/step
# for fold 4 optimal test mcc of 0.37259615384615385 validation mcc of 0.4385566936919029
# 2/2 [==============================] - 0s 817us/step
# 2/2 [==============================] - 0s 787us/step
# for fold 5 optimal test mcc of 0.4693339858180978 validation mcc of 0.36886386424569245
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7123287671232876
# mcc = 0.43142098500564113
# ========================================
# For dataset NR-AR_Morganfp.csv
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 818us/step
# for fold 1 optimal test mcc of 0.6002099318605758 validation mcc of 0.5424327604368505
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 956us/step
# for fold 2 optimal test mcc of 0.6564322015646866 validation mcc of 0.3611575592573076
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 865us/step
# for fold 3 optimal test mcc of 0.3595462477533374 validation mcc of 0.6082291325648282
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 826us/step
# for fold 4 optimal test mcc of 0.6371766120160759 validation mcc of 0.38697637169562726
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 901us/step
# for fold 5 optimal test mcc of 0.5496323529411765 validation mcc of 0.19611613513818404
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.712
# mcc = 0.44796757643182106
# ========================================
# For dataset Cardiotoxicity-5_MACCSfp.csv
# 4/4 [==============================] - 0s 696us/step
# 4/4 [==============================] - 0s 469us/step
# for fold 1 optimal test mcc of 0.4342084214324218 validation mcc of 0.182827400991189
# 4/4 [==============================] - 0s 557us/step
# 4/4 [==============================] - 0s 460us/step
# for fold 2 optimal test mcc of 0.46039042670631547 validation mcc of 0.3065202268086465
# 4/4 [==============================] - 0s 661us/step
# 4/4 [==============================] - 0s 610us/step
# for fold 3 optimal test mcc of 0.4045434552364592 validation mcc of 0.3214515285203248
# 4/4 [==============================] - 0s 497us/step
# 4/4 [==============================] - 0s 526us/step
# for fold 4 optimal test mcc of 0.30327256270294783 validation mcc of 0.503030303030303
# 4/4 [==============================] - 0s 549us/step
# 4/4 [==============================] - 0s 466us/step
# for fold 5 optimal test mcc of 0.34106679443414406 validation mcc of 0.36395847991016445
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.6903225806451613
# mcc = 0.407119734848667
# ========================================
# For dataset Respiratory_Toxicity_Avafp.csv
# 4/4 [==============================] - 0s 842us/step
# 4/4 [==============================] - 0s 498us/step
# for fold 1 optimal test mcc of 0.5241175301099288 validation mcc of 0.4665346754998075
# 4/4 [==============================] - 0s 617us/step
# 4/4 [==============================] - 0s 614us/step
# for fold 2 optimal test mcc of 0.6160360402613523 validation mcc of 0.3668255672105241
# 4/4 [==============================] - 0s 706us/step
# 4/4 [==============================] - 0s 506us/step
# for fold 3 optimal test mcc of 0.5935713583715229 validation mcc of 0.6587780963974609
# 4/4 [==============================] - 0s 676us/step
# 4/4 [==============================] - 0s 559us/step
# for fold 4 optimal test mcc of 0.5961883443589163 validation mcc of 0.5861898270389748
# 4/4 [==============================] - 0s 578us/step
# 4/4 [==============================] - 0s 465us/step
# for fold 5 optimal test mcc of 0.5882102220125542 validation mcc of 0.5170595310415245
#
# validation metrics of:
# positives in data 164
# negatives in data 106
# net accuracy = 0.7444444444444445
# mcc = 0.4547118910279882
# ========================================
# For dataset NR-ER_Morganfp.csv
# 5/5 [==============================] - 0s 771us/step
# 5/5 [==============================] - 0s 687us/step
# for fold 1 optimal test mcc of 0.21279437698364115 validation mcc of 0.1494979653269976
# 5/5 [==============================] - 0s 920us/step
# 5/5 [==============================] - 0s 580us/step
# for fold 2 optimal test mcc of 0.3192741208728346 validation mcc of 0.32541100054716715
# 5/5 [==============================] - 0s 793us/step
# 5/5 [==============================] - 0s 521us/step
# for fold 3 optimal test mcc of 0.2728070524916565 validation mcc of 0.28913668930179304
# 5/5 [==============================] - 0s 725us/step
# 5/5 [==============================] - 0s 618us/step
# for fold 4 optimal test mcc of 0.23403088855661086 validation mcc of 0.26717598669417125
# 5/5 [==============================] - 0s 752us/step
# 5/5 [==============================] - 0s 539us/step
# for fold 5 optimal test mcc of 0.23757425355816877 validation mcc of 0.3172769300670386
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6521739130434783
# mcc = 0.2696340790430041
# ========================================
# For dataset SR-ARE_Morganfp.csv
# 6/6 [==============================] - 0s 751us/step
# 6/6 [==============================] - 0s 578us/step
# for fold 1 optimal test mcc of 0.3966490927477637 validation mcc of 0.43746788498211625
# 6/6 [==============================] - 0s 647us/step
# 6/6 [==============================] - 0s 515us/step
# for fold 2 optimal test mcc of 0.36318803161504065 validation mcc of 0.29387050581882157
# 6/6 [==============================] - 0s 697us/step
# 6/6 [==============================] - 0s 685us/step
# for fold 3 optimal test mcc of 0.4656609235506919 validation mcc of 0.2497226843295101
# 6/6 [==============================] - 0s 668us/step
# 6/6 [==============================] - 0s 545us/step
# for fold 4 optimal test mcc of 0.37941579616892507 validation mcc of 0.3277063367823473
# 6/6 [==============================] - 0s 693us/step
# 6/6 [==============================] - 0s 574us/step
# for fold 5 optimal test mcc of 0.2990154989356951 validation mcc of 0.14532002458770774
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7264150943396226
# mcc = 0.4332986229744472
# ========================================
# For dataset NR-AR-LBD_Morganfp.csv
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 789us/step
# for fold 1 optimal test mcc of 0.845756645578146 validation mcc of 0.6592443967173135
# 2/2 [==============================] - 0s 814us/step
# 2/2 [==============================] - 0s 808us/step
# for fold 2 optimal test mcc of 0.6490229342872016 validation mcc of 0
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 755us/step
# for fold 3 optimal test mcc of 0.610170215847752 validation mcc of 0.7010681840159741
# 2/2 [==============================] - 0s 880us/step
# 2/2 [==============================] - 0s 770us/step
# for fold 4 optimal test mcc of 0.7022915233992105 validation mcc of 0.4542199791661351
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 949us/step
# for fold 5 optimal test mcc of 0.6900721388834448 validation mcc of 0.6854365268376295
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.75
# mcc = 0.49978289188015634
# ========================================
# For dataset Ames_Mutagenicity_Avafp.csv
# 19/19 [==============================] - 0s 496us/step
# 19/19 [==============================] - 0s 448us/step
# for fold 1 optimal test mcc of 0.6001198345646365 validation mcc of 0.5669379945573834
# 19/19 [==============================] - 0s 885us/step
# 19/19 [==============================] - 0s 476us/step
# for fold 2 optimal test mcc of 0.6420116065715153 validation mcc of 0.5938686400465556
# 19/19 [==============================] - 0s 431us/step
# 19/19 [==============================] - 0s 377us/step
# for fold 3 optimal test mcc of 0.6693039386271521 validation mcc of 0.5755222979916702
# 19/19 [==============================] - 0s 410us/step
# 19/19 [==============================] - 0s 392us/step
# for fold 4 optimal test mcc of 0.6217382124506434 validation mcc of 0.5573397170011973
# 19/19 [==============================] - 0s 434us/step
# 19/19 [==============================] - 0s 381us/step
# for fold 5 optimal test mcc of 0.6547632520285568 validation mcc of 0.5608999682928317
#
# validation metrics of:
# positives in data 839
# negatives in data 658
# net accuracy = 0.8036072144288577
# mcc = 0.622446955687276
# ========================================
# For dataset Reproductive_Toxicity_TTorsionfp.csv
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 1 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 2 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 3 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 10ms/step
# for fold 4 optimal test mcc of 0 validation mcc of 0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# for fold 5 optimal test mcc of 0 validation mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Ames_Mutagenicity_Morganfp.csv
# 19/19 [==============================] - 0s 721us/step
# 19/19 [==============================] - 0s 536us/step
# for fold 1 optimal test mcc of 0.5966218454213833 validation mcc of 0.5470892998920918
# 19/19 [==============================] - 0s 607us/step
# 19/19 [==============================] - 0s 570us/step
# for fold 2 optimal test mcc of 0.6587526009704956 validation mcc of 0.5727605393717712
# 19/19 [==============================] - 0s 722us/step
# 19/19 [==============================] - 0s 522us/step
# for fold 3 optimal test mcc of 0.6148014511553934 validation mcc of 0.5628421478148414
# 19/19 [==============================] - 0s 662us/step
# 19/19 [==============================] - 0s 515us/step
# for fold 4 optimal test mcc of 0.5983319979898829 validation mcc of 0.5451613502165782
# 19/19 [==============================] - 0s 615us/step
# 19/19 [==============================] - 0s 499us/step
# for fold 5 optimal test mcc of 0.5740837649307148 validation mcc of 0.5782036061910832
#
# validation metrics of:
# positives in data 839
# negatives in data 658
# net accuracy = 0.8102872411489646
# mcc = 0.6183520659265372
# ========================================
# For dataset Ames_Mutagenicity_TTorsionfp.csv
# 19/19 [==============================] - 0s 463us/step
# 19/19 [==============================] - 0s 424us/step
# for fold 1 optimal test mcc of 0.48149152708149595 validation mcc of 0.5287094436630629
# 19/19 [==============================] - 0s 436us/step
# 19/19 [==============================] - 0s 386us/step
# for fold 2 optimal test mcc of 0.5845008166179405 validation mcc of 0.528760570262583
# 19/19 [==============================] - 0s 442us/step
# 19/19 [==============================] - 0s 407us/step
# for fold 3 optimal test mcc of 0.5544714708727795 validation mcc of 0.4771684406274336
# 19/19 [==============================] - 0s 449us/step
# 19/19 [==============================] - 0s 392us/step
# for fold 4 optimal test mcc of 0.5112794109400792 validation mcc of 0.5382808661768286
# 19/19 [==============================] - 0s 435us/step
# 19/19 [==============================] - 0s 380us/step
# for fold 5 optimal test mcc of 0.5758029330573428 validation mcc of 0.5369875605671086
#
# validation metrics of:
# positives in data 839
# negatives in data 658
# net accuracy = 0.7768871075484302
# mcc = 0.5646783503639144
# ========================================
# For dataset NR-AR_MACCSfp.csv
# 2/2 [==============================] - 0s 896us/step
# 2/2 [==============================] - 0s 696us/step
# for fold 1 optimal test mcc of 0.6082291325648282 validation mcc of 0.2668549015130478
# 2/2 [==============================] - 0s 863us/step
# 2/2 [==============================] - 0s 827us/step
# for fold 2 optimal test mcc of 0.4787162492387211 validation mcc of 0.5216720300383332
# 2/2 [==============================] - 0s 835us/step
# 2/2 [==============================] - 0s 747us/step
# for fold 3 optimal test mcc of 0.358974358974359 validation mcc of 0.3931785497463923
# 2/2 [==============================] - 0s 888us/step
# 2/2 [==============================] - 0s 703us/step
# for fold 4 optimal test mcc of 0.5537765319092597 validation mcc of 0.38697637169562726
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 696us/step
# for fold 5 optimal test mcc of 0.6816381233958094 validation mcc of 0.41825095628565206
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.736
# mcc = 0.5274949660495826
# ========================================
# For dataset Hepatotoxicity_MACCSfp.csv
# 8/8 [==============================] - 0s 494us/step
# 8/8 [==============================] - 0s 376us/step
# for fold 1 optimal test mcc of 0.3272590848227912 validation mcc of 0.3241437598443527
# 8/8 [==============================] - 0s 400us/step
# 8/8 [==============================] - 0s 345us/step
# for fold 2 optimal test mcc of 0.4941237212097698 validation mcc of 0.39718137176690455
# 8/8 [==============================] - 0s 384us/step
# 8/8 [==============================] - 0s 503us/step
# for fold 3 optimal test mcc of 0.5212076285790874 validation mcc of 0.3923565449855032
# 8/8 [==============================] - 0s 465us/step
# 8/8 [==============================] - 0s 387us/step
# for fold 4 optimal test mcc of 0.4053843015675611 validation mcc of 0.4404518083940085
# 8/8 [==============================] - 0s 450us/step
# 8/8 [==============================] - 0s 375us/step
# for fold 5 optimal test mcc of 0.425643672166856 validation mcc of 0.39641384504296645
#
# validation metrics of:
# positives in data 293
# negatives in data 285
# net accuracy = 0.7162629757785467
# mcc = 0.4345671881086436
# ========================================
# For dataset NR-AR-LBD_MACCSfp.csv
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 752us/step
# for fold 1 optimal test mcc of 0.7385686213637485 validation mcc of 0.50709255283711
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 850us/step
# for fold 2 optimal test mcc of 0.5379289185083113 validation mcc of 0.4092455058494485
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 737us/step
# for fold 3 optimal test mcc of 0.6998964726756151 validation mcc of 0.4353577159671462
# 2/2 [==============================] - 0s 841us/step
# 2/2 [==============================] - 0s 721us/step
# for fold 4 optimal test mcc of 0.7944444444444444 validation mcc of 0.4147575310031266
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 938us/step
# for fold 5 optimal test mcc of 0.6428785635743144 validation mcc of 0.5865557254410011
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.71875
# mcc = 0.4388443252279987
# ========================================
# For dataset Ames_Mutagenicity_MACCSfp.csv

# %%
temp = pd.DataFrame(finalresults, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Data/Model_Outputs/Fingerprint/NeuralNet_Fingerprint_Results')
resultframe
# Out:
#                                  Dataset  MCC
# 0            CarcinogenicityMorganfp.csv  0.0
# 1                    morganfp_SR-p53.csv  NaN
# 2                    morganfp_NR-AhR.csv  NaN
# 3                 morganfp_NR-ER-LBD.csv  NaN
# 4                  mutagenTTorsionfp.csv  NaN
# 5             morganfp_NR-PPAR-gamma.csv  NaN
# 6       Respiratory_ToxicityMorganfp.csv  NaN
# 7                     mutagenMACCSfp.csv  NaN
# 8    Reproductive_ToxicityTTorsionfp.csv  NaN
# 9               CarcinogenicityAvafp.csv  NaN
# 10         CarcinogenicityTTorsionfp.csv  NaN
# 11            CarcinogenicityMACCSfp.csv  NaN
# 12                    morganfp_NR-ER.csv  NaN
# 13         Respiratory_ToxicityAvafp.csv  NaN
# 14  Developmental_ToxicityTTorsionfp.csv  NaN
# 15                 morganfp_SR-ATAD5.csv  NaN
# 16    Developmental_ToxicityMorganfp.csv  NaN
# 17                   mutagenMorganfp.csv  NaN
# 18                      mutagenAvafp.csv  NaN
# 19        Reproductive_ToxicityAvafp.csv  NaN
# 20                   morganfp_SR-ARE.csv  NaN
# 21       Developmental_ToxicityAvafp.csv  NaN
# 22                    morganfp_NR-AR.csv  NaN
# 23     Reproductive_ToxicityMorganfp.csv  NaN
# 24     Developmental_ToxicityMACCSfp.csv  NaN
# 25                   morganfp_SR-HSE.csv  NaN
# 26                   morganfp_SR-MMP.csv  NaN
# 27    Respiratory_ToxicityTTorsionfp.csv  NaN
# 28       Respiratory_ToxicityMACCSfp.csv  NaN
# 29             morganfp_NR-aromatase.csv  NaN
# 30                morganfp_NR-AR-LBD.csv  NaN
# 31      Reproductive_ToxicityMACCSfp.csv  NaN

# %%
finalresults
# Out:
# [0]
