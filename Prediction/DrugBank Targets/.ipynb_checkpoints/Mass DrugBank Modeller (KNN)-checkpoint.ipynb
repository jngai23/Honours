# %%
#10/9/24 Creates a K fold KNN model for each file in a folder provided they are DB

import os
import pandas as pd
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Targets/Drugbank/datasets/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = df.drop(['Unnamed: 0', 'inchi'], axis = 1)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
finalresults = []
splitcount = 3
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / splitcount
    splitsize = math.ceil(size)
    empty = [[] for _ in range(splitcount)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,splitcount):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        
        length = len(xtrain)
        nneigh = 100
        if length < nneigh:
            nneigh = length
        for mtry in range(1, nneigh):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = KNeighborsClassifier(n_neighbors=mtry, weights='distance', 
                            algorithm='auto', leaf_size=100, p=2, metric='minkowski', 
                            metric_params=None, n_jobs=4)

            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = KNeighborsClassifier(n_neighbors=bestmetrics, weights='distance', 
                            algorithm='auto', leaf_size=100, p=2, metric='minkowski', 
                            metric_params=None, n_jobs=4)
        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    finalresults.append(results[12])
# Out:
# ========================================
# For dataset Cardiotoxicity_Cardiotoxicity-1_DBtargets.csv
# for fold 1 test set mcc of 0.4147575310031266 valid set mcc of 0.65
# for fold 2 test set mcc of 0.15811388300841897 valid set mcc of 0.5006939628599933
# for fold 3 test set mcc of 0.29277002188455997 valid set mcc of 0
#
# validation metrics of:
# positives in data 8
# negatives in data 12
# net accuracy = 0.65
# mcc = 0.23570226039551584
# ========================================
# For dataset Endocrine Disruption_SR-ARE_DBtargets.csv
# for fold 1 test set mcc of 0.5569045355497197 valid set mcc of 0.12804555422442268
# for fold 2 test set mcc of 0.2690951821386604 valid set mcc of -0.029160592175990215
# for fold 3 test set mcc of 0.299267063286242 valid set mcc of 0.23083009236969323
#
# validation metrics of:
# positives in data 37
# negatives in data 53
# net accuracy = 0.5222222222222223
# mcc = 0.17502302401383005
# ========================================
# For dataset Cardiotoxicity_Cardiotoxicity-5_DBtargets.csv
# for fold 1 test set mcc of 0.4596771955627792 valid set mcc of 0.26519741765271837
# for fold 2 test set mcc of 0.5417363388859614 valid set mcc of 0.12226666573419243
# for fold 3 test set mcc of 0.6853849062771005 valid set mcc of 0.1829719585206481
#
# validation metrics of:
# positives in data 21
# negatives in data 33
# net accuracy = 0.6481481481481481
# mcc = 0.26629315143831916
# ========================================
# For dataset Endocrine Disruption_SR-MMP_DBtargets.csv
# for fold 1 test set mcc of 0.6821865008193587 valid set mcc of 0.11129915212628864
# for fold 2 test set mcc of 0.4046171929194086 valid set mcc of 0.18480045471873585
# for fold 3 test set mcc of 0.5166358948230949 valid set mcc of 0.5488604301969738
#
# validation metrics of:
# positives in data 32
# negatives in data 43
# net accuracy = 0.68
# mcc = 0.3328770246548891
# ========================================
# For dataset Endocrine Disruption_NR-ER-LBD_DBtargets.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.40006613209931935 valid set mcc of 0.4113063728303113
# for fold 3 test set mcc of 0.29019050004400465 valid set mcc of 0.2721655269759087
#
# validation metrics of:
# positives in data 18
# negatives in data 21
# net accuracy = 0.5384615384615384
# mcc = 0.1649572197684645
# ========================================
# For dataset Carcinogenicity_Carcinogenicity_DBtargets.csv
# for fold 1 test set mcc of 0.24331548436407657 valid set mcc of 0.20938142159739226
# for fold 2 test set mcc of 0.2211629342323457 valid set mcc of 0
# for fold 3 test set mcc of 0.23592535771038772 valid set mcc of 0.17459497553883238
#
# validation metrics of:
# positives in data 12
# negatives in data 27
# net accuracy = 0.6153846153846154
# mcc = 0.030429030972509225
# ========================================
# For dataset Endocrine Disruption_SR-HSE_DBtargets.csv
# for fold 1 test set mcc of 0 valid set mcc of -0.05547001962252291
# for fold 2 test set mcc of 0.46088240084927024 valid set mcc of 0.5493502655735357
# for fold 3 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 12
# negatives in data 14
# net accuracy = 0.5384615384615384
# mcc = 0.18093671611393647
# ========================================
# For dataset Hepatotoxicity_Hepatotoxicity_DBtargets.csv
# for fold 1 test set mcc of 0.29630568382896155 valid set mcc of 0.2842617406720452
# for fold 2 test set mcc of 0.5142532992047641 valid set mcc of 0.375615846174271
# for fold 3 test set mcc of 0.31255083787994364 valid set mcc of 0.33409507754071555
#
# validation metrics of:
# positives in data 91
# negatives in data 73
# net accuracy = 0.6097560975609756
# mcc = 0.19169227962856555
# ========================================
# For dataset Endocrine Disruption_SR-ATAD5_DBtargets.csv
# for fold 1 test set mcc of 0.5773502691896257 valid set mcc of 0
# for fold 2 test set mcc of 0.03289758474798845 valid set mcc of -0.10050378152592121
# for fold 3 test set mcc of 0.31754264805429416 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Endocrine Disruption_NR-AR_DBtargets.csv
# for fold 1 test set mcc of 0.4878525788459435 valid set mcc of 0.35355339059327373
# for fold 2 test set mcc of 0.7009124021507408 valid set mcc of 0.7050707456243541
# for fold 3 test set mcc of 0.5159304318668514 valid set mcc of 0.3346716159128789
#
# validation metrics of:
# positives in data 23
# negatives in data 28
# net accuracy = 0.7254901960784313
# mcc = 0.47114400558710495
# ========================================
# For dataset Endocrine Disruption_NR-aromatase_DBtargets.csv
# for fold 1 test set mcc of 0.23063512107853829 valid set mcc of 0.1953363462243731
# for fold 2 test set mcc of 0.5523398999523437 valid set mcc of 0.23162640965743445
# for fold 3 test set mcc of 0.4195731958391368 valid set mcc of 0
#
# validation metrics of:
# positives in data 15
# negatives in data 18
# net accuracy = 0.6666666666666666
# mcc = 0.33210558207753577
# ========================================
# For dataset Mutagenicity_Ames Mutagenicity_DBtargets.csv
# for fold 1 test set mcc of 0 valid set mcc of 0.2458601059488743
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0.19245008972987526
#
# validation metrics of:
# positives in data 18
# negatives in data 60
# net accuracy = 0.717948717948718
# mcc = 0.14028563548635165
# ========================================
# For dataset Endocrine Disruption_NR-AhR_DBtargets.csv
# for fold 1 test set mcc of 0.5881182619831972 valid set mcc of -0.13731430681184992
# for fold 2 test set mcc of 0.3024116491930132 valid set mcc of 0.19493925957690475
# for fold 3 test set mcc of 0.57798165350068 valid set mcc of 0.03217447260438935
#
# validation metrics of:
# positives in data 22
# negatives in data 24
# net accuracy = 0.6521739130434783
# mcc = 0.30590258071629417
# ========================================
# For dataset Cardiotoxicity_Cardiotoxicity-30_DBtargets.csv
# for fold 1 test set mcc of 0.09759000729485333 valid set mcc of 0.1649915822768611
# for fold 2 test set mcc of 0.6666666666666666 valid set mcc of 0
# for fold 3 test set mcc of 0.37796447300922725 valid set mcc of -0.047619047619047616
#
# validation metrics of:
# positives in data 15
# negatives in data 9
# net accuracy = 0.625
# mcc = 0.11547005383792515
# ========================================
# For dataset Endocrine Disruption_SR-p53_DBtargets.csv
# for fold 1 test set mcc of 0.5488604301969738 valid set mcc of 0
# for fold 2 test set mcc of 0.5 valid set mcc of 0.38869157943029664
# for fold 3 test set mcc of 0.2160246899469287 valid set mcc of 0.31622776601683794
#
# validation metrics of:
# positives in data 19
# negatives in data 23
# net accuracy = 0.7142857142857143
# mcc = 0.4199942951621736
# ========================================
# For dataset Endocrine Disruption_NR-ER_DBtargets.csv
# for fold 1 test set mcc of 0.33472777435825257 valid set mcc of 0.412837477233712
# for fold 2 test set mcc of 0.5240934367753826 valid set mcc of 0.4319602248521752
# for fold 3 test set mcc of 0.4730480613727343 valid set mcc of 0.33910491408822535
#
# validation metrics of:
# positives in data 36
# negatives in data 62
# net accuracy = 0.5714285714285714
# mcc = 0.08865749924595245
# ========================================
# For dataset Cardiotoxicity_Cardiotoxicity-10_DBtargets.csv
# for fold 1 test set mcc of 0.2645751311064591 valid set mcc of 0.3867971017332104
# for fold 2 test set mcc of 0.48524850980819084 valid set mcc of -0.009405128133399417
# for fold 3 test set mcc of 0.3364192474471549 valid set mcc of -0.18341472143474843
#
# validation metrics of:
# positives in data 29
# negatives in data 25
# net accuracy = 0.5740740740740741
# mcc = 0.14117731575135795
# ========================================
# For dataset Endocrine Disruption_NR-AR-LBD_DBtargets.csv
# for fold 1 test set mcc of 0.7566444492037343 valid set mcc of 0
# for fold 2 test set mcc of 0.4800793585191832 valid set mcc of 0.6753246753246753
# for fold 3 test set mcc of 0.7237925541034954 valid set mcc of 0.5016881674068239
#
# validation metrics of:
# positives in data 17
# negatives in data 20
# net accuracy = 0.918918918918919
# mcc = 0.8387132838343627
# ========================================
# For dataset Endocrine Disruption_NR-PPAR-gamma_DBtargets.csv
# for fold 1 test set mcc of 0.31622776601683794 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0.09128709291752768 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0

# %%
finalresults
# Out:
# [0.5224392925598775,
#  0.33743567470752406,
#  0.4646785977740792,
#  0.4516591109168654,
#  0.5723387958404564,
#  0.5589979253939279,
#  0.381897590901659,
#  0.41156557439955455,
#  0.35349951843867855,
#  0.37841890351674645,
#  0.3926767941066129,
#  0.3863095765811034,
#  0.4442276861859421,
#  0.3308801538385406,
#  0.514525791312545,
#  0.05976143046671968,
#  0.3402804183494084,
#  -0.16666666666666666,
#  0.4077671491175933,
#  0.38940111458138327,
#  0.45383877172149034,
#  0.05976143046671968,
#  0.30000599502710085,
#  0.5305539523742169,
#  0.5720642066959932,
#  0.23529652646066698,
#  0.3773936184383908,
#  0.4657214663500352,
#  0,
#  0.3510045885850323,
#  0.5770485509757954,
#  0.2869749231780359,
#  0.3591556191769535,
#  0.6073664063908583,
#  0.5984209925969702,
#  0.05976143046671968,
#  0.5939723189065484,
#  0.5602117964757503,
#  0.4605346858287855,
#  0.42556070567620496,
#  0.6134162532192503,
#  0.614948522161922,
#  0.5274949660495826,
#  0.2903943999526783,
#  0.3275731085241172,
#  0.45992667090925055,
#  0.3071149881268544,
#  0.45207098530153456,
#  0.6305685768037953,
#  0,
#  0.49981502034776176,
#  0.3861822756557772,
#  0.41418632195946004,
#  0.3378519411762474,
#  0.26962910102155585,
#  0.42167948019344165,
#  0.449866942327967,
#  0.5945060965364305,
#  0.0,
#  0.3096395318037289,
#  0.3716938032170481,
#  0.40927265372891947,
#  0.24585044023959438,
#  0.31172131642952244,
#  0.32210056276318155,
#  0.42201647311072243,
#  0.24527567465267522,
#  -0.28867513459481287,
#  0.3927928887740745,
#  0.5395818099391085,
#  0.5165899598123257,
#  0.38575837490522974,
#  0.43843263386540193,
#  0.19582333967869303,
#  0.4852112926274516,
#  0.4158536074703739,
#  0.49135656026473973,
#  0.30605351152602067,
#  0.5278810206938803,
#  0.4697527309420669,
#  0.37232592565731115,
#  0.34490670846450067,
#  0.28755899927359346,
#  0.5594309277855158,
#  0.24991343555537843,
#  0.4808031967121333,
#  0.2288144891541078,
#  0.32685719622158743]

# %%
temp = pd.DataFrame(finalresults, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Figure_Development/DrugBank Targets/modelout/drugbank_knn.csv')

# %%
resultframe
# Out:
#                                  Dataset       MCC
# 0            CarcinogenicityMorganfp.csv  0.300006
# 1                    morganfp_SR-p53.csv  0.392793
# 2                    morganfp_NR-AhR.csv  0.572339
# 3                 morganfp_NR-ER-LBD.csv  0.453839
# 4                  mutagenTTorsionfp.csv  0.514638
# 5             morganfp_NR-PPAR-gamma.csv  0.353500
# 6       Respiratory_ToxicityMorganfp.csv  0.421679
# 7                     mutagenMACCSfp.csv  0.614949
# 8    Reproductive_ToxicityTTorsionfp.csv  0.000000
# 9               CarcinogenicityAvafp.csv  0.269629
# 10         CarcinogenicityTTorsionfp.csv  0.337852
# 11            CarcinogenicityMACCSfp.csv  0.326857
# 12                    morganfp_NR-ER.csv  0.286975
# 13         Respiratory_ToxicityAvafp.csv  0.577049
# 14  Developmental_ToxicityTTorsionfp.csv  0.000000
# 15                 morganfp_SR-ATAD5.csv  0.337436
# 16    Developmental_ToxicityMorganfp.csv  0.035088
# 17                   mutagenMorganfp.csv  0.645710
# 18                      mutagenAvafp.csv  0.617388
# 19        Reproductive_ToxicityAvafp.csv  0.000000
# 20                   morganfp_SR-ARE.csv  0.359156
# 21       Developmental_ToxicityAvafp.csv  0.066396
# 22                    morganfp_NR-AR.csv  0.000000
# 23     Reproductive_ToxicityMorganfp.csv  0.000000
# 24     Developmental_ToxicityMACCSfp.csv  0.104713
# 25                   morganfp_SR-HSE.csv  0.309640
# 26                   morganfp_SR-MMP.csv  0.444228
# 27    Respiratory_ToxicityTTorsionfp.csv  0.449867
# 28       Respiratory_ToxicityMACCSfp.csv  0.491357
# 29             morganfp_NR-aromatase.csv  0.409273
# 30                morganfp_NR-AR-LBD.csv  0.607366
# 31      Reproductive_ToxicityMACCSfp.csv  0.202610
