# %%
#23/8/24 Creates a K fold KNN model for each file in a folder provided they are chemopy

import os
import pandas as pd
import numpy as np
import math
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Fusion/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = df.drop(['Unnamed: 0', 'inchi'], axis = 1)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
splitcount = 3
resultslist = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / splitcount
    splitsize = math.ceil(size)
    empty = [[] for _ in range(splitcount)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,splitcount):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 4):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = mtry,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)


            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = bestmetrics,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)

        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 2 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    resultslist.append(results[12])
# Out:
# ========================================
# For dataset NR-ER-LBD_fusion.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.420827817635731 valid set mcc of 0.5125
# for fold 3 test set mcc of 0 valid set mcc of 0.5541466051858357
#
# validation metrics of:
# positives in data 18
# negatives in data 21
# net accuracy = 0.6923076923076923
# mcc = 0.3794016054674684
# ========================================
# For dataset Cardiotoxicity-1_fusion.csv
# for fold 1 test set mcc of 0 valid set mcc of 0.65
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 8
# negatives in data 12
# net accuracy = 0.7
# mcc = 0.3572172541558802
# ========================================
# For dataset Cardiotoxicity-10_fusion.csv
# for fold 1 test set mcc of 0.30303450170106633 valid set mcc of 0.5262976958009257
# for fold 2 test set mcc of 0.5629262517526437 valid set mcc of 0.09730393190744961
# for fold 3 test set mcc of 0.3495010688839122 valid set mcc of 0.538536841659474
#
# validation metrics of:
# positives in data 29
# negatives in data 25
# net accuracy = 0.6666666666666666
# mcc = 0.3296551724137931
# ========================================
# For dataset NR-aromatase_fusion.csv
# for fold 1 test set mcc of 0.17142178795424282 valid set mcc of 0.27789338971674993
# for fold 2 test set mcc of 0.6333333333333333 valid set mcc of 0
# for fold 3 test set mcc of 0.5095246653650681 valid set mcc of 0.26967994498529685
#
# validation metrics of:
# positives in data 15
# negatives in data 18
# net accuracy = 0.6363636363636364
# mcc = 0.260423717853257
# ========================================
# For dataset NR-ER_fusion.csv
# for fold 1 test set mcc of 0.41442486349116986 valid set mcc of 0.4104842631359055
# for fold 2 test set mcc of 0.4382846876811764 valid set mcc of 0.5203787324221011
# for fold 3 test set mcc of 0.3910867600715406 valid set mcc of 0
#
# validation metrics of:
# positives in data 36
# negatives in data 62
# net accuracy = 0.6530612244897959
# mcc = 0.17282528245507087
# ========================================
# For dataset Hepatotoxicity_fusion.csv
# for fold 1 test set mcc of 0.4305704853140126 valid set mcc of 0.2877800597784197
# for fold 2 test set mcc of 0.5110420979986198 valid set mcc of 0.3783912303223801
# for fold 3 test set mcc of 0.5148542090962764 valid set mcc of 0.3846999208876706
#
# validation metrics of:
# positives in data 91
# negatives in data 73
# net accuracy = 0.6341463414634146
# mcc = 0.24998092491339324
# ========================================
# For dataset SR-ARE_fusion.csv
# for fold 1 test set mcc of 0.6245007955370551 valid set mcc of 0.3783859483727242
# for fold 2 test set mcc of 0.3364523096642636 valid set mcc of 0.365115221656727
# for fold 3 test set mcc of 0.4594887975968556 valid set mcc of 0.36363636363636365
#
# validation metrics of:
# positives in data 37
# negatives in data 53
# net accuracy = 0.6222222222222222
# mcc = 0.17371791302640222
# ========================================
# For dataset SR-HSE_fusion.csv
# for fold 1 test set mcc of 0.42600643361512924 valid set mcc of 0.3952847075210474
# for fold 2 test set mcc of 0.36780617896031226 valid set mcc of 0.21428571428571427
# for fold 3 test set mcc of 0 valid set mcc of 0.1272937693043289
#
# validation metrics of:
# positives in data 12
# negatives in data 14
# net accuracy = 0.5769230769230769
# mcc = 0.13722155123693863
# ========================================
# For dataset SR-ATAD5_fusion.csv
# for fold 1 test set mcc of 0.31622776601683794 valid set mcc of -0.14907119849998599
# for fold 2 test set mcc of 0.03289758474798845 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0.21957751641341997
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-AR-LBD_fusion.csv
# for fold 1 test set mcc of 0.7566444492037343 valid set mcc of 0.761306166786451
# for fold 2 test set mcc of 0.5428571428571428 valid set mcc of 0.8376623376623377
# for fold 3 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-PPAR-gamma_fusion.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.05976143046671968 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0.2581988897471611
#
# validation metrics of:
# positives in data 7
# negatives in data 7
# net accuracy = 0.6428571428571429
# mcc = 0.31622776601683794
# ========================================
# For dataset NR-AR_fusion.csv
# for fold 1 test set mcc of 0 valid set mcc of 0.5793654595023211
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 23
# negatives in data 28
# net accuracy = 0.8627450980392157
# mcc = 0.7324231214502538
# ========================================
# For dataset Cardiotoxicity-5_fusion.csv
# for fold 1 test set mcc of 0.32348719116573565 valid set mcc of 0
# for fold 2 test set mcc of 0.3235531815621354 valid set mcc of 0
# for fold 3 test set mcc of 0.13241022442571243 valid set mcc of 0.45658558314607584
#
# validation metrics of:
# positives in data 21
# negatives in data 33
# net accuracy = 0.7037037037037037
# mcc = 0.35046881618922116
# ========================================
# For dataset SR-MMP_fusion.csv
# for fold 1 test set mcc of 0.40754331965559837 valid set mcc of 0.5552336962739256
# for fold 2 test set mcc of 0.613790951461876 valid set mcc of 0.2693828191582387
# for fold 3 test set mcc of 0.5761945405366717 valid set mcc of 0.627757664824853
#
# validation metrics of:
# positives in data 32
# negatives in data 43
# net accuracy = 0.7466666666666667
# mcc = 0.5122056727163324
# ========================================
# For dataset NR-AhR_fusion.csv
# for fold 1 test set mcc of 0.5084928361809214 valid set mcc of 0.3444233600968322
# for fold 2 test set mcc of 0.48911598804451845 valid set mcc of 0.49362682632474875
# for fold 3 test set mcc of 0.5637254901960784 valid set mcc of 0.4330127018922193
#
# validation metrics of:
# positives in data 22
# negatives in data 24
# net accuracy = 0.782608695652174
# mcc = 0.5643939393939394
# ========================================
# For dataset SR-p53_fusion.csv
# for fold 1 test set mcc of 0.6243713415848884 valid set mcc of 0.41761455180057855
# for fold 2 test set mcc of 0.17660431427533918 valid set mcc of 0.25133689839572193
# for fold 3 test set mcc of 0.32024493467004 valid set mcc of 0.31622776601683794
#
# validation metrics of:
# positives in data 19
# negatives in data 23
# net accuracy = 0.7380952380952381
# mcc = 0.4735570640442169
# ========================================
# For dataset Ames Mutagenicity_fusion.csv
# for fold 1 test set mcc of 0.12923301908921092 valid set mcc of 0.22363409850067592
# for fold 2 test set mcc of 0.14406143934002158 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 18
# negatives in data 60
# net accuracy = 0.8076923076923077
# mcc = 0.36034114546266677
# ========================================
# For dataset Cardiotoxicity-30_fusion.csv
# for fold 1 test set mcc of 0.3133397807202561 valid set mcc of 0.34993385618385614
# for fold 2 test set mcc of 0.6666666666666666 valid set mcc of -0.047619047619047616
# for fold 3 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 15
# negatives in data 9
# net accuracy = 0.6666666666666666
# mcc = 0.22771001702132443
# ========================================
# For dataset Carcinogenicity_fusion.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0

# %%
namelist
# Out:
# ['NR-ER_Chemopy.csv',
#  'Developmental_Toxicity_Chemopy.csv',
#  'NR-aromatase_Chemopy.csv',
#  'SR-ATAD5_Chemopy.csv',
#  'SR-ARE_Chemopy.csv',
#  'SR-p53_Chemopy.csv',
#  'Cardiotoxicity-1_Chemopy.csv',
#  'SR-HSE_Chemopy.csv',
#  'Respiratory_Toxicity_Chemopy.csv',
#  'Carcinogenicity_Chemopy.csv',
#  'Cardiotoxicity-30_Chemopy.csv',
#  'Cardiotoxicity-10_Chemopy.csv',
#  'Cardiotoxicity-5_Chemopy.csv',
#  'NR-AR-LBD_Chemopy.csv',
#  'Ames_Mutagenicity_Chemopy.csv',
#  'Hepatotoxicity_Chemopy.csv',
#  'NR-AR_Chemopy.csv',
#  'Reproductive_Toxicity_Chemopy.csv',
#  'NR-ER-LBD_Chemopy.csv',
#  'NR-PPAR-gamma_Chemopy.csv',
#  'NR-AhR_Chemopy.csv',
#  'SR-MMP_Chemopy.csv']

# %%
len(resultslist)
# Out:
# 19

# %%
temp = pd.DataFrame(resultslist, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Figure_Development/fusion/data/fusion_svm.csv')
