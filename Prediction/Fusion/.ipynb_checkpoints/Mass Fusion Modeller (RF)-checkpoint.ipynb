# %%
#10/9/24 Creates a K fold RF model for DrugBank data, a copy of the fingerprint one



import os
import pandas as pd
import numpy as np
import math
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Fusion/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df = df.drop(['Unnamed: 0', 'inchi'], axis = 1)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
finalresults = []
splitcount = 3
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / splitcount
    splitsize = math.ceil(size)
    empty = [[] for _ in range(splitcount)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,splitcount):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 50):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = RandomForestClassifier(n_estimators=mtry, criterion='entropy', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                    max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                    verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)

            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = RandomForestClassifier(n_estimators=bestmetrics, criterion='entropy', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                    max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                    verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 2 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    finalresults.append(results[12])
    sets += 1
# Out:
# ========================================
# For dataset NR-ER-LBD_fusion.csv
# for fold 1 test set mcc of 0.5757575757575758 valid set mcc of 0.5272727272727272
# for fold 2 test set mcc of 0.5819143739626463 valid set mcc of 0.5125
# for fold 3 test set mcc of 0.6573757351339165 valid set mcc of 0.378726042189707
#
# validation metrics of:
# positives in data 18
# negatives in data 21
# net accuracy = 0.6923076923076923
# mcc = 0.38095238095238093
# ========================================
# For dataset Cardiotoxicity-1_fusion.csv
# for fold 1 test set mcc of 0.4147575310031266 valid set mcc of 0.3
# for fold 2 test set mcc of 0.5006939628599933 valid set mcc of 0.42600643361512924
# for fold 3 test set mcc of 0.3142857142857143 valid set mcc of 0.50709255283711
#
# validation metrics of:
# positives in data 8
# negatives in data 12
# net accuracy = 0.7
# mcc = 0.3563483225498992
# ========================================
# For dataset Cardiotoxicity-10_fusion.csv
# for fold 1 test set mcc of 0.5737128161373645 valid set mcc of 0.3624780666214897
# for fold 2 test set mcc of 0.5629262517526437 valid set mcc of 0.215594634005188
# for fold 3 test set mcc of 0.3495010688839122 valid set mcc of 0.43278921145054855
#
# validation metrics of:
# positives in data 29
# negatives in data 25
# net accuracy = 0.6666666666666666
# mcc = 0.33425160871869336
# ========================================
# For dataset NR-aromatase_fusion.csv
# for fold 1 test set mcc of 0.15253477177414315 valid set mcc of 0.09607689228305229
# for fold 2 test set mcc of 0.5523398999523437 valid set mcc of 0
# for fold 3 test set mcc of 0.6123724356957946 valid set mcc of 0.5533985905294664
#
# validation metrics of:
# positives in data 15
# negatives in data 18
# net accuracy = 0.6060606060606061
# mcc = 0.2008213586922364
# ========================================
# For dataset NR-ER_fusion.csv
# for fold 1 test set mcc of 0.33757464295529616 valid set mcc of 0.3730019232961255
# for fold 2 test set mcc of 0.48703306314100375 valid set mcc of 0.5203787324221011
# for fold 3 test set mcc of 0.5452322350826353 valid set mcc of 0.4331838401560904
#
# validation metrics of:
# positives in data 36
# negatives in data 62
# net accuracy = 0.6326530612244898
# mcc = 0.10278687311773489
# ========================================
# For dataset Hepatotoxicity_fusion.csv
# for fold 1 test set mcc of 0.46920145709950734 valid set mcc of 0.1860167434467839
# for fold 2 test set mcc of 0.5443077139501638 valid set mcc of 0.31092423515269135
# for fold 3 test set mcc of 0.5148542090962764 valid set mcc of 0.3293786015232713
#
# validation metrics of:
# positives in data 91
# negatives in data 73
# net accuracy = 0.6524390243902439
# mcc = 0.2885117796623924
# ========================================
# For dataset SR-ARE_fusion.csv
# for fold 1 test set mcc of 0.47619373329613723 valid set mcc of 0.33665245661246834
# for fold 2 test set mcc of 0.24657969355483222 valid set mcc of 0.2618924633082486
# for fold 3 test set mcc of 0.45275401420363104 valid set mcc of 0.32881335013854035
#
# validation metrics of:
# positives in data 37
# negatives in data 53
# net accuracy = 0.6333333333333333
# mcc = 0.2032374384797152
# ========================================
# For dataset SR-HSE_fusion.csv
# for fold 1 test set mcc of 0.3105172139687914 valid set mcc of 0.2091650066335189
# for fold 2 test set mcc of 0.3825184261187248 valid set mcc of 0.13241022442571243
# for fold 3 test set mcc of 0.2581988897471611 valid set mcc of 0.1690308509457033
#
# validation metrics of:
# positives in data 12
# negatives in data 14
# net accuracy = 0.6153846153846154
# mcc = 0.21859641244629688
# ========================================
# For dataset SR-ATAD5_fusion.csv
# for fold 1 test set mcc of 0.31622776601683794 valid set mcc of 0.31622776601683794
# for fold 2 test set mcc of 0.07142857142857142 valid set mcc of 0.4166666666666667
# for fold 3 test set mcc of 0.18446619684315546 valid set mcc of 0.21957751641341997
#
# validation metrics of:
# positives in data 10
# negatives in data 11
# net accuracy = 0.7142857142857143
# mcc = 0.4300756154038903
# ========================================
# For dataset NR-AR-LBD_fusion.csv
# for fold 1 test set mcc of 0.7566444492037343 valid set mcc of 0.8397435897435898
# for fold 2 test set mcc of 0.5428571428571428 valid set mcc of 0.7566444492037343
# for fold 3 test set mcc of 0.7237925541034954 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-PPAR-gamma_fusion.csv
# for fold 1 test set mcc of 0.55 valid set mcc of 0.10206207261596577
# for fold 2 test set mcc of 0.31622776601683794 valid set mcc of 0.05976143046671968
# for fold 3 test set mcc of 0.09128709291752768 valid set mcc of 0.06666666666666667
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-AR_fusion.csv
# for fold 1 test set mcc of 0.5026745510374 valid set mcc of 0.5793654595023211
# for fold 2 test set mcc of 0.7636174600000242 valid set mcc of 0
# for fold 3 test set mcc of 0.7531708838213974 valid set mcc of -0.10312858091567377
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Cardiotoxicity-5_fusion.csv
# for fold 1 test set mcc of 0.32348719116573565 valid set mcc of 0
# for fold 2 test set mcc of 0.3931785497463923 valid set mcc of 0.16265001215808886
# for fold 3 test set mcc of 0.5075725269652309 valid set mcc of 0.18341472143474843
#
# validation metrics of:
# positives in data 21
# negatives in data 33
# net accuracy = 0.5740740740740741
# mcc = -0.011881211413043937
# ========================================
# For dataset SR-MMP_fusion.csv
# for fold 1 test set mcc of 0.5341637197842793 valid set mcc of 0.45758914968782144
# for fold 2 test set mcc of 0.613790951461876 valid set mcc of 0.36777120196500895
# for fold 3 test set mcc of 0.7644405368433403 valid set mcc of 0.5888292511776803
#
# validation metrics of:
# positives in data 32
# negatives in data 43
# net accuracy = 0.72
# mcc = 0.4344130291988638
# ========================================
# For dataset NR-AhR_fusion.csv
# for fold 1 test set mcc of 0.5084928361809214 valid set mcc of 0.25262158224835785
# for fold 2 test set mcc of 0.5909278263416963 valid set mcc of 0.4069607278818027
# for fold 3 test set mcc of 0.5894338862466559 valid set mcc of -0.06804138174397717
#
# validation metrics of:
# positives in data 22
# negatives in data 24
# net accuracy = 0.782608695652174
# mcc = 0.5699215788690634
# ========================================
# For dataset SR-p53_fusion.csv
# for fold 1 test set mcc of 0.6990224993351266 valid set mcc of 0.17021289926939803
# for fold 2 test set mcc of 0.5594309277855158 valid set mcc of 0.2927858357513112
# for fold 3 test set mcc of 0.7541822390332477 valid set mcc of -0.04264014327112209
#
# validation metrics of:
# positives in data 19
# negatives in data 23
# net accuracy = 0.7380952380952381
# mcc = 0.4840712166528413
# ========================================
# For dataset Ames Mutagenicity_fusion.csv
# for fold 1 test set mcc of 0.2253744679276044 valid set mcc of 0
# for fold 2 test set mcc of 0.38571288597489645 valid set mcc of 0.0879173964527716
# for fold 3 test set mcc of 0.10208217584305429 valid set mcc of 0.12028130608117203
#
# validation metrics of:
# positives in data 18
# negatives in data 60
# net accuracy = 0.782051282051282
# mcc = 0.22935287163239837
# ========================================
# For dataset Cardiotoxicity-30_fusion.csv
# for fold 1 test set mcc of 0.3578300267477955 valid set mcc of 0.34993385618385614
# for fold 2 test set mcc of 0.6666666666666666 valid set mcc of 0.10087125544480041
# for fold 3 test set mcc of 0.2004459314343183 valid set mcc of -0.050964719143762556
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset Carcinogenicity_fusion.csv
# for fold 1 test set mcc of 0.09335200560186732 valid set mcc of 0.20938142159739226
# for fold 2 test set mcc of 0.08574929257125442 valid set mcc of 0.1951075189460849
# for fold 3 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 12
# negatives in data 27
# net accuracy = 0.6923076923076923
# mcc = 0.14085904245475275

# %%
finalresults
# Out:
# [0.38095238095238093,
#  0.3563483225498992,
#  0.33425160871869336,
#  0.2008213586922364,
#  0.10278687311773489,
#  0.2885117796623924,
#  0.2032374384797152,
#  0.21859641244629688,
#  0.4300756154038903,
#  0,
#  0,
#  0,
#  -0.011881211413043937,
#  0.4344130291988638,
#  0.5699215788690634,
#  0.4840712166528413,
#  0.22935287163239837,
#  0,
#  0.14085904245475275]

# %%
bing = df.drop(['Unnamed: 0', 'inchi'], axis = 1)

# %%
bing

# %%
temp = pd.DataFrame(finalresults, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Figure_Development/fusion/data/fusion_rf.csv')

# %%
datasets[6]
