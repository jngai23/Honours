# %%
#30/7/24 Creates a K fold KNN model for each file in a folder provided they are Fingerprints

import os
import pandas as pd
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Fingerprints/Endocrine/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df.drop(columns=['SMILES'], inplace=True)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
finalresults = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Values'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 90):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = KNeighborsClassifier(n_neighbors=mtry, weights='distance', 
                            algorithm='auto', leaf_size=100, p=2, metric='minkowski', 
                            metric_params=None, n_jobs=4)

            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = KNeighborsClassifier(n_neighbors=bestmetrics, weights='distance', 
                            algorithm='auto', leaf_size=100, p=2, metric='minkowski', 
                            metric_params=None, n_jobs=4)
        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    finalresults.append(results[12])
# Out:
# ========================================
# For dataset NR-AhRMACCSfp.csv
# for fold 1 test set mcc of 0.6911651838917381 valid set mcc of 0.43208688018531766
# for fold 2 test set mcc of 0.5774863796036351 valid set mcc of 0.5158261583396506
# for fold 3 test set mcc of 0.6281224728184416 valid set mcc of 0.5351168830199021
# for fold 4 test set mcc of 0.6504757059781684 valid set mcc of 0.5695194442276702
# for fold 5 test set mcc of 0.7006347046760188 valid set mcc of 0.6191348181252644
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.7880597014925373
# mcc = 0.5720642066959932
# ========================================
# For dataset SR-MMPMACCSfp.csv
# for fold 1 test set mcc of 0.6930271149175106 valid set mcc of 0.4316858359002737
# for fold 2 test set mcc of 0.5871773243454872 valid set mcc of 0.5190499120887042
# for fold 3 test set mcc of 0.45879607264416916 valid set mcc of 0.550350964762303
# for fold 4 test set mcc of 0.5876681602870233 valid set mcc of 0.46061074593403173
# for fold 5 test set mcc of 0.6529559667572015 valid set mcc of 0.48413653375253796
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7701421800947867
# mcc = 0.5305539523742169
# ========================================
# For dataset SR-AREAvafp.csv
# for fold 1 test set mcc of 0.41250718861924707 valid set mcc of 0.487358735252068
# for fold 2 test set mcc of 0.5383446040115234 valid set mcc of 0.4025492896541228
# for fold 3 test set mcc of 0.37025010072265624 valid set mcc of 0.2696865629506007
# for fold 4 test set mcc of 0.3688231371844334 valid set mcc of 0.2541713622676137
# for fold 5 test set mcc of 0.3657532822884929 valid set mcc of 0.17284031208164258
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7004716981132075
# mcc = 0.3773936184383908
# ========================================
# For dataset SR-HSEMorganfp.csv
# for fold 1 test set mcc of 0.2807201297058903 valid set mcc of 0.3033924860942162
# for fold 2 test set mcc of 0.18584401579232587 valid set mcc of 0.3179080053249594
# for fold 3 test set mcc of 0.4930203093008865 valid set mcc of 0.5908467654886124
# for fold 4 test set mcc of 0.5300338766533665 valid set mcc of 0.20256914833653536
# for fold 5 test set mcc of 0.4125709683745876 valid set mcc of 0.19876584354584703
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6447368421052632
# mcc = 0.3096395318037289
# ========================================
# For dataset NR-AhRTTorsionfp.csv
# for fold 1 test set mcc of 0.5801045258907845 valid set mcc of 0.35856858280031806
# for fold 2 test set mcc of 0.4971857410881801 valid set mcc of 0.509009009009009
# for fold 3 test set mcc of 0.6251326146494808 valid set mcc of 0.548235753830076
# for fold 4 test set mcc of 0.5825759965874454 valid set mcc of 0.575117985720616
# for fold 5 test set mcc of 0.5322289982686127 valid set mcc of 0.5390322958904399
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.746268656716418
# mcc = 0.4852112926274516
# ========================================
# For dataset NR-PPAR-gammaAvafp.csv
# for fold 1 test set mcc of 0.5277777777777778 valid set mcc of 0.25
# for fold 2 test set mcc of 0.2974059387397313 valid set mcc of 0.225912997889962
# for fold 3 test set mcc of 0.5606060606060606 valid set mcc of 0.6225430174794672
# for fold 4 test set mcc of 0.44188962412495847 valid set mcc of 0.027461751819054483
# for fold 5 test set mcc of 0.4183300132670378 valid set mcc of 0.40106951871657753
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.7123287671232876
# mcc = 0.4516591109168654
# ========================================
# For dataset SR-p53MACCSfp.csv
# for fold 1 test set mcc of 0.48212728857890147 valid set mcc of 0.29711375212224106
# for fold 2 test set mcc of 0.4384525375961447 valid set mcc of 0.3435830064841323
# for fold 3 test set mcc of 0.5627039587626639 valid set mcc of 0.28336742802815035
# for fold 4 test set mcc of 0.6286946134619316 valid set mcc of 0.320369882919027
# for fold 5 test set mcc of 0.5448693641758077 valid set mcc of 0.43929505599093616
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6647058823529411
# mcc = 0.3275731085241172
# ========================================
# For dataset NR-ER-LBDTTorsionfp.csv
# for fold 1 test set mcc of 0.5606060606060606 valid set mcc of 0.49863962634782666
# for fold 2 test set mcc of 0.4391200278423017 valid set mcc of 0.2524800654694249
# for fold 3 test set mcc of 0.5045307543166047 valid set mcc of 0.4446642302571421
# for fold 4 test set mcc of 0.5120192307692307 valid set mcc of 0.4423076923076923
# for fold 5 test set mcc of 0.680009255387445 valid set mcc of 0.28942722045797453
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.6506849315068494
# mcc = 0.3071149881268544
# ========================================
# For dataset NR-PPAR-gammaTTorsionfp.csv
# for fold 1 test set mcc of 0.338501600193165 valid set mcc of 0.4
# for fold 2 test set mcc of 0.4542199791661351 valid set mcc of 0
# for fold 3 test set mcc of 0.4779197223550799 valid set mcc of 0.5091750772173156
# for fold 4 test set mcc of 0.3619137456499585 valid set mcc of 0.1438234930593239
# for fold 5 test set mcc of 0.3990119375605064 valid set mcc of 0.04222003309207491
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.684931506849315
# mcc = 0.3926767941066129
# ========================================
# For dataset NR-AR-LBDAvafp.csv
# for fold 1 test set mcc of 0.686773437176115 valid set mcc of 0.44695292514227164
# for fold 2 test set mcc of 0.5865557254410011 valid set mcc of 0.46046933104270676
# for fold 3 test set mcc of 0.6546536707079772 valid set mcc of 0.3780500531015748
# for fold 4 test set mcc of 0.7022915233992105 valid set mcc of 0.37609021559644396
# for fold 5 test set mcc of 0.7876414620128274 valid set mcc of 0.4893451639269458
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7604166666666666
# mcc = 0.5224392925598775
# ========================================
# For dataset NR-ER-LBDAvafp.csv
# for fold 1 test set mcc of 0.5419011036681934 valid set mcc of 0.45622119815668205
# for fold 2 test set mcc of 0.5857142857142857 valid set mcc of 0.4588931344933328
# for fold 3 test set mcc of 0.6033653846153846 valid set mcc of 0.4446642302571421
# for fold 4 test set mcc of 0.3942307692307692 valid set mcc of 0.30861597282272785
# for fold 5 test set mcc of 0.7205766921228921 valid set mcc of 0.29707156852002076
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7328767123287672
# mcc = 0.4657214663500352
# ========================================
# For dataset SR-p53Avafp.csv
# for fold 1 test set mcc of 0.48212728857890147 valid set mcc of 0.3799206873241579
# for fold 2 test set mcc of 0.43425341367190734 valid set mcc of 0.30366908351147925
# for fold 3 test set mcc of 0.5905837297899343 valid set mcc of 0.23958333333333334
# for fold 4 test set mcc of 0.6349615513197886 valid set mcc of 0.2370942955749733
# for fold 5 test set mcc of 0.6703357759518795 valid set mcc of 0.32311587211073656
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6588235294117647
# mcc = 0.32210056276318155
# ========================================
# For dataset NR-ERMorganfp.csv
# for fold 1 test set mcc of 0.31615021986523195 valid set mcc of 0.3348849262132673
# for fold 2 test set mcc of 0.3118951764771245 valid set mcc of 0.32600477670341316
# for fold 3 test set mcc of 0.3973607473320002 valid set mcc of 0.31605852784686966
# for fold 4 test set mcc of 0.39023688819445085 valid set mcc of 0.2621109941372696
# for fold 5 test set mcc of 0.375698047690944 valid set mcc of 0.39813633278652677
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.657608695652174
# mcc = 0.2869749231780359
# ========================================
# For dataset NR-aromataseMorganfp.csv
# for fold 1 test set mcc of 0.35901253346404605 valid set mcc of 0.14301644557079338
# for fold 2 test set mcc of 0.09690874237046979 valid set mcc of 0
# for fold 3 test set mcc of 0.5772574469240125 valid set mcc of 0.4210714148023306
# for fold 4 test set mcc of 0.362030053499966 valid set mcc of 0.4740428361972617
# for fold 5 test set mcc of 0.3889592577357173 valid set mcc of 0.488546503365251
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.6776859504132231
# mcc = 0.40927265372891947
# ========================================
# For dataset NR-ARAvafp.csv
# for fold 1 test set mcc of 0.6572311106330365 valid set mcc of 0.33710193876865807
# for fold 2 test set mcc of 0.6929407109164757 valid set mcc of 0.600245047998781
# for fold 3 test set mcc of 0.48495047402467656 valid set mcc of 0.5570029454740558
# for fold 4 test set mcc of 0.5290432684448219 valid set mcc of 0.2573206596865631
# for fold 5 test set mcc of 0.5830006053876384 valid set mcc of 0.3572172541558801
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.76
# mcc = 0.5589979253939279
# ========================================
# For dataset SR-AREMorganfp.csv
# for fold 1 test set mcc of 0.33743214149288236 valid set mcc of 0.36071493263878995
# for fold 2 test set mcc of 0.3941755458745612 valid set mcc of 0.40372311585907145
# for fold 3 test set mcc of 0.3585903124423121 valid set mcc of 0.2378471642446886
# for fold 4 test set mcc of 0.2954985333277038 valid set mcc of 0.2670903587479511
# for fold 5 test set mcc of 0.4132744454015916 valid set mcc of 0.12737153472243154
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.6863207547169812
# mcc = 0.3591556191769535
# ========================================
# For dataset SR-p53TTorsionfp.csv
# for fold 1 test set mcc of 0.506781412331691 valid set mcc of 0.29496311962570004
# for fold 2 test set mcc of 0.42618452124563977 valid set mcc of 0.25415212262620723
# for fold 3 test set mcc of 0.4874903711815117 valid set mcc of 0.32596473160912093
# for fold 4 test set mcc of 0.620220362223602 valid set mcc of 0.14001806684733514
# for fold 5 test set mcc of 0.5021008403361344 valid set mcc of 0.166196077492123
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.7
# mcc = 0.42201647311072243
# ========================================
# For dataset NR-ARMACCSfp.csv
# for fold 1 test set mcc of 0.6929407109164757 valid set mcc of 0.2953485554912521
# for fold 2 test set mcc of 0.6572311106330365 valid set mcc of 0.600245047998781
# for fold 3 test set mcc of 0.44702442937253495 valid set mcc of 0.4750907476102241
# for fold 4 test set mcc of 0.5537765319092597 valid set mcc of 0.29417420270727607
# for fold 5 test set mcc of 0.6397058823529411 valid set mcc of 0.3572172541558801
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.712
# mcc = 0.4605346858287855
# ========================================
# For dataset SR-ATAD5Morganfp.csv
# for fold 1 test set mcc of 0.49348842518528757 valid set mcc of 0.12126781251816648
# for fold 2 test set mcc of 0.5685575072471674 valid set mcc of 0.4690753506235187
# for fold 3 test set mcc of 0.5038378351241242 valid set mcc of 0.3872983346207417
# for fold 4 test set mcc of 0.36226673028138096 valid set mcc of 0.5262013605584339
# for fold 5 test set mcc of 0.4947753344488257 valid set mcc of 0.35186577527449836
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.6634615384615384
# mcc = 0.33743567470752406
# ========================================
# For dataset SR-p53Morganfp.csv
# for fold 1 test set mcc of 0.4153454787347698 valid set mcc of 0.22734698921316415
# for fold 2 test set mcc of 0.49792839185625315 valid set mcc of 0.3880481080679098
# for fold 3 test set mcc of 0.4710370493665035 valid set mcc of 0.19312073944138397
# for fold 4 test set mcc of 0.49028346578852766 valid set mcc of 0.27398950717817444
# for fold 5 test set mcc of 0.38256477963467794 valid set mcc of 0.34264935874413216
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.6764705882352942
# mcc = 0.3927928887740745
# ========================================
# For dataset NR-AR-LBDMACCSfp.csv
# for fold 1 test set mcc of 0.7420317739506375 valid set mcc of 0.7187909865703438
# for fold 2 test set mcc of 0.5865557254410011 valid set mcc of 0.2855201203600804
# for fold 3 test set mcc of 0.6546536707079772 valid set mcc of 0.33245498310218435
# for fold 4 test set mcc of 0.5833333333333334 valid set mcc of 0.5522311464689716
# for fold 5 test set mcc of 0.6428785635743144 valid set mcc of 0.477295345211795
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.8020833333333334
# mcc = 0.6134162532192503
# ========================================
# For dataset NR-PPAR-gammaMACCSfp.csv
# for fold 1 test set mcc of 0.7222222222222222 valid set mcc of 0.1414213562373095
# for fold 2 test set mcc of 0.6884520066159542 valid set mcc of 0.0
# for fold 3 test set mcc of 0.7243576850866262 valid set mcc of 0.3333333333333333
# for fold 4 test set mcc of 0.44188962412495847 valid set mcc of 0.3861969258768566
# for fold 5 test set mcc of 0.3944467458277703 valid set mcc of 0.3089682853364634
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.6164383561643836
# mcc = 0.23529652646066698
# ========================================
# For dataset NR-AR-LBDTTorsionfp.csv
# for fold 1 test set mcc of 0.7420317739506375 valid set mcc of 0.50709255283711
# for fold 2 test set mcc of 0.7921848383943094 valid set mcc of 0.4249246370887065
# for fold 3 test set mcc of 0.610170215847752 valid set mcc of 0.5938459911664722
# for fold 4 test set mcc of 0.6583050504534322 valid set mcc of 0.4823765808736999
# for fold 5 test set mcc of 0.6428785635743144 valid set mcc of 0.7434307035293071
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7916666666666666
# mcc = 0.5945060965364305
# ========================================
# For dataset NR-AR-LBDMorganfp.csv
# for fold 1 test set mcc of 0.7420317739506375 valid set mcc of 0.6000077303150751
# for fold 2 test set mcc of 0.6958161056702072 valid set mcc of 0.5329708913388167
# for fold 3 test set mcc of 0.6546536707079772 valid set mcc of 0.7010681840159741
# for fold 4 test set mcc of 0.6153084570802658 valid set mcc of 0.4823765808736999
# for fold 5 test set mcc of 0.6428785635743144 valid set mcc of 0.7364081197050363
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7916666666666666
# mcc = 0.6073664063908583
# ========================================
# For dataset NR-ERTTorsionfp.csv
# for fold 1 test set mcc of 0.39608698810175885 valid set mcc of 0.15452477672431694
# for fold 2 test set mcc of 0.35244943451906 valid set mcc of 0.34248519312074044
# for fold 3 test set mcc of 0.34305383901704245 valid set mcc of 0.25671312265387636
# for fold 4 test set mcc of 0.4064530352139875 valid set mcc of 0.2889488901182513
# for fold 5 test set mcc of 0.3688685811123343 valid set mcc of 0.32270771760590083
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6847826086956522
# mcc = 0.34490670846450067
# ========================================
# For dataset SR-MMPTTorsionfp.csv
# for fold 1 test set mcc of 0.6013967806190504 valid set mcc of 0.4830987367227869
# for fold 2 test set mcc of 0.5596608403477615 valid set mcc of 0.4770380212152593
# for fold 3 test set mcc of 0.4600677589440014 valid set mcc of 0.5071619433514563
# for fold 4 test set mcc of 0.6227523687795277 valid set mcc of 0.3481064788496629
# for fold 5 test set mcc of 0.6427109349787492 valid set mcc of 0.5059514220422243
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7701421800947867
# mcc = 0.5278810206938803
# ========================================
# For dataset NR-ARMorganfp.csv
# for fold 1 test set mcc of 0.6572311106330365 valid set mcc of 0.6379052256590134
# for fold 2 test set mcc of 0.5507419492112821 valid set mcc of 0.5015568278463085
# for fold 3 test set mcc of 0.45613254692533467 valid set mcc of 0
# for fold 4 test set mcc of 0.5393193716300061 valid set mcc of 0.2795426231258449
# for fold 5 test set mcc of 0.6816381233958094 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset SR-HSEMACCSfp.csv
# for fold 1 test set mcc of 0.40737325786900264 valid set mcc of 0.2064289190324326
# for fold 2 test set mcc of 0.4563376701880213 valid set mcc of 0.45726659240727496
# for fold 3 test set mcc of 0.4595725150090289 valid set mcc of 0.4500265855315861
# for fold 4 test set mcc of 0.40524896881636446 valid set mcc of 0.41518942736604736
# for fold 5 test set mcc of 0.5184688572366651 valid set mcc of 0.16803478540247052
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6447368421052632
# mcc = 0.28755899927359346
# ========================================
# For dataset SR-ATAD5MACCSfp.csv
# for fold 1 test set mcc of 0.6264144833056663 valid set mcc of 0.3922322702763681
# for fold 2 test set mcc of 0.4842969937928884 valid set mcc of 0.2311212814645309
# for fold 3 test set mcc of 0.5013026509266503 valid set mcc of 0.3440511766019877
# for fold 4 test set mcc of 0.4297371021269962 valid set mcc of 0.4767312946227962
# for fold 5 test set mcc of 0.447213595499958 valid set mcc of 0.5270462766947299
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.75
# mcc = 0.49981502034776176
# ========================================
# For dataset SR-ARETTorsionfp.csv
# for fold 1 test set mcc of 0.4738267709690998 valid set mcc of 0.43548459347750196
# for fold 2 test set mcc of 0.35185257775970213 valid set mcc of 0.3444809470595119
# for fold 3 test set mcc of 0.33806170189140666 valid set mcc of 0.35084085327003417
# for fold 4 test set mcc of 0.34345380351344046 valid set mcc of 0.3993086647358457
# for fold 5 test set mcc of 0.47748110894004775 valid set mcc of 0.17383454240653054
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.6792452830188679
# mcc = 0.3308801538385406
# ========================================
# For dataset SR-ATAD5Avafp.csv
# for fold 1 test set mcc of 0.6971153846153846 valid set mcc of 0.23918243661746993
# for fold 2 test set mcc of 0.5095693779904307 valid set mcc of -0.023453767531175933
# for fold 3 test set mcc of 0.64607127179228 valid set mcc of 0.3038024971663591
# for fold 4 test set mcc of 0.2830692585361489 valid set mcc of 0.23918243661746993
# for fold 5 test set mcc of 0.21957751641341997 valid set mcc of 0.42163702135578396
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7403846153846154
# mcc = 0.4808031967121333
# ========================================
# For dataset SR-AREMACCSfp.csv
# for fold 1 test set mcc of 0.44565370449712405 valid set mcc of 0.4922632400081123
# for fold 2 test set mcc of 0.4903774884479323 valid set mcc of 0.4129052490906922
# for fold 3 test set mcc of 0.33126091520781664 valid set mcc of 0.3869129414180872
# for fold 4 test set mcc of 0.4602120960224558 valid set mcc of 0.49641305622825804
# for fold 5 test set mcc of 0.4540690868696168 valid set mcc of 0.24483031797434493
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.7169811320754716
# mcc = 0.41418632195946004
# ========================================
# For dataset NR-aromataseAvafp.csv
# for fold 1 test set mcc of 0.5201371567644535 valid set mcc of 0.34673804626442817
# for fold 2 test set mcc of 0.4232692231247351 valid set mcc of 0.5083612040133779
# for fold 3 test set mcc of 0.5027785182957974 valid set mcc of 0.42833333333333334
# for fold 4 test set mcc of 0.43915343915343913 valid set mcc of 0.4714045207910317
# for fold 5 test set mcc of 0.4918338408540253 valid set mcc of 0.5362309875550463
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7355371900826446
# mcc = 0.4697527309420669
# ========================================
# For dataset NR-PPAR-gammaMorganfp.csv
# for fold 1 test set mcc of 0.30207927000959933 valid set mcc of 0.2786391062876764
# for fold 2 test set mcc of 0.4384540666452508 valid set mcc of 0.19767387315371676
# for fold 3 test set mcc of 0.5554932406347733 valid set mcc of 0.48420012470625223
# for fold 4 test set mcc of 0.2854557100602737 valid set mcc of 0.2788995520575487
# for fold 5 test set mcc of 0.6236348727784989 valid set mcc of 0.3799802978286742
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.6712328767123288
# mcc = 0.35349951843867855
# ========================================
# For dataset NR-AhRMorganfp.csv
# for fold 1 test set mcc of 0.5965689878337475 valid set mcc of 0.31690242599769936
# for fold 2 test set mcc of 0.48785157894575487 valid set mcc of 0.3667477495589351
# for fold 3 test set mcc of 0.5961175670032391 valid set mcc of 0.5247489691506202
# for fold 4 test set mcc of 0.5119104235131421 valid set mcc of 0.4701333545832436
# for fold 5 test set mcc of 0.5341906884423221 valid set mcc of 0.48155789655719766
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.7850746268656716
# mcc = 0.5723387958404564
# ========================================
# For dataset SR-MMPMorganfp.csv
# for fold 1 test set mcc of 0.5702726345417722 valid set mcc of 0.5206621852818676
# for fold 2 test set mcc of 0.5301654736258709 valid set mcc of 0.35724162488222
# for fold 3 test set mcc of 0.42847127705780436 valid set mcc of 0.4702621496909165
# for fold 4 test set mcc of 0.6076436202501999 valid set mcc of 0.3779372815279644
# for fold 5 test set mcc of 0.6048506359065365 valid set mcc of 0.5115817956786489
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7322274881516587
# mcc = 0.4442276861859421
# ========================================
# For dataset NR-AhRAvafp.csv
# for fold 1 test set mcc of 0.6266701450390608 valid set mcc of 0.3539631615218462
# for fold 2 test set mcc of 0.6119448472095808 valid set mcc of 0.43587202835588007
# for fold 3 test set mcc of 0.6689871996406916 valid set mcc of 0.6316851468378916
# for fold 4 test set mcc of 0.6277777777777778 valid set mcc of 0.7499345873163411
# for fold 5 test set mcc of 0.684034310119148 valid set mcc of 0.6312297735867225
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.817910447761194
# mcc = 0.6305685768037953
# ========================================
# For dataset NR-ER-LBDMorganfp.csv
# for fold 1 test set mcc of 0.5958460099157059 valid set mcc of 0.29147465437788017
# for fold 2 test set mcc of 0.5569649872678669 valid set mcc of 0.47390242621925555
# for fold 3 test set mcc of 0.5461422450332466 valid set mcc of 0.5379519296838619
# for fold 4 test set mcc of 0.49688954990641687 valid set mcc of 0.36720990919214974
# for fold 5 test set mcc of 0.6761234037828132 valid set mcc of 0.20989896436231156
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7191780821917808
# mcc = 0.45383877172149034
# ========================================
# For dataset SR-HSEAvafp.csv
# for fold 1 test set mcc of 0.3632837903998322 valid set mcc of 0.2733101380504877
# for fold 2 test set mcc of 0.4896877227115848 valid set mcc of 0.4238531229230863
# for fold 3 test set mcc of 0.4152606693620403 valid set mcc of 0.4492292696347603
# for fold 4 test set mcc of 0.47587807481007366 valid set mcc of 0.5160299751825812
# for fold 5 test set mcc of 0.43055762801289416 valid set mcc of 0.301227212573792
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6513157894736842
# mcc = 0.30605351152602067
# ========================================
# For dataset NR-ERAvafp.csv
# for fold 1 test set mcc of 0.3490711379181125 valid set mcc of 0.25918663677676024
# for fold 2 test set mcc of 0.32936774553854514 valid set mcc of 0.24782563463193813
# for fold 3 test set mcc of 0.4027544447044016 valid set mcc of 0.2823662293116958
# for fold 4 test set mcc of 0.34205810052077457 valid set mcc of 0.41286141192238524
# for fold 5 test set mcc of 0.44274086448093847 valid set mcc of 0.3786328225009482
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6603260869565217
# mcc = 0.2903943999526783
# ========================================
# For dataset NR-ARTTorsionfp.csv
# for fold 1 test set mcc of 0.6572311106330365 valid set mcc of 0.5069447770645309
# for fold 2 test set mcc of 0.5618006477335896 valid set mcc of 0.600245047998781
# for fold 3 test set mcc of 0.44702442937253495 valid set mcc of 0.5341637197842793
# for fold 4 test set mcc of 0.6050751277598158 valid set mcc of 0.29417420270727607
# for fold 5 test set mcc of 0.5819358307200044 valid set mcc of 0.4422689813358516
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.736
# mcc = 0.5274949660495826
# ========================================
# For dataset NR-aromataseTTorsionfp.csv
# for fold 1 test set mcc of 0.43691762051643435 valid set mcc of 0.2118923641468466
# for fold 2 test set mcc of 0.2600231530725279 valid set mcc of 0.5104035324589247
# for fold 3 test set mcc of 0.5056205829602306 valid set mcc of 0
# for fold 4 test set mcc of 0.32951276778634797 valid set mcc of 0.07993052538854532
# for fold 5 test set mcc of 0.5005216395553902 valid set mcc of 0.6010910976500518
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7024793388429752
# mcc = 0.4646785977740792
# ========================================
# For dataset SR-HSETTorsionfp.csv
# for fold 1 test set mcc of 0.1829534767323246 valid set mcc of 0.18688841543883614
# for fold 2 test set mcc of 0.41147167957154823 valid set mcc of 0.2077069959094179
# for fold 3 test set mcc of 0.42763415500842855 valid set mcc of 0.2917148634810174
# for fold 4 test set mcc of 0.4723929936340633 valid set mcc of 0.3127387694660169
# for fold 5 test set mcc of 0.37096082719259466 valid set mcc of 0.301227212573792
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.5986842105263158
# mcc = 0.19582333967869303
# ========================================
# For dataset SR-MMPAvafp.csv
# for fold 1 test set mcc of 0.636797090063531 valid set mcc of 0.4059793854890171
# for fold 2 test set mcc of 0.5541952714552937 valid set mcc of 0.577186375979705
# for fold 3 test set mcc of 0.5088257224402446 valid set mcc of 0.509048435339345
# for fold 4 test set mcc of 0.6157558485510554 valid set mcc of 0.43596901878529754
# for fold 5 test set mcc of 0.6392610270322598 valid set mcc of 0.4742958421631853
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.7654028436018957
# mcc = 0.5165899598123257
# ========================================
# For dataset SR-ATAD5TTorsionfp.csv
# for fold 1 test set mcc of 0.49348842518528757 valid set mcc of 0.17407765595569785
# for fold 2 test set mcc of 0.6280977702400266 valid set mcc of 0.11579410874166
# for fold 3 test set mcc of 0.5375 valid set mcc of 0.3339115355603141
# for fold 4 test set mcc of 0.360367569878785 valid set mcc of 0.30304576336566325
# for fold 5 test set mcc of 0.44508181954215625 valid set mcc of 0.31622776601683794
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.6923076923076923
# mcc = 0.43843263386540193
# ========================================
# For dataset NR-ER-LBDMACCSfp.csv
# for fold 1 test set mcc of 0.5526971103567273 valid set mcc of 0.3882488479262673
# for fold 2 test set mcc of 0.5857142857142857 valid set mcc of 0.5033679061597705
# for fold 3 test set mcc of 0.6626870114100435 valid set mcc of 0.5043324439329557
# for fold 4 test set mcc of 0.3547050069348813 valid set mcc of 0.16373638398364068
# for fold 5 test set mcc of 0.6779076806833005 valid set mcc of 0.21889453648082105
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.6712328767123288
# mcc = 0.3402804183494084
# ========================================
# For dataset NR-ERMACCSfp.csv
# for fold 1 test set mcc of 0.43961081031835786 valid set mcc of 0.37160018553931384
# for fold 2 test set mcc of 0.34947572690134593 valid set mcc of 0.2955692193101549
# for fold 3 test set mcc of 0.4295597050715079 valid set mcc of 0.3847937471446751
# for fold 4 test set mcc of 0.41240174410178804 valid set mcc of 0.3863840291908135
# for fold 5 test set mcc of 0.4260064336151292 valid set mcc of 0.45102112704368214
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6385869565217391
# mcc = 0.2383837110929597
# ========================================
# For dataset NR-aromataseMACCSfp.csv
# for fold 1 test set mcc of 0.6327220837212335 valid set mcc of 0.3608023871499459
# for fold 2 test set mcc of 0.45818979495265694 valid set mcc of 0.3860443241498841
# for fold 3 test set mcc of 0.5427786801746859 valid set mcc of 0.5561209244434306
# for fold 4 test set mcc of 0.5238095238095238 valid set mcc of 0.3919647479510927
# for fold 5 test set mcc of 0.4891304347826087 valid set mcc of 0.40653424483875156
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.6942148760330579
# mcc = 0.3893502032796108

# %%
def setbalance(df):
    import pandas as pd
    import numpy as np
    #df = df.iloc[:,1:]
    toxvals = df['Toxicity_Values']

    zercount = 0
    for value in toxvals:
        if value == 0:
            zercount += 1

    poscount = len(toxvals)-zercount
    domval = 0

    if poscount > zercount:
        temp = poscount
        poscount = zercount
        poscount = temp
        domval = 1

    if poscount*4 < zercount:
        ratio = zercount / poscount
        factor = int(ratio) - 1

        loops = 0
        todel = []
        for value in toxvals:
            if loops % factor != 0 and value == domval:
                todel.append(loops)
            loops += 1

        df = df.drop(todel)
        
    return df

# %%
namelist
# Out:
# ['CarcinogenicityMorganfp.csv',
#  'morganfp_SR-p53.csv',
#  'morganfp_NR-AhR.csv',
#  'morganfp_NR-ER-LBD.csv',
#  'mutagenTTorsionfp.csv',
#  'morganfp_NR-PPAR-gamma.csv',
#  'Respiratory_ToxicityMorganfp.csv',
#  'mutagenMACCSfp.csv',
#  'Reproductive_ToxicityTTorsionfp.csv',
#  'CarcinogenicityAvafp.csv',
#  'CarcinogenicityTTorsionfp.csv',
#  'CarcinogenicityMACCSfp.csv',
#  'morganfp_NR-ER.csv',
#  'Respiratory_ToxicityAvafp.csv',
#  'Developmental_ToxicityTTorsionfp.csv',
#  'morganfp_SR-ATAD5.csv',
#  'Developmental_ToxicityMorganfp.csv',
#  'mutagenMorganfp.csv',
#  'mutagenAvafp.csv',
#  'Reproductive_ToxicityAvafp.csv',
#  'morganfp_SR-ARE.csv',
#  'Developmental_ToxicityAvafp.csv',
#  'morganfp_NR-AR.csv',
#  'Reproductive_ToxicityMorganfp.csv',
#  'Developmental_ToxicityMACCSfp.csv',
#  'morganfp_SR-HSE.csv',
#  'morganfp_SR-MMP.csv',
#  'Respiratory_ToxicityTTorsionfp.csv',
#  'Respiratory_ToxicityMACCSfp.csv',
#  'morganfp_NR-aromatase.csv',
#  'morganfp_NR-AR-LBD.csv',
#  'Reproductive_ToxicityMACCSfp.csv']

# %%
temp = pd.DataFrame(finalresults, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Data/Model_Outputs/Fingerprint/KNN_Fingerprint_Results')

# %%
resultframe
# Out:
#                                  Dataset       MCC
# 0            CarcinogenicityMorganfp.csv  0.300006
# 1                    morganfp_SR-p53.csv  0.392793
# 2                    morganfp_NR-AhR.csv  0.572339
# 3                 morganfp_NR-ER-LBD.csv  0.453839
# 4                  mutagenTTorsionfp.csv  0.514638
# 5             morganfp_NR-PPAR-gamma.csv  0.353500
# 6       Respiratory_ToxicityMorganfp.csv  0.421679
# 7                     mutagenMACCSfp.csv  0.614949
# 8    Reproductive_ToxicityTTorsionfp.csv  0.000000
# 9               CarcinogenicityAvafp.csv  0.269629
# 10         CarcinogenicityTTorsionfp.csv  0.337852
# 11            CarcinogenicityMACCSfp.csv  0.326857
# 12                    morganfp_NR-ER.csv  0.286975
# 13         Respiratory_ToxicityAvafp.csv  0.577049
# 14  Developmental_ToxicityTTorsionfp.csv  0.000000
# 15                 morganfp_SR-ATAD5.csv  0.337436
# 16    Developmental_ToxicityMorganfp.csv  0.035088
# 17                   mutagenMorganfp.csv  0.645710
# 18                      mutagenAvafp.csv  0.617388
# 19        Reproductive_ToxicityAvafp.csv  0.000000
# 20                   morganfp_SR-ARE.csv  0.359156
# 21       Developmental_ToxicityAvafp.csv  0.066396
# 22                    morganfp_NR-AR.csv  0.000000
# 23     Reproductive_ToxicityMorganfp.csv  0.000000
# 24     Developmental_ToxicityMACCSfp.csv  0.104713
# 25                   morganfp_SR-HSE.csv  0.309640
# 26                   morganfp_SR-MMP.csv  0.444228
# 27    Respiratory_ToxicityTTorsionfp.csv  0.449867
# 28       Respiratory_ToxicityMACCSfp.csv  0.491357
# 29             morganfp_NR-aromatase.csv  0.409273
# 30                morganfp_NR-AR-LBD.csv  0.607366
# 31      Reproductive_ToxicityMACCSfp.csv  0.202610
