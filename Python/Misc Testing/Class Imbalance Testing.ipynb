# %%
#16/8/24 This script aims to test ways of fixing class imbalance

import pandas as pd
import numpy as np
import os
import math

seed = 81
#Data import
df = pd.read_csv('/Users/james/Documents/Honours/Data/Fingerprints/SR-ATAD5_Morganfp.csv')
toxvals = (df['Toxicity_Value'].values)

# %%
#K fold partioning

#Given imbalanced data
#split majority class into K partitions where K is (Number of majority class) / (number of minority class)
#each partition is the size of the minority class
#Each parition is then modelled against minority class so K models are made

# %%
#Determine Degree of Class Imbalance
posvals = 0
negvals = 0
loops = 0
neglist = []
poslist = []
for value in toxvals:
    if value == 1:
        posvals += 1
        poslist.append(loops)
    else:
        negvals += 1
        neglist.append(loops)
        
    loops += 1

print('Total samples =', (negvals + posvals))
print('Positives in data:', posvals)
print('Negatives in data:', negvals)
print('Class Imbalance =', (posvals/negvals), ':', (1 - (posvals/negvals)))
# Out:
# Total samples = 6931
# Positives in data: 253
# Negatives in data: 6678
# Class Imbalance = 0.037885594489368075 : 0.9621144055106319

# %%
#Find Model Performance on Imbalanced Set
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 

df = pd.read_csv('/Users/james/Documents/Honours/Data/Fingerprints/SR-ATAD5_Morganfp.csv')
#df = pd.read_csv('/Users/james/Documents/Honours/Data/Fingerprints/Ames_Mutagenicity_Morganfp.csv')
df.drop(columns=['SMILES'], inplace=True)
df = df.dropna()
dfarray = df.to_numpy()

dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                    random_state=seed, stratify = df['Toxicity_Value'])

size = len(dfarray) / 5
splitsize = math.ceil(size)
empty = [[] for _ in range(5)]
splits = []
for list in empty:
    splits.append(list)

loops = 0
currsplit = 0
#Results in a list of 5 lists that each contain 1/5 of the targetdata
for row in dfarray:
    splits[currsplit].append(row)
    if loops == splitsize:
        loops = 0
        currsplit = currsplit + 1
    loops = loops + 1

folds = []
for split in splits:
    temp = pd.DataFrame(split)
    folds.append(temp)

model_list = []
validlist = []
totalmetrics = []
testdat = []
#For loop that uses each fold once for valid/testing and the rest for training
#Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
iteration = 1
print('========================================')
for split in range(0,5):
    #Set creation
    trainlist = [df for i, df in enumerate(folds) if i != split]
    trainset = pd.concat(trainlist, axis=0)
    testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

    ytrain = trainset[0].values
    xtrain = trainset.iloc[:, 1:]

    ytest = testset[0].values
    xtest = testset.iloc[:, 1:]

    yvalid = validset[0].values
    xvalid = validset.iloc[:, 1:]

    #lists of metric values
    mcclist = []
    bestmetrics = 1
    maxval = 0
    for mtry in range(1, 50):
        #using mtry as the adjusted hyperparameter creates a series of random forests
        rf = RandomForestClassifier(n_estimators=mtry, criterion='entropy', max_depth=None, 
                                min_samples_split=2, min_samples_leaf=1, 
                                min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)

        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xtest)
        #calculate metric (mcc)
        mcc = metriccalc(preds, ytest)[12]
        mcclist.append(mcc)
        if mcc > maxval:
            maxval = mcc
            bestmetrics = mtry
    #store best model for the given fold and plot the metric vs mcc value
    rf = RandomForestClassifier(n_estimators=bestmetrics, criterion='entropy', max_depth=None, 
                                min_samples_split=2, min_samples_leaf=1, 
                                min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
    model_list.append(rf)
    testdat.append(maxval)
    totalmetrics.append(mcclist)

    #check models onto validation set, printing various metrics
    model= rf.fit(xtrain, ytrain)
    preds = model.predict(xvalid)
    results = metriccalc(preds, yvalid)
    validlist.append(results)
    print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])

    iteration = iteration + 1

    #get x and y values for the final validation set

toxvals = []
fingerprints = []
for row in tempset:
    toxvals.append(row[0])
    fingerprints.append(row[1:])

#calculates consensus of models on each fingerprint in the final validation set
consensuslist = []
predictions = []
for fp in fingerprints:
    consensus = -1
    fp = fp.reshape(1, -1)
    #appends each model's prediction to a list
    predictions = []
    predlist = []
    for model in model_list:
        preds = model.predict(fp)
        predictions.append(preds)
        predlist.append(preds)
    predictions.append(predlist)

    #finds number of 0s in the prediction list
    zercount = 0
    for num in predictions:
        if num == 0:
            zercount = zercount + 1
    #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
    if zercount < 3:
        consensus = 1
    else:
        consensus = 0
    consensuslist.append(consensus)
#calculate and print metrics
results = metriccalc(consensuslist, toxvals)
print('\nvalidation metrics of:')
print('positives in data', results[0])
print('negatives in data', results[1])
print('net accuracy =', results[6])
print('mcc =',results[12])
# Out:
# ========================================
# for fold 1 test set mcc of 0.2639431263837363 valid set mcc of 0.2723211280201637
# for fold 2 test set mcc of 0.3179965487615299 valid set mcc of 0.11262150407710413
# for fold 3 test set mcc of 0.15403218406501445 valid set mcc of 0.1212662593325755
# for fold 4 test set mcc of 0.13414143899278652 valid set mcc of 0.30290273405904894
# for fold 5 test set mcc of 0.48983581302779317 valid set mcc of 0.19130468963600855
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0

# %%
#as seen the results using the whole dataset is suboptimal at best

# %%
#Partioning dominant results into portions of 253 (number of non-dominant samples)
import random
random.seed(seed)
#Start by randomising dominant sample list before partitioning
rneglist = neglist
random.shuffle(rneglist)
#Creates partitions of dominant data each the size of non dominant data
loops = 0
partitions = []
currpart = []
for value in rneglist:
    currpart.append(value)
    loops += 1
    if loops == posvals:
        partitions.append(currpart)
        currpart = []
        loops = 0

# %%
#Create models for each partition
datasets = []
for part in partitions:
    newframe = pd.DataFrame()
    for item in poslist:
        newframe = pd.concat([newframe, df.iloc[item]], axis = 1)
    for value in part:
        newframe = pd.concat([newframe, df.iloc[value]], axis = 1)
    newframe = newframe.transpose()
    newframe.drop(columns=['SMILES'], inplace=True)
    
    datasets.append(newframe)

# %%
#Model dev on each partition
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
iter = 0
finalresults = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()

    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])

    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)

    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)

    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For Partition', iter)
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 50):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = RandomForestClassifier(n_estimators=mtry, criterion='entropy', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                    max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                    verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)

            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = RandomForestClassifier(n_estimators=bestmetrics, criterion='entropy', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, max_features='sqrt', 
                                    max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    bootstrap=True, oob_score=False, n_jobs= 4, random_state=seed, 
                                    verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])

        iteration = iteration + 1

        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])

    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3:
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    
    finalresults.append(results[12])
    iter += 1
# Out:
# ========================================
# For Partition 0
# for fold 1 test set mcc of 0.39705882352941174 valid set mcc of -0.023809523809523808
# for fold 2 test set mcc of 0.5959595959595959 valid set mcc of 0.5429187467294155
# for fold 3 test set mcc of 0.5506887917539348 valid set mcc of 0.24637845104051562
# for fold 4 test set mcc of 0.7035264706814485 valid set mcc of 0.4304142310105583
# for fold 5 test set mcc of 0.45848623461254817 valid set mcc of 0.447801930486707
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7549019607843137
# mcc = 0.5146749286021822
# ========================================
# For Partition 1
# for fold 1 test set mcc of 0.49754901960784315 valid set mcc of 0.20558916985752212
# for fold 2 test set mcc of 0.4530333378893934 valid set mcc of 0.63802580126271
# for fold 3 test set mcc of 0.556293911166591 valid set mcc of 0
# for fold 4 test set mcc of 0.6508140266182866 valid set mcc of 0.2805712709727033
# for fold 5 test set mcc of 0.5522311464689716 valid set mcc of 0.32824397594488725
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7745098039215687
# mcc = 0.5499719409228703
# ========================================
# For Partition 2
# for fold 1 test set mcc of 0.38857004094753733 valid set mcc of 0.06983799021553296
# for fold 2 test set mcc of 0.5484315777870906 valid set mcc of 0.64607127179228
# for fold 3 test set mcc of 0.545544725589981 valid set mcc of 0.12534517449920557
# for fold 4 test set mcc of 0.545544725589981 valid set mcc of 0.12779141270558958
# for fold 5 test set mcc of 0.23078316568852547 valid set mcc of 0.30151134457776363
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7156862745098039
# mcc = 0.446108908109597
# ========================================
# For Partition 3
# for fold 1 test set mcc of 0.49754901960784315 valid set mcc of 0.36666666666666664
# for fold 2 test set mcc of 0.43082021842766455 valid set mcc of 0.4875
# for fold 3 test set mcc of 0.450563556889583 valid set mcc of 0.4717948717948718
# for fold 4 test set mcc of 0.7144345083117603 valid set mcc of 0.4005506475541372
# for fold 5 test set mcc of 0.21720251464278623 valid set mcc of 0.3939393939393939
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7254901960784313
# mcc = 0.4541341396153042
# ========================================
# For Partition 4
# for fold 1 test set mcc of 0.4092309597549907 valid set mcc of -0.13342487699899822
# for fold 2 test set mcc of 0.1846372364689991 valid set mcc of 0.38060102844992794
# for fold 3 test set mcc of 0.40201512610368484 valid set mcc of 0.14434293091262532
# for fold 4 test set mcc of 0.7585826061362605 valid set mcc of 0.3196072738906446
# for fold 5 test set mcc of 0.39577285860251626 valid set mcc of 0.30151134457776363
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7549019607843137
# mcc = 0.510688230856951
# ========================================
# For Partition 5
# for fold 1 test set mcc of 0.542379944075025 valid set mcc of 0.3076542285401329
# for fold 2 test set mcc of 0.558389928096229 valid set mcc of 0.47834038488248487
# for fold 3 test set mcc of 0.6508140266182866 valid set mcc of 0.22812821758855417
# for fold 4 test set mcc of 0.7 valid set mcc of 0.1386206560167344
# for fold 5 test set mcc of 0.5896739130434783 valid set mcc of 0.40201512610368484
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.696078431372549
# mcc = 0.4103049699311091
# ========================================
# For Partition 6
# for fold 1 test set mcc of 0.38857004094753733 valid set mcc of 0.21823106724697847
# for fold 2 test set mcc of 0.2465426358859398 valid set mcc of 0.5445811486371709
# for fold 3 test set mcc of 0.502518907629606 valid set mcc of 0.4373370968300497
# for fold 4 test set mcc of 0.502518907629606 valid set mcc of 0.3055174448225651
# for fold 5 test set mcc of 0.483695652173913 valid set mcc of 0.494949494949495
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7058823529411765
# mcc = 0.4169260787524219
# ========================================
# For Partition 7
# for fold 1 test set mcc of 0.49754901960784315 valid set mcc of 0.07159924926194092
# for fold 2 test set mcc of 0.447801930486707 valid set mcc of 0.6196965463223185
# for fold 3 test set mcc of 0.556293911166591 valid set mcc of 0.3134825331559627
# for fold 4 test set mcc of 0.7035264706814485 valid set mcc of 0.44309102548206175
# for fold 5 test set mcc of 0.4430931298712839 valid set mcc of 0.6759983952461461
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7352941176470589
# mcc = 0.48193159734149926
# ========================================
# For Partition 8
# for fold 1 test set mcc of 0.45256680091718243 valid set mcc of 0.3262667427157852
# for fold 2 test set mcc of 0.558389928096229 valid set mcc of 0.38060102844992794
# for fold 3 test set mcc of 0.502518907629606 valid set mcc of 0.20054531545702303
# for fold 4 test set mcc of 0.556293911166591 valid set mcc of 0.44309102548206175
# for fold 5 test set mcc of 0.522928147972873 valid set mcc of 0.45786489521674534
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.6862745098039216
# mcc = 0.37515428924742517
# ========================================
# For Partition 9
# for fold 1 test set mcc of 0.4092309597549907 valid set mcc of 0.22195767271201686
# for fold 2 test set mcc of 0.41414141414141414 valid set mcc of -0.16584971344859295
# for fold 3 test set mcc of 0.5 valid set mcc of -0.004953470161627079
# for fold 4 test set mcc of 0.5506887917539348 valid set mcc of 0.531215016673469
# for fold 5 test set mcc of 0.4068130951800076 valid set mcc of 0.07374961314478497
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.6764705882352942
# mcc = 0.3563134121092031
# ========================================
# For Partition 10
# for fold 1 test set mcc of 0.4842969937928884 valid set mcc of 0.488492646219756
# for fold 2 test set mcc of 0.4530333378893934 valid set mcc of 0.59
# for fold 3 test set mcc of 0.6713171133426189 valid set mcc of 0.5386411701070669
# for fold 4 test set mcc of 0.556293911166591 valid set mcc of 0.4875
# for fold 5 test set mcc of 0.43855911358657207 valid set mcc of 0.6161616161616161
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.696078431372549
# mcc = 0.3922322702763681
# ========================================
# For Partition 11
# for fold 1 test set mcc of 0.45256680091718243 valid set mcc of 0.31666666666666665
# for fold 2 test set mcc of 0.5333964609104418 valid set mcc of 0.34238119163116293
# for fold 3 test set mcc of 0.556293911166591 valid set mcc of 0.1564102564102564
# for fold 4 test set mcc of 0.408248290463863 valid set mcc of 0.376085729841583
# for fold 5 test set mcc of 0.4791863575034157 valid set mcc of 0.6759983952461461
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.6764705882352942
# mcc = 0.3563134121092031
# ========================================
# For Partition 12
# for fold 1 test set mcc of 0.5445811486371709 valid set mcc of 0.12046772038736683
# for fold 2 test set mcc of 0.5968491905238342 valid set mcc of 0.47834038488248487
# for fold 3 test set mcc of 0.4 valid set mcc of 0.3309112606779027
# for fold 4 test set mcc of 0.6508140266182866 valid set mcc of 0.24211241408203665
# for fold 5 test set mcc of 0.4068130951800076 valid set mcc of 0.502518907629606
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7352941176470589
# mcc = 0.48193159734149926
# ========================================
# For Partition 13
# for fold 1 test set mcc of 0.44309102548206175 valid set mcc of 0.4662325411705106
# for fold 2 test set mcc of 0.5333964609104418 valid set mcc of 0.3416009023269526
# for fold 3 test set mcc of 0.7144345083117603 valid set mcc of 0.17048734283205327
# for fold 4 test set mcc of 0.6574382586514258 valid set mcc of 0.41963703136786923
# for fold 5 test set mcc of 0.5522311464689716 valid set mcc of 0.40201512610368484
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7352941176470589
# mcc = 0.49236596391733095
# ========================================
# For Partition 14
# for fold 1 test set mcc of 0.4913530840368859 valid set mcc of 0.07159924926194092
# for fold 2 test set mcc of 0.4530333378893934 valid set mcc of 0.41963703136786923
# for fold 3 test set mcc of 0.450563556889583 valid set mcc of 0.15472230622130836
# for fold 4 test set mcc of 0.502518907629606 valid set mcc of 0.4806307859271526
# for fold 5 test set mcc of 0.4791863575034157 valid set mcc of 0.6359727033932191
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7058823529411765
# mcc = 0.4199160251916029
# ========================================
# For Partition 15
# for fold 1 test set mcc of 0.6077399860725146 valid set mcc of 0.12046772038736683
# for fold 2 test set mcc of 0.6030226891555273 valid set mcc of 0.5600378063109737
# for fold 3 test set mcc of 0.40201512610368484 valid set mcc of 0.2717914161090704
# for fold 4 test set mcc of 0.7509392614826383 valid set mcc of 0.3266084458844825
# for fold 5 test set mcc of 0.5000643551261523 valid set mcc of 0.6030226891555273
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7352941176470589
# mcc = 0.47508454947893747
# ========================================
# For Partition 16
# for fold 1 test set mcc of 0.4378892067677064 valid set mcc of 0.3165549546879248
# for fold 2 test set mcc of 0.43082021842766455 valid set mcc of 0.5196667888450939
# for fold 3 test set mcc of 0.5680375574437545 valid set mcc of 0.23472895027601537
# for fold 4 test set mcc of 0.6574382586514258 valid set mcc of 0.19904664080911114
# for fold 5 test set mcc of 0.6043558516497883 valid set mcc of 0.44219443899559935
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.6862745098039216
# mcc = 0.3728358164321559
# ========================================
# For Partition 17
# for fold 1 test set mcc of 0.36718832257988404 valid set mcc of 0.12142857142857143
# for fold 2 test set mcc of 0.6161616161616161 valid set mcc of 0.4005506475541372
# for fold 3 test set mcc of 0.6123724356957946 valid set mcc of 0.2999131084834078
# for fold 4 test set mcc of 0.5 valid set mcc of 0.2592314736635948
# for fold 5 test set mcc of 0.44508181954215625 valid set mcc of 0.5333964609104418
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7352941176470589
# mcc = 0.48193159734149926
# ========================================
# For Partition 18
# for fold 1 test set mcc of 0.4092309597549907 valid set mcc of 0.36718832257988404
# for fold 2 test set mcc of 0.40201512610368484 valid set mcc of 0.3196072738906446
# for fold 3 test set mcc of 0.6123724356957946 valid set mcc of 0
# for fold 4 test set mcc of 0.450563556889583 valid set mcc of 0.2825
# for fold 5 test set mcc of 0.40693149089675484 valid set mcc of 0.3939393939393939
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7156862745098039
# mcc = 0.4354941703556927
# ========================================
# For Partition 19
# for fold 1 test set mcc of 0.542379944075025 valid set mcc of 0.11990717980603212
# for fold 2 test set mcc of 0.40201512610368484 valid set mcc of 0.41963703136786923
# for fold 3 test set mcc of 0.6508140266182866 valid set mcc of 0.2717914161090704
# for fold 4 test set mcc of 0.6574382586514258 valid set mcc of 0.3144854510165755
# for fold 5 test set mcc of 0.5522311464689716 valid set mcc of 0.5151515151515151
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7058823529411765
# mcc = 0.41303706026554643
# ========================================
# For Partition 20
# for fold 1 test set mcc of 0.6077927272100749 valid set mcc of 0.17048734283205327
# for fold 2 test set mcc of 0.558389928096229 valid set mcc of 0.385
# for fold 3 test set mcc of 0.6123724356957946 valid set mcc of 0.47439956266310473
# for fold 4 test set mcc of 0.556293911166591 valid set mcc of 0.47834038488248487
# for fold 5 test set mcc of 0.40693149089675484 valid set mcc of 0.32824397594488725
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.696078431372549
# mcc = 0.3959037912324479
# ========================================
# For Partition 21
# for fold 1 test set mcc of 0.2965686274509804 valid set mcc of 0.17391361226671942
# for fold 2 test set mcc of 0.45786489521674534 valid set mcc of 0.24211241408203665
# for fold 3 test set mcc of 0.4551495636817563 valid set mcc of 0.2637991495989359
# for fold 4 test set mcc of 0.6508140266182866 valid set mcc of 0.36065576474688615
# for fold 5 test set mcc of 0.5154823466322014 valid set mcc of 0.1919191919191919
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7647058823529411
# mcc = 0.5505619884431753
# ========================================
# For Partition 22
# for fold 1 test set mcc of 0.39705882352941174 valid set mcc of 0.3836329682354105
# for fold 2 test set mcc of 0.28721347895177635 valid set mcc of 0.35950025121272106
# for fold 3 test set mcc of 0.6123724356957946 valid set mcc of 0.38857004094753733
# for fold 4 test set mcc of 0.6508140266182866 valid set mcc of 0.30471337605345405
# for fold 5 test set mcc of 0.4178034171948212 valid set mcc of 0.5333964609104418
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7156862745098039
# mcc = 0.4314554973040049
# ========================================
# For Partition 23
# for fold 1 test set mcc of 0.49754901960784315 valid set mcc of 0.017568209223157664
# for fold 2 test set mcc of 0.6759983952461461 valid set mcc of 0.3196072738906446
# for fold 3 test set mcc of 0.6030226891555273 valid set mcc of 0.3730954893860876
# for fold 4 test set mcc of 0.450563556889583 valid set mcc of 0.47834038488248487
# for fold 5 test set mcc of 0.5154823466322014 valid set mcc of 0.447801930486707
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.7745098039215687
# mcc = 0.5516772843673704
# ========================================
# For Partition 24
# for fold 1 test set mcc of 0.4600922335133197 valid set mcc of 0.12748301895894945
# for fold 2 test set mcc of 0.5484315777870906 valid set mcc of 0.4875
# for fold 3 test set mcc of 0.556293911166591 valid set mcc of 0.3658346697268262
# for fold 4 test set mcc of 0.7 valid set mcc of 0.5445811486371709
# for fold 5 test set mcc of 0.2510099539888792 valid set mcc of 0.41306611464517334
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.696078431372549
# mcc = 0.40555355282690636
# ========================================
# For Partition 25
# for fold 1 test set mcc of 0.5085118434825329 valid set mcc of 0.0700556668080042
# for fold 2 test set mcc of 0.5584945425171289 valid set mcc of 0.5445811486371709
# for fold 3 test set mcc of 0.556293911166591 valid set mcc of 0.4012310830917934
# for fold 4 test set mcc of 0.5039032598602688 valid set mcc of 0.31304951684997057
# for fold 5 test set mcc of 0.37771739130434784 valid set mcc of 0.502518907629606
#
# validation metrics of:
# positives in data 51
# negatives in data 51
# net accuracy = 0.6568627450980392
# mcc = 0.3244428422615251

# %%
np.mean(finalresults)
# Out:
# 0.4421902274859165

# %%
#As can be seen this form of class balancing is working well
finalresults
# Out:
# [0.5146749286021822,
#  0.5499719409228703,
#  0.446108908109597,
#  0.4541341396153042,
#  0.510688230856951,
#  0.4103049699311091,
#  0.4169260787524219,
#  0.48193159734149926,
#  0.37515428924742517,
#  0.3563134121092031,
#  0.3922322702763681,
#  0.3563134121092031,
#  0.48193159734149926,
#  0.49236596391733095,
#  0.4199160251916029,
#  0.47508454947893747,
#  0.3728358164321559,
#  0.48193159734149926,
#  0.4354941703556927,
#  0.41303706026554643,
#  0.3959037912324479,
#  0.5505619884431753,
#  0.4314554973040049,
#  0.5516772843673704,
#  0.40555355282690636,
#  0.3244428422615251]
