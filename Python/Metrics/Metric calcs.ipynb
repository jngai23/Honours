# %%
#3/6/24 When inputted a csv file of metrics, ouputs its mcc, kappa etc.
import pandas as pd
import numpy as np
#Data import
targetdata = pd.read_csv('/Users/james/Downloads/autoencdtSVM.csv')


####################
#Todo: iterate over multiple epoch size, batchsize and latent space sizes
#maintain seed
#store best model

# %%
targetdata
# Out:
#     type     cost   tp    tn    fn    fp       acc
# 0      0     0.01   12  1563    16  1057  0.594789
# 1      0     0.10   81  1459   120   988  0.581571
# 2      0     1.00  118  1408   171   951  0.576284
# 3      0   100.00  121  1396   183   948  0.572885
# 4      0  1000.00  123  1398   181   946  0.574396
# 5      1     0.01   77  1474   105   992  0.585725
# 6      1     0.10  111  1412   167   958  0.575151
# 7      1     1.00  119  1403   176   950  0.574773
# 8      1   100.00  881   292  1287   188  0.442976
# 9      1  1000.00  244  1222   357   825  0.553625
# 10     2     0.01   77  1472   107   992  0.584970
# 11     2     0.10  111  1410   169   958  0.574396
# 12     2     1.00  116  1402   177   953  0.573263
# 13     2   100.00  120  1402   177   949  0.574773
# 14     2  1000.00  116  1402   177   953  0.573263
# 15     3     0.01    0  1579     0  1069  0.596299
# 16     3     0.10   15  1560    19  1054  0.594789
# ...
