# %%
#For testing CHEMBL/Pubchem API data scraping
import pandas as pd
import numpy as np
#Data import
dataset = pd.read_csv('/Users/james/Documents/Honours/Data/processed_endo_data.csv')
smiles = dataset['Canonical SMILES'].tolist()
toxvals = dataset['Toxicity Value'].tolist()
dflist =  list(zip(smiles, toxvals))
df = pd.DataFrame(dflist, columns = ['SMILES', 'Toxicity_Values'])

half = (len(df) // 2)
firsthalf = df.iloc[:half]
secondhalf = df.iloc[half:]

# %%
import requests
import re

def extractor(text):
    pattern = r'{([^}]*)}'
    matches = re.findall(pattern, text)
    return matches

targets = []

for words in firsthalf.SMILES:
    url = 'https://www.ebi.ac.uk/chembl/target-predictions'
    headers = {
        'Content-Type': 'application/json'
    }
    input = words
    data = {
        'smiles': input
    }
    response = requests.post(url, headers=headers, json=data)
    
    if response.status_code == 200:
        objects = extractor(response.content.decode('utf-8'))
        keyphrase = '\"90%\": \"active\"'
        objects = pd.DataFrame(objects)
        list = objects[0].str.contains(keyphrase)
        loops = 0
        hits = []
        
        for items in objects[0]:
            if list[loops] == True:
                hits.append(items)
            loops = loops + 1
    
        matches = []
        pattern = r'"target_chemblid": "(.*?)"'
        for items in hits:
            matches.append(re.findall(pattern, items))
        targets.append(matches)
        
    else:
        targets.append('None')
firsthalf['Targets'] = targets
firsthalf.to_csv('datahalf1.csv', index=False)

# %%
#Extracts CHEMBL ID from SMILES input
import time
start_time = time.time()
from chembl_webresource_client.new_client import new_client

idlist = []

#for items in smiles:
#    similarity = new_client.similarity
#    res = similarity.filter(smiles=items, similarity=100).only(['molecule_chembl_id', 'similarity'])
#    idlist.append(res[0])
    

test = 'CS(C)=O'

similarity = new_client.similarity
res = similarity.filter(smiles=test, similarity=100).only(['molecule_chembl_id', 'similarity'])
print(res[0])


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# {'molecule_chembl_id': 'CHEMBL504', 'similarity': '100'}
# --- 0.4552021026611328 seconds ---

# %%
import requests
import re

def extractor(text):
    pattern = r'{([^}]*)}'
    matches = re.findall(pattern, text)
    return matches

targets = []

url = 'https://www.ebi.ac.uk/chembl/target-predictions'
headers = {
    'Content-Type': 'application/json'
}
input = 'O=C(O)c1ccccc1'
data = {
    'smiles': input
}
response = requests.post(url, headers=headers, json=data)

if response.status_code == 200:
    objects = extractor(response.content.decode('utf-8'))
    keyphrase = '\"90%\": \"active\"'
    objects = pd.DataFrame(objects)
    list = objects[0].str.contains(keyphrase)
    loops = 0
    hits = []
    
    for items in objects[0]:
        if list[loops] == True:
            hits.append(items)
        loops = loops + 1

    matches = []
    pattern = r'"target_chemblid": "(.*?)"'
    print(hits)
    for items in hits:
        matches.append(re.findall(pattern, items))
    matches
    #targets.append(matches)
    
else:
    print('bing')
    matches.append('None')
# Out:
# ['"target_chemblid": "CHEMBL4793", "organism": "Homo sapiens", "pref_name": "Dipeptidyl peptidase IX", "70%": "empty", "80%": "empty", "90%": "active", "threshold": 6.0', '"target_chemblid": "CHEMBL2283", "organism": "Bos taurus", "pref_name": "Carbonic anhydrase II", "70%": "active", "80%": "active", "90%": "active", "threshold": 6.0', '"target_chemblid": "CHEMBL4780", "organism": "Torpedo californica", "pref_name": "Acetylcholinesterase", "70%": "active", "80%": "active", "90%": "active", "threshold": 6.0', '"target_chemblid": "CHEMBL2163176", "organism": "Homo sapiens", "pref_name": "Lysine-specific demethylase 5C", "70%": "empty", "80%": "empty", "90%": "active", "threshold": 6.0', '"target_chemblid": "CHEMBL2966", "organism": "Bos taurus", "pref_name": "Adenosine deaminase", "70%": "active", "80%": "active", "90%": "active", "threshold": 6.0', '"target_chemblid": "CHEMBL4086", "organism": "Rattus norvegicus", "pref_name": "Prostanoid EP4 receptor", "70%": "active", "80%": "active", "90%": "active", "threshold": 7.0', '"target_chemblid": "CHEMBL4657", "organism": "Homo sapiens", "pref_name": "Dipeptidyl peptidase VIII", "70%": "empty", "80%": "empty", "90%": "active", "threshold": 6.0', '"target_chemblid": "CHEMBL1899", "organism": "Homo sapiens", "pref_name": "Serotonin 3a (5-HT3a) receptor", "70%": "active", "80%": "active", "90%": "active", "threshold": 5.0', '"target_chemblid": "CHEMBL276", "organism": "Rattus norvegicus", "pref_name": "Muscarinic acetylcholine receptor M1", "70%": "empty", "80%": "empty", "90%": "active", "threshold": 7.0', '"target_chemblid": "CHEMBL5457", "organism": "Mycobacterium avium", "pref_name": "Dihydrofolate reductase", "70%": "empty", "80%": "empty", "90%": "active", "threshold": 6.0']

# %%
#!/usr/bin/python
import pandas as pd
import numpy as np
#Data import
dataset = pd.read_csv('/Users/james/Documents/Honours/Data/processed_endo_data.csv')
smiles = dataset['Canonical SMILES'].tolist()
toxvals = dataset['Toxicity Value'].tolist()
loops = 0
for items in smiles:
    smiles[loops] = smiles[loops].replace('=', '%3d')
    smiles[loops] = smiles[loops].replace('$', '%24')
    smiles[loops] = smiles[loops].replace('+', '%2b')
    smiles[loops] = smiles[loops].replace(',', '%2c')
    smiles[loops] = smiles[loops].replace('/', '%2f')
    smiles[loops] = smiles[loops].replace(':', '%3a')
    smiles[loops] = smiles[loops].replace(';', '%3b')
    smiles[loops] = smiles[loops].replace('?', '%3f')
    smiles[loops] = smiles[loops].replace('@', '%40')
    loops = loops + 1

dflist =  list(zip(smiles, toxvals))
df = pd.DataFrame(dflist, columns = ['SMILES', 'Toxicity_Values'])

# %%
objects = extractor(response.content.decode('utf-8'))
keyphrase = '\"90%\": \"active\"'
objects = pd.DataFrame(objects)
list = objects[0].str.contains(keyphrase)
loops = 0
hits = []

for items in objects[0]:
    if list[loops] == True:
        hits.append(items)
    loops = loops + 1

matches = []
pattern = r'"target_chemblid": "(.*?)"'
for items in hits:
    matches.append(re.findall(pattern, items))

# %%
test = df.iloc[:10]

# %%
test['Targets'] = targets
# Out:
# /var/folders/cq/5cl8ry195dj0219k6rt6csbm0000gn/T/ipykernel_30824/4147195665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Targets'] = targets

# %%
import time
start_time = time.time()

import time
import requests
import re

def extractor(text):
    pattern = r'{([^}]*)}'
    matches = re.findall(pattern, text)
    return matches

targets = []
loops = 0
for words in df.SMILES:
    url = 'https://www.ebi.ac.uk/chembl/target-predictions'
    headers = {
        'Content-Type': 'application/json'
    }
    input = words
    data = {
        'smiles': input
    }
    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        objects = extractor(response.content.decode('utf-8'))
        keyphrase = '\"90%\": \"active\"'
        objects = pd.DataFrame(objects)
        list = objects[0].str.contains(keyphrase)
        loops = 0
        hits = []

        for items in objects[0]:
            if list[loops] == True:
                hits.append(items)
            loops = loops + 1

        matches = []
        pattern = r'"target_chemblid": "(.*?)"'
        for items in hits:
            matches.append(re.findall(pattern, items))
        targets.append(matches)
        time.sleep(0.5)

    else:
        targets.append(response.status_code)
        time.sleep(0.5)
targets.to_csv('2of5.csv', index=False)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 4828
# 1794
#                                                  SMILES  Toxicity_Values  \
# 0                  Clc1ccc(Cn2c(CN3CCCC3)nc3ccccc32)cc1                1
# 1               COc1ccccc1N1CCN(CCCC(=O)c2ccc(F)cc2)CC1                1
# 2                           CNC(=O)Oc1cccc2c1OC(C)(C)C2                1
# 3                                        Cc1cc(Cl)ccc1O                1
# 4     CCCN(CCC)c1c([N+](=O)[O-])cc(C(F)(F)F)cc1[N+](...                1
# ...                                                 ...              ...
# 6617                        CCCCCCCCCCCCCCn1cc[n+](C)c1                0
# 6618                   CC(C)COC(=O)COc1cc(Cl)c(Cl)cc1Cl                0
# 6619  CCCCC[C@H](O)/C=C/[C@H]1[C@H](O)CC(=O)[C@@H]1C...                0
# 6620  CCCCC[C@H](O)/C=C/[C@H]1[C@H](O)C[C@H](O)[C@@H...                0
# 6621                        CC(=O)/C=C/C1=C(C)CCCC1(C)C                0
#
#                                                 Targets
# 0     [['CHEMBL2283'], ['CHEMBL231'], ['CHEMBL2487']...
# 1     [['CHEMBL2725'], ['CHEMBL4793'], ['CHEMBL5880'...
# 2     [['CHEMBL2487'], ['CHEMBL220'], ['CHEMBL3403']...
# 3     [['CHEMBL1907594'], ['CHEMBL2966'], ['CHEMBL40...
# 4     [['CHEMBL5880'], ['CHEMBL5498'], ['CHEMBL2283'...
# ...                                                 ...
# 6617  [['CHEMBL5880'], ['CHEMBL2283'], ['CHEMBL19075...
# 6618  [['CHEMBL4793'], ['CHEMBL2283'], ['CHEMBL4828'...
# 6619                                                429
# 6620                                                429
# 6621                                                429
#
# [6622 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 ting = [1, 2, 3]
# ----> 2 df['bling'] = ting
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
#    4303         key in self.columns
#    4304         and value.ndim == 1
#    4305         and not isinstance(value.dtype, ExtensionDtype)
#    4306     ):
#    4307         # broadcast across multiple columns if necessary
#    4308         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5039, in DataFrame._sanitize_column(self, value)
#    5036     return _reindex_for_setitem(value, self.index)
#    5038 if is_list_like(value):
# -> 5039     com.require_length_match(value, self.index)
#    5040 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (3) does not match length of index (13244)
