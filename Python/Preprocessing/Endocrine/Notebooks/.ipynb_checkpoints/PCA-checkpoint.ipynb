# %%
#UMAP testing
import pandas as pd
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import umap


from rdkit import Chem
import pandas as pd

data = pd.read_csv('deepnormspedata.csv')
dataframe = data.drop("DeepSMILE", axis=1)
dataframe = dataframe.drop("Toxicity_Value", axis=1)

# %%
#Scales data to have 0 mean and unit var
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
scaled_df = std_scaler.fit_transform(dataframe)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
bing = pca.fit(dataframe)

# %%
bing.explained_variance_ratio_
# Out:
# array([0.06183813, 0.05618688, 0.031666  ])

# %%
nums=np.arange(100)

# %%
var_ratio = []
for num in nums:
  pca = PCA(n_components=num)
  #pca.fit(scaled_df)
  pca.fit(dataframe)
  var_ratio.append(np.sum(pca.explained_variance_ratio_))

# %%
print(sum(pca.explained_variance_ratio_))
# Out:
# 0.867940253081994

# %%
plt.figure(figsize=(4,2),dpi=150)
plt.grid()
plt.plot(nums,var_ratio,marker='o')
plt.xlabel('n_components')
plt.ylabel('Explained variance ratio')
plt.title('n_components vs. Explained Variance Ratio')
# Out:
# Text(0.5, 1.0, 'n_components vs. Explained Variance Ratio')

# %%
bing=pca.fit(dataframe)

# %%
type(bing)
# Out:
# sklearn.decomposition._pca.PCA

# %%
from sklearn.decomposition import TruncatedSVD
sparsepca = TruncatedSVD(n_components=3)
sparsepca.fit_transform(dataframe)
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 3.65667731e-03,  4.78802381e-03, -5.20304333e-03],
#        [ 2.43736952e-04, -9.83061693e-05, -5.09991871e-05],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 2.21724845e-04,  4.50897876e-04, -2.88351356e-04],
#        [ 2.74059956e-04, -5.24800156e-05, -3.34572462e-04]])

# %%
print(sum(sparsepca.explained_variance_ratio_))
# Out:
# 0.14804904764512755

# %%
compcount = range(1,50)
iterations = 10
oversamples = 10
seed = 81

# %%
from sklearn.decomposition import TruncatedSVD
test = TruncatedSVD(n_components=50, algorithm='randomized', n_iter=iterations, n_oversamples=oversamples, random_state=seed)
temp = test.fit(dataframe)

# %%
# Out:
# 10

# %%
temp.explained_variance_ratio_
# Out:
# array([0.0567029 , 0.06025464, 0.0311013 , 0.03108875, 0.02928129])

# %%
compcount = range(1,300)
iterations = 10
oversamples = 10
seed = 81

# %%
varlist = []
for items in compcount:
    test = TruncatedSVD(n_components=items, algorithm='randomized', n_iter=iterations, n_oversamples=oversamples, random_state=seed)
    test.fit(dataframe)
    varlist.append(np.sum(test.explained_variance_ratio_))

# %%
plt.figure(figsize=(4,2),dpi=500)
plt.grid()
plt.plot(compcount,varlist,marker='o', markersize=1)
plt.xlabel('n_components')
plt.ylabel('Explained variance ratio')
plt.title('n_components vs. Explained Variance Ratio')
# Out:
# Text(0.5, 1.0, 'n_components vs. Explained Variance Ratio')

# %%
print(sum(test.explained_variance_ratio_))
# Out:
# 0.9999999999999971

# %%
varlist
# Out:
# [0.056702743755168254,
#  0.11695738141560709,
#  0.14805745643194287,
#  0.17915153149552684,
#  0.20843557299100746,
#  0.23484004380131782,
#  0.25669453638770023,
#  0.278322679065833,
#  0.29884892513519884,
#  0.31855839214596554,
#  0.3370989026664286,
#  0.3530097922811505,
#  0.36880128722480954,
#  0.3838227035270493,
#  0.39869752353120996,
#  0.4114658947903998,
#  0.424165237375501,
#  0.4368462443980339,
#  0.44840719704904125,
#  0.45958107765430656,
#  0.4697577638214566,
#  0.4794900435473173,
#  0.4892418797927884,
#  0.4989817144347357,
#  0.5086583374459939,
#  0.5183107151346108,
#  0.5270546674850314,
#  0.535366769962791,
#  0.5434809117619286,
#  0.5514560269384724,
#  0.5590373742976111,
#  0.5663207481268451,
#  0.5735324860264378,
#  0.5805216041741778,
#  0.5874468492823797,
#  0.5942789862703333,
#  0.6009658858213872,
#  0.6076376120705801,
#  0.6140979670258659,
#  0.620495180479639,
#  0.6270914418264754,
#  0.63327417934612,
#  0.6396812348176384,
# ...
