# %%
#UMAP testing

import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
import umap


from rdkit import Chem
import pandas as pd

data = pd.read_csv('deepnormspedata.csv')
dataframe = data.drop("DeepSMILE",axis=1)

# %%
reducer = umap.UMAP()

embedding = reducer.fit_transform(dataframe)
embedding.shape
# Out:
# /Users/james/anaconda3/lib/python3.11/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# (13244, 2)

# %%
embedding
# Out:
# array([[-14.8815975 ,   2.6071353 ],
#        [ -0.18077342,   7.935501  ],
#        [  3.7175272 ,   0.12789474],
#        ...,
#        [-14.79624   ,   2.301991  ],
#        [ -0.21707428,  -5.31794   ],
#        [  5.2245436 ,  13.4329195 ]], dtype=float32)

# %%
plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
    c=[sns.color_palette()[x] for x in dataframe.Toxicity_Value.map({0:0, 1:1})])
plt.gca().set_aspect('equal', 'datalim')

# %%
print(dataframe.dtypes)
# Out:
# Toxicity_Value      int64
# /C=C\C(=O)OCC     float64
# /C=C1             float64
# )cccc3            float64
# (CC(O)=O)         float64
#                    ...
# /C=C(/CC          float64
# .O=C([O-])        float64
# -c1ccccc1)cc2     float64
# (N(C)C)           float64
# (CN)              float64
# Length: 309, dtype: object
