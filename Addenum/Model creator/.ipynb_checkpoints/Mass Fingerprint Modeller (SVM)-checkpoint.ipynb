# %%
#1/12/24 Creates and saves the models for:
#MorganFP | SVM | NR-AhR

import os
import pandas as pd
import numpy as np
import math
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Fingerprints/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' and 'organ' in filename and 'NR-AhR' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df.drop(columns=['SMILES'], inplace=True)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
resultslist = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 1
        maxval = 0
        for mtry in range(1, 4):
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = mtry,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)


            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = mtry
        #store best model for the given fold and plot the metric vs mcc value
        rf = SVM = svm.SVC(C=1, kernel='poly', gamma='scale',degree = bestmetrics,
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)

        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    resultslist.append(results[12])
# Out:
# ========================================
# For dataset NR-AhR_Morganfp.csv
# for fold 1 test set mcc of 0.6892889335554799 valid set mcc of 0.4409077231272339
# for fold 2 test set mcc of 0.551015445038995 valid set mcc of 0.5048839721464334
# for fold 3 test set mcc of 0.6081385697683463 valid set mcc of 0.6957622169940441
# for fold 4 test set mcc of 0.6982390321941425 valid set mcc of 0.5778357190665774
# for fold 5 test set mcc of 0.6865236565629865 valid set mcc of 0.6439569789995535
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.8328358208955224
# mcc = 0.6603887227797506

# %%
import joblib
loops = 0
for item in model_list:
    temp = loops
    loops = str(loops)
    name = loops + '.pkl'
    path = '/Users/james/Documents/Honours/Addenum/Model storage/MorganFP/SVM/NR-AhR/' + name
    
    joblib.dump(item, path) 
    loops = temp + 1

# %%
temp = pd.DataFrame(resultslist, columns=['MCC'])
temp2 = pd.DataFrame(namelist, columns=['Dataset'])
resultframe = pd.concat([temp2, temp], axis=1)
resultframe.to_csv('/Users/james/Documents/Honours/Results/Model_Outputs/SVM_Fingerprint_Results.csv')

# %%
#30/7/24 Creates a K fold KNN model for each file in a folder provided they are Fingerprints

import os
import pandas as pd
import numpy as np
import math
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sys
sys.path.insert(1, '/Users/james/Documents/Honours/Python')
from Function_Repo import metriccalc 
from Function_Repo import setbalance
import math

seed = 81
#Data import
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Data/Fingerprints/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' and 'organ' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        df.drop(columns=['SMILES'], inplace=True)
        df = setbalance(df)
        datasets.append(df)
        namelist.append(filename)

sets = 0
resultslist = []
for df in datasets:
    df = df.dropna()
    dfarray = df.to_numpy()
    
    dfarray, tempset = train_test_split(dfarray, test_size=0.2, 
                                        random_state=seed, stratify = df['Toxicity_Value'])
    
    size = len(dfarray) / 5
    splitsize = math.ceil(size)
    empty = [[] for _ in range(5)]
    splits = []
    for list in empty:
        splits.append(list)
        
    loops = 0
    currsplit = 0
    #Results in a list of 5 lists that each contain 1/5 of the targetdata
    for row in dfarray:
        splits[currsplit].append(row)
        if loops == splitsize:
            loops = 0
            currsplit = currsplit + 1
        loops = loops + 1

    folds = []
    for split in splits:
        temp = pd.DataFrame(split)
        folds.append(temp)
    
    model_list = []
    validlist = []
    totalmetrics = []
    testdat = []
    #For loop that uses each fold once for valid/testing and the rest for training
    #Each 'split' in the range corresponds to the set used for test/validation with the other 4 for training
    iteration = 1
    print('========================================')
    print('For dataset', namelist[sets])
    for split in range(0,5):
        #Set creation
        trainlist = [df for i, df in enumerate(folds) if i != split]
        trainset = pd.concat(trainlist, axis=0)
        testset, validset = train_test_split(folds[split], test_size=0.5, random_state=seed)

        ytrain = trainset[0].values
        xtrain = trainset.iloc[:, 1:]

        ytest = testset[0].values
        xtest = testset.iloc[:, 1:]

        yvalid = validset[0].values
        xvalid = validset.iloc[:, 1:]

        #lists of metric values
        mcclist = []
        bestmetrics = 'linear'
        maxval = 0
        mtry = ['linear', 'rbf']
        for item in mtry:
            #using mtry as the adjusted hyperparameter creates a series of random forests
            rf = SVM = svm.SVC(C=1, kernel=item, gamma='scale',
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)


            model= rf.fit(xtrain, ytrain)
            preds = model.predict(xtest)
            #calculate metric (mcc)
            mcc = metriccalc(preds, ytest)[12]
            mcclist.append(mcc)
            if mcc > maxval:
                maxval = mcc
                bestmetrics = item
        #store best model for the given fold and plot the metric vs mcc value
        rf = SVM = svm.SVC(C=1, kernel=bestmetrics, gamma='scale',
              coef0=0.4, shrinking=True, probability=False, 
              tol=0.001, cache_size=200, class_weight=None, 
              verbose=False, max_iter=-1, decision_function_shape='ovr', 
              break_ties=False, random_state=seed)

        model_list.append(rf)
        testdat.append(maxval)
        totalmetrics.append(mcclist)

        #check models onto validation set, printing various metrics
        model= rf.fit(xtrain, ytrain)
        preds = model.predict(xvalid)
        results = metriccalc(preds, yvalid)
        validlist.append(results)
        print('for fold', split + 1, 'test set mcc of', maxval, 'valid set mcc of', results[12])
        
        iteration = iteration + 1
        
        #get x and y values for the final validation set

    toxvals = []
    fingerprints = []
    for row in tempset:
        toxvals.append(row[0])
        fingerprints.append(row[1:])
        
    #calculates consensus of models on each fingerprint in the final validation set
    consensuslist = []
    predictions = []
    for fp in fingerprints:
        consensus = -1
        fp = fp.reshape(1, -1)
        #appends each model's prediction to a list
        predictions = []
        predlist = []
        for model in model_list:
            preds = model.predict(fp)
            predictions.append(preds)
            predlist.append(preds)
        predictions.append(predlist)

        #finds number of 0s in the prediction list
        zercount = 0
        for num in predictions:
            if num == 0:
                zercount = zercount + 1
        #as there are 5 models, if there are less than 3 0s predicted, the consensus is 1
        if zercount < 3 :
            consensus = 1
        else:
            consensus = 0
        consensuslist.append(consensus)
    #calculate and print metrics
    results = metriccalc(consensuslist, toxvals)
    print('\nvalidation metrics of:')
    print('positives in data', results[0])
    print('negatives in data', results[1])
    print('net accuracy =', results[6])
    print('mcc =',results[12])
    sets += 1
    resultslist.append(results[12])
# Out:
# ========================================
# For dataset SR-ATAD5_Morganfp.csv
# for fold 1 test set mcc of 0.5961538461538461 valid set mcc of 0.4305283859114459
# for fold 2 test set mcc of 0.4630084785605513 valid set mcc of 0.2311212814645309
# for fold 3 test set mcc of 0.38060102844992794 valid set mcc of 0.5601120336112039
# for fold 4 test set mcc of 0.3597509890988714 valid set mcc of 0.4902903378454601
# for fold 5 test set mcc of 0.17844356324383878 valid set mcc of 0.5299706017918122
#
# validation metrics of:
# positives in data 51
# negatives in data 53
# net accuracy = 0.7788461538461539
# mcc = 0.5778306605659206
# ========================================
# For dataset NR-AhR_Morganfp.csv
# for fold 1 test set mcc of 0.6588055285731584 valid set mcc of 0.5022788975351153
# for fold 2 test set mcc of 0.5185500755397814 valid set mcc of 0.5489687507225844
# for fold 3 test set mcc of 0.6535484324666608 valid set mcc of 0.6490476190476191
# for fold 4 test set mcc of 0.6412519283220873 valid set mcc of 0.6524544026942056
# for fold 5 test set mcc of 0.7467728458225558 valid set mcc of 0.613314303433564
#
# validation metrics of:
# positives in data 148
# negatives in data 187
# net accuracy = 0.8477611940298507
# mcc = 0.6913558719743398
# ========================================
# For dataset Hepatotoxicity_Morganfp.csv
# for fold 1 test set mcc of 0.5436539236653813 valid set mcc of 0.4774496695012353
# for fold 2 test set mcc of 0.48062073753771806 valid set mcc of 0.4822378180613641
# for fold 3 test set mcc of 0.5590464581634931 valid set mcc of 0.39284479166156655
# for fold 4 test set mcc of 0.45587017323405643 valid set mcc of 0.4418146204422421
# for fold 5 test set mcc of 0.47054249827818717 valid set mcc of 0.48564083079901305
#
# validation metrics of:
# positives in data 293
# negatives in data 285
# net accuracy = 0.754325259515571
# mcc = 0.5086258430141107
# ========================================
# For dataset Cardiotoxicity-5_Morganfp.csv
# for fold 1 test set mcc of 0.5080602010346503 valid set mcc of 0.3853987191542301
# for fold 2 test set mcc of 0.5577162044746101 valid set mcc of 0.3120960167811957
# for fold 3 test set mcc of 0.5483870967741935 valid set mcc of 0.46575893040085814
# for fold 4 test set mcc of 0.3617282821275655 valid set mcc of 0.42431694168556217
# for fold 5 test set mcc of 0.3620217653823299 valid set mcc of 0.3781886714809979
#
# validation metrics of:
# positives in data 143
# negatives in data 167
# net accuracy = 0.7677419354838709
# mcc = 0.5343661566350804
# ========================================
# For dataset NR-PPAR-gamma_Morganfp.csv
# for fold 1 test set mcc of 0.600099198148979 valid set mcc of 0.48911598804451845
# for fold 2 test set mcc of 0.4542199791661351 valid set mcc of 0.08183170883849714
# for fold 3 test set mcc of 0.3299670532745312 valid set mcc of 0.4708709557974187
# for fold 4 test set mcc of 0.3619137456499585 valid set mcc of 0.27865801780244004
# for fold 5 test set mcc of 0.47193990372426947 valid set mcc of 0.29433147307547786
#
# validation metrics of:
# positives in data 36
# negatives in data 37
# net accuracy = 0.7671232876712328
# mcc = 0.5496756560934648
# ========================================
# For dataset Cardiotoxicity-10_Morganfp.csv
# for fold 1 test set mcc of 0.3776453809531824 valid set mcc of 0.37746438264440085
# for fold 2 test set mcc of 0.45345112042656843 valid set mcc of 0.28054285679021057
# for fold 3 test set mcc of 0.26230294551046796 valid set mcc of 0.4255303629257752
# for fold 4 test set mcc of 0.23389316207853797 valid set mcc of 0.3721583972708073
# for fold 5 test set mcc of 0.4556257028553703 valid set mcc of 0.40500540769534277
#
# validation metrics of:
# positives in data 190
# negatives in data 120
# net accuracy = 0.7032258064516129
# mcc = 0.3472969182242667
# ========================================
# For dataset SR-MMP_Morganfp.csv
# for fold 1 test set mcc of 0.7169930618012961 valid set mcc of 0.49127778738348393
# for fold 2 test set mcc of 0.5871773243454872 valid set mcc of 0.6410532974933835
# for fold 3 test set mcc of 0.4687521542268279 valid set mcc of 0.5409164436982483
# for fold 4 test set mcc of 0.5981688731256756 valid set mcc of 0.46063014044654443
# for fold 5 test set mcc of 0.6559191657538715 valid set mcc of 0.5488276478712105
#
# validation metrics of:
# positives in data 179
# negatives in data 243
# net accuracy = 0.8104265402843602
# mcc = 0.61318066854479
# ========================================
# For dataset Reproductive_Toxicity_Morganfp.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0 valid set mcc of 0
#
# validation metrics of:
# positives in data 0
# negatives in data 0
# net accuracy = 0
# mcc = 0
# ========================================
# For dataset NR-ER-LBD_Morganfp.csv
# for fold 1 test set mcc of 0.5285084312760371 valid set mcc of 0.5072599298483808
# for fold 2 test set mcc of 0.4072838101874617 valid set mcc of 0
# for fold 3 test set mcc of 0.4814165682409486 valid set mcc of 0.5850931677018634
# for fold 4 test set mcc of 0.43511859102905415 valid set mcc of 0.315793088469768
# for fold 5 test set mcc of 0.5972598827888349 valid set mcc of 0.2252792727943491
#
# validation metrics of:
# positives in data 70
# negatives in data 76
# net accuracy = 0.7191780821917808
# mcc = 0.46806441448386027
# ========================================
# For dataset Carcinogenicity_Morganfp.csv
# for fold 1 test set mcc of 0.4873400814033414 valid set mcc of 0.32224898890795184
# for fold 2 test set mcc of 0.4071077882379526 valid set mcc of 0.30292777803327536
# for fold 3 test set mcc of 0.45256680091718243 valid set mcc of 0.12434118282549846
# for fold 4 test set mcc of 0.32052388726899966 valid set mcc of 0.46845798908546105
# for fold 5 test set mcc of 0.4145720198718883 valid set mcc of 0.1987467064891862
#
# validation metrics of:
# positives in data 102
# negatives in data 103
# net accuracy = 0.6487804878048781
# mcc = 0.2992028464771644
# ========================================
# For dataset NR-AR_Morganfp.csv
# for fold 1 test set mcc of 0.5967763691724937 valid set mcc of 0.37442263245202967
# for fold 2 test set mcc of 0.48514197070501264 valid set mcc of 0.5216720300383332
# for fold 3 test set mcc of 0.45655162399178084 valid set mcc of 0.621731542699735
# for fold 4 test set mcc of 0.5290432684448219 valid set mcc of 0.19677828887276913
# for fold 5 test set mcc of 0.5819358307200044 valid set mcc of 0.44543540318737396
#
# validation metrics of:
# positives in data 61
# negatives in data 64
# net accuracy = 0.712
# mcc = 0.4347919047721259
# ========================================
# For dataset NR-ER_Morganfp.csv
# for fold 1 test set mcc of 0.3534885438423482 valid set mcc of 0.40163510501428556
# for fold 2 test set mcc of 0.3282830595097093 valid set mcc of 0.4707816468423359
# for fold 3 test set mcc of 0.42964230674981785 valid set mcc of 0.4587043201444248
# for fold 4 test set mcc of 0.3503182061590064 valid set mcc of 0.3964155453837805
# for fold 5 test set mcc of 0.42082781763573107 valid set mcc of 0.4989189492208138
#
# validation metrics of:
# positives in data 156
# negatives in data 212
# net accuracy = 0.6875
# mcc = 0.3550414797683218
# ========================================
# For dataset SR-ARE_Morganfp.csv
# for fold 1 test set mcc of 0.5191606221211645 valid set mcc of 0.45226701686664544
# for fold 2 test set mcc of 0.49438190445569213 valid set mcc of 0.5040448465561634
# for fold 3 test set mcc of 0.39232849464507114 valid set mcc of 0.28073634874547126
# for fold 4 test set mcc of 0.4087049144146445 valid set mcc of 0.4947756201496187
# for fold 5 test set mcc of 0.4087049144146445 valid set mcc of 0.27666349353121783
#
# validation metrics of:
# positives in data 181
# negatives in data 243
# net accuracy = 0.714622641509434
# mcc = 0.4116432595158152
# ========================================
# For dataset NR-AR-LBD_Morganfp.csv
# for fold 1 test set mcc of 0.8436933521418002 valid set mcc of 0.4913538149119954
# for fold 2 test set mcc of 0.47193990372426947 valid set mcc of 0.35387166498534905
# for fold 3 test set mcc of 0.610170215847752 valid set mcc of 0.6086409915171404
# for fold 4 test set mcc of 0.7475658184884459 valid set mcc of 0.33793249261534086
# for fold 5 test set mcc of 0.621703553052045 valid set mcc of 0.6324555320336758
#
# validation metrics of:
# positives in data 47
# negatives in data 49
# net accuracy = 0.7604166666666666
# mcc = 0.5224392925598775
# ========================================
# For dataset Ames_Mutagenicity_Morganfp.csv
# for fold 1 test set mcc of 0.5768350189076229 valid set mcc of 0.639201909806263
# for fold 2 test set mcc of 0.6418922369491205 valid set mcc of 0.6738109560559242
# for fold 3 test set mcc of 0.6430102248516405 valid set mcc of 0.6116411148928902
# for fold 4 test set mcc of 0.6753101654978036 valid set mcc of 0.6381703457928374
# for fold 5 test set mcc of 0.5928399118973537 valid set mcc of 0.6201337052300818
#
# validation metrics of:
# positives in data 839
# negatives in data 658
# net accuracy = 0.8269873079492318
# mcc = 0.6483706301683761
# ========================================
# For dataset Respiratory_Toxicity_Morganfp.csv
# for fold 1 test set mcc of 0.47515419717981877 valid set mcc of 0.5941024615485658
# for fold 2 test set mcc of 0.6015309886719727 valid set mcc of 0.38980119027882554
# for fold 3 test set mcc of 0.5684227030550382 valid set mcc of 0.6031563375749631
# for fold 4 test set mcc of 0.6070264880658435 valid set mcc of 0.5999283841048733
# for fold 5 test set mcc of 0.5594309277855157 valid set mcc of 0.4601335160452312
#
# validation metrics of:
# positives in data 164
# negatives in data 106
# net accuracy = 0.774074074074074
# mcc = 0.5214808739457241
# ========================================
# For dataset SR-HSE_Morganfp.csv
# for fold 1 test set mcc of 0.30087815483526853 valid set mcc of 0.3037636376123802
# for fold 2 test set mcc of 0.3572223076986949 valid set mcc of 0.5307692307692308
# for fold 3 test set mcc of 0.39282507830533664 valid set mcc of 0.6489513805854031
# for fold 4 test set mcc of 0.2337114772985157 valid set mcc of 0.49058177521232704
# for fold 5 test set mcc of 0.5312628103109458 valid set mcc of 0.3142857142857143
#
# validation metrics of:
# positives in data 73
# negatives in data 79
# net accuracy = 0.6776315789473685
# mcc = 0.35341500311298857
# ========================================
# For dataset NR-aromatase_Morganfp.csv
# for fold 1 test set mcc of 0.3837459900665664 valid set mcc of 0.4307184633247447
# for fold 2 test set mcc of 0.33100637062042226 valid set mcc of 0.5943488886335515
# for fold 3 test set mcc of 0.7513319206146093 valid set mcc of 0.7660323462854265
# for fold 4 test set mcc of 0.49913659061809706 valid set mcc of 0.34673804626442817
# for fold 5 test set mcc of 0.27717391304347827 valid set mcc of 0.7945454545454546
#
# validation metrics of:
# positives in data 58
# negatives in data 63
# net accuracy = 0.7851239669421488
# mcc = 0.5719366282482605
# ========================================
# For dataset SR-p53_Morganfp.csv
# for fold 1 test set mcc of 0.48212728857890147 valid set mcc of 0.5008546959021241
# for fold 2 test set mcc of 0.3518700657449876 valid set mcc of 0.27684044624136017
# for fold 3 test set mcc of 0.412987012987013 valid set mcc of 0.18499380949549885
# for fold 4 test set mcc of 0.5477420177531778 valid set mcc of 0.3125333896215557
# for fold 5 test set mcc of 0.5534608112409755 valid set mcc of 0.6070947975067227
#
# validation metrics of:
# positives in data 81
# negatives in data 89
# net accuracy = 0.7
# mcc = 0.4012427832875904
# ========================================
# For dataset Cardiotoxicity-1_Morganfp.csv
# for fold 1 test set mcc of 0.4012572858800745 valid set mcc of 0.5287882878677945
# for fold 2 test set mcc of 0.486050365268909 valid set mcc of 0.6494176445883851
# for fold 3 test set mcc of 0.47140864721310444 valid set mcc of 0.5157147160546084
# for fold 4 test set mcc of 0.45204587779921973 valid set mcc of 0.3438949540447199
# for fold 5 test set mcc of 0.5144561561215357 valid set mcc of 0.5203115248912034
#
# validation metrics of:
# positives in data 70
# negatives in data 240
# net accuracy = 0.832258064516129
# mcc = 0.469071754703819
# ========================================
# For dataset Developmental_Toxicity_Morganfp.csv
# for fold 1 test set mcc of 0 valid set mcc of 0
# for fold 2 test set mcc of 0.16666666666666666 valid set mcc of 0
# for fold 3 test set mcc of 0 valid set mcc of 0
# for fold 4 test set mcc of 0 valid set mcc of 0
# for fold 5 test set mcc of 0.16666666666666666 valid set mcc of 0
#
# validation metrics of:
# positives in data 8
# negatives in data 6
# net accuracy = 0.7142857142857143
# mcc = 0.41079191812887456
# ========================================
# For dataset Cardiotoxicity-30_Morganfp.csv
# for fold 1 test set mcc of 0.1705466252048397 valid set mcc of 0.35976048897510887
# for fold 2 test set mcc of 0.26246117725335566 valid set mcc of 0.4629100498862757
# for fold 3 test set mcc of 0.39181209465563177 valid set mcc of 0.30817554274731757
# for fold 4 test set mcc of 0.46973951668784747 valid set mcc of 0.1336306209562122
# for fold 5 test set mcc of 0.2520295471191023 valid set mcc of 0.32563597234079483
#
# validation metrics of:
# positives in data 85
# negatives in data 53
# net accuracy = 0.6956521739130435
# mcc = 0.33429605127451517

# %%
resultslist
# Out:
# [0.5778306605659206,
#  0.6913558719743398,
#  0.5086258430141107,
#  0.5343661566350804,
#  0.5496756560934648,
#  0.3472969182242667,
#  0.61318066854479,
#  0,
#  0.46806441448386027,
#  0.2992028464771644,
#  0.4347919047721259,
#  0.3550414797683218,
#  0.4116432595158152,
#  0.5224392925598775,
#  0.6483706301683761,
#  0.5214808739457241,
#  0.35341500311298857,
#  0.5719366282482605,
#  0.4012427832875904,
#  0.469071754703819,
#  0.41079191812887456,
#  0.33429605127451517]

# %%
import os
datasets = []
index = []
directory = '/Users/james/Documents/Honours/Results/Model_Outputs/'
namelist = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if 'csv' in filename:
        pathname = directory + file
        df = pd.read_csv(pathname)
        datasets.append(df)
        namelist.append(filename)

# %%
old = datasets[1]['MCC']

# %%
loops = 0
for item in old:
    print(old[loops], resultslist[loops])
    loops += 1
# Out:
# 0.4632511391540115 0.5778306605659206
# 0.6057622340798641 0.6913558719743398
# 0.5330317753634951 0.5086258430141107
# 0.4976444945946108 0.5343661566350804
# 0.5179467772872011 0.5496756560934648
# 0.348065274025202 0.3472969182242667
# 0.5863241664917337 0.61318066854479
# 0.1 0
# 0.487670425490951 0.46806441448386027
# 0.3560887510773948 0.2992028464771644
# 0.4968030024467603 0.4347919047721259
# 0.4156946743886325 0.3550414797683218
# 0.4533787293352714 0.4116432595158152
# 0.5818429184443191 0.5224392925598775
# 0.634433058924186 0.6483706301683761
# 0.5085112938598969 0.5214808739457241
# 0.314423761344636 0.35341500311298857
# 0.525117853414576 0.5719366282482605
# 0.3838460077003889 0.4012427832875904
# 0.5511343174274512 0.469071754703819
# 0.251259453814803 0.41079191812887456
# 0.3821686953829813 0.33429605127451517
